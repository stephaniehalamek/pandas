# %% [markdown]
# # String Series Methods
#
# The previous chapters in this part focused mainly on Series that contained numeric values. In this chapter, we focus on methods that work for Series containing string data. Columns of strings are usually processed differently than columns of numeric values. Remember, that strings are read in as the **object** data type which technically may contain any Python object.
#
# With the release of pandas 1.0, a dedicated string data type was made available. All of the commands in this chapter will use the old object data type but will also work for this new string data type. The reason the string data type is not used in this chapter, is that it is not the default data type. Let's begin by reading in the employee dataset and selecting the `dept` column as a Series.

# %%
import pandas as pd
emp = pd.read_csv('../data/employee.csv')
dept = emp['dept']
dept.head(3)
# Out:
# 0                  Police
# 1                   Other
# 2    Houston Public Works
# Name: dept, dtype: object

# %% [markdown]
# ### Attempt to take the mean
#
# Several methods that worked on numeric columns will either not work with strings or provide little value. For instance, the `mean` method raises an exception when attempted on a string column.

# %%
dept.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'PoliceOtherHouston Public WorksPolicePoliceOtherHouston Public WorksPoliceFirePoliceHealth & Human ServicesFireLibraryHouston Public WorksFireFireOtherPoliceHouston Public WorksOtherHouston Airport SystemFirePoliceSolid Waste ManagementPolicePoliceHouston Airport SystemHouston Public WorksOtherHouston Public WorksHouston Public WorksPoliceHouston Public WorksOtherPoliceParks & RecreationPoliceOtherPoliceHouston Airport SystemPoliceHealth & Human ServicesFireFireHouston Public WorksFireLibraryPoliceFireFireHouston Public WorksOtherOtherHouston Public WorksPoliceOtherHouston Public WorksPoliceFirePoliceOtherFireParks & RecreationFireParks & RecreationFireFireFireHouston Airport SystemFireParks & RecreationSolid Waste ManagementHouston Public WorksPoliceParks & RecreationFireHouston Airport SystemHouston Public WorksHouston Airport SystemHouston Airport SystemHouston Airport SystemPoliceParks & RecreationOtherFireFireHealth & Human ServicesParks & RecreationOtherFireFireHouston Airport SystemHouston Public WorksPoliceHouston Public WorksParks & RecreationPolicePoliceHouston Airport SystemFirePoliceOtherPolicePolicePolicePoliceOtherPoliceHealth & Human ServicesHouston Public WorksFirePoliceFirePoliceHouston Airport SystemHouston Public WorksFirePoliceHouston Airport SystemHealth & Human ServicesPoliceOtherFirePoliceFirePoliceHouston Public WorksHouston Public WorksHouston Public WorksFireOtherPoliceHouston Public WorksPolicePoliceParks & RecreationPoliceHouston Public WorksFireFirePoliceFireHouston Public WorksHouston Airport SystemHealth & Human ServicesPoliceFireHouston Public WorksSolid Waste ManagementOtherFirePoliceHouston Public WorksHouston Public WorksOtherParks & RecreationHouston Public WorksFirePolicePoliceHouston Public WorksPoliceFirePoliceHouston Public WorksOtherHouston Public WorksSolid Waste ManagementHouston Public WorksOtherHouston Public WorksHouston Public WorksHouston Public WorksParks & RecreationHouston Public WorksFireOtherOtherSolid Waste ManagementOtherHouston Public WorksPoliceHouston Public WorksSolid Waste ManagementHouston Public WorksPoliceHouston Public WorksFireHouston Public WorksFireFireFireOtherPolicePoliceHouston Airport SystemSolid Waste ManagementFireHouston Public WorksOtherPoliceParks & RecreationPoliceOtherPoliceFireHealth & Human ServicesOtherHouston Public WorksPoliceFirePoliceOtherHealth & Human ServicesHouston Public WorksParks & RecreationParks & RecreationPoliceOtherPolicePoliceHealth & Human ServicesHouston Public WorksOtherHouston Public WorksHouston Airport SystemOtherHouston Public WorksPoliceFirePoliceSolid Waste ManagementPolicePolicePolicePoliceParks & RecreationPoliceHouston Public WorksPoliceHouston Public WorksFirePolicePoliceParks & RecreationFireFireOtherFireHouston Public WorksFirePolicePolicePolicePoliceHouston Public WorksHealth & Human ServicesFireOtherHouston Public WorksParks & RecreationHouston Airport SystemPoliceHouston Airport SystemOtherFirePolicePoliceOtherHouston Airport SystemParks & RecreationHouston Airport SystemPolicePoliceHouston Public WorksParks & RecreationFireParks & RecreationOtherFirePolicePoliceFirePolicePolicePoliceParks & RecreationParks & RecreationPolicePolicePolicePolicePoliceOtherHouston Public WorksPoliceFireOtherHouston Public WorksPoliceLibraryHouston Airport SystemPoliceFireFireFirePolicePoliceLibraryHouston Public WorksHouston Public WorksHouston Public WorksFireHouston Public WorksOtherPoliceHealth & Human ServicesOtherHouston Public WorksPolicePoliceHealth & Human ServicesPoliceFireHouston Public WorksOtherHouston Airport SystemOtherPoliceFireOtherParks & RecreationHouston Public WorksPoliceHouston Airport SystemFireHouston Public WorksPolicePoliceHouston Public WorksHouston Public WorksFireFireOtherPoliceSolid Waste ManagementSolid Waste ManagementHouston Public WorksPolicePoliceHouston Airport SystemFireSolid Waste ManagementOtherHouston Public WorksHealth & Human ServicesHouston Pub ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dept.mean()
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert PoliceOtherHouston Public WorksPolicePoliceOtherHouston Public WorksPoliceFirePoliceHealth & Human ServicesFireLibraryHouston Public WorksFireFireOtherPoliceHouston Public WorksOtherHouston Airport SystemFirePoliceSolid Waste ManagementPolicePoliceHouston Airport SystemHouston Public WorksOtherHouston Public WorksHouston Public WorksPoliceHouston Public WorksOtherPoliceParks & RecreationPoliceOtherPoliceHouston Airport SystemPoliceHealth & Human ServicesFireFireHouston Public WorksFireLibraryPoliceFireFireHouston Public WorksOtherOtherHouston Public WorksPoliceOtherHouston Public WorksPoliceFirePoliceOtherFireParks & RecreationFireParks & RecreationFireFireFireHouston Airport SystemFireParks & RecreationSolid Waste ManagementHouston Public WorksPoliceParks & RecreationFireHouston Airport SystemHouston Public WorksHouston Airport SystemHouston Airport SystemHouston Airport SystemPoliceParks & RecreationOtherFireFireHealth & Human ServicesParks & RecreationOtherFireFireHouston Airport SystemHouston Public WorksPoliceHouston Public WorksParks & RecreationPolicePoliceHouston Airport SystemFirePoliceOtherPolicePolicePolicePoliceOtherPoliceHealth & Human ServicesHouston Public WorksFirePoliceFirePoliceHouston Airport SystemHouston Public WorksFirePoliceHouston Airport SystemHealth & Human ServicesPoliceOtherFirePoliceFirePoliceHouston Public WorksHouston Public WorksHouston Public WorksFireOtherPoliceHouston Public WorksPolicePoliceParks & RecreationPoliceHouston Public WorksFireFirePoliceFireHouston Public WorksHouston Airport SystemHealth & Human ServicesPoliceFireHouston Public WorksSolid Waste ManagementOtherFirePoliceHouston Public WorksHouston Public WorksOtherParks & RecreationHouston Public WorksFirePolicePoliceHouston Public WorksPoliceFirePoliceHouston Public WorksOtherHouston Public WorksSolid Waste ManagementHouston Public WorksOtherHouston Public WorksHouston Public WorksHouston Public WorksParks & RecreationHouston Public WorksFireOtherOtherSolid Waste ManagementOtherHouston Public WorksPoliceHouston Public WorksSolid Waste ManagementHouston Public WorksPoliceHouston Public WorksFireHouston Public WorksFireFireFireOtherPolicePoliceHouston Airport SystemSolid Waste ManagementFireHouston Public WorksOtherPoliceParks & RecreationPoliceOtherPoliceFireHealth & Human ServicesOtherHouston Public WorksPoliceFirePoliceOtherHealth & Human ServicesHouston Public WorksParks & RecreationParks & RecreationPoliceOtherPolicePoliceHealth & Human ServicesHouston Public WorksOtherHouston Public WorksHouston Airport SystemOtherHouston Public WorksPoliceFirePoliceSolid Waste ManagementPolicePolicePolicePoliceParks & RecreationPoliceHouston Public WorksPoliceHouston Public WorksFirePolicePoliceParks & RecreationFireFireOtherFireHouston Public WorksFirePolicePolicePolicePoliceHouston Public WorksHealth & Human ServicesFireOtherHouston Public WorksParks & RecreationHouston Airport SystemPoliceHouston Airport SystemOtherFirePolicePoliceOtherHouston Airport SystemParks & RecreationHouston Airport SystemPolicePoliceHouston Public WorksParks & RecreationFireParks & RecreationOtherFirePolicePoliceFirePolicePolicePoliceParks & RecreationParks & RecreationPolicePolicePolicePolicePoliceOtherHouston Public WorksPoliceFireOtherHouston Public WorksPoliceLibraryHouston Airport SystemPoliceFireFireFirePolicePoliceLibraryHouston Public WorksHouston Public WorksHouston Public WorksFireHouston Public WorksOtherPoliceHealth & Human ServicesOtherHouston Public WorksPolicePoliceHealth & Human ServicesPoliceFireHouston Public WorksOtherHouston Airport SystemOtherPoliceFireOtherParks & RecreationHouston Public WorksPoliceHouston Airport SystemFireHouston Public WorksPolicePoliceHouston Public WorksHouston Public WorksFireFireOtherPoliceSolid Waste ManagementSolid Waste ManagementHouston Public WorksPolicePoliceHouston Airport SystemFireSolid Waste ManagementOtherHouston Public WorksHealth & Human ServicesHouston Public WorksOtherHoust ...

# %% [markdown]
# ### Other methods do work
#
# Many of the other methods we covered from the previous chapters in this part work with string columns, such as finding the maximum department. The `max` of a string is based on its alphabetical ordering.

# %%
dept.max()
# Out:
# 'Solid Waste Management'

# %% [markdown]
# ### Missing values
#
# Many other methods work with string columns identically as they do with numeric columns. Below, we calculate the number of missing values. Object data type Series can contain multiple missing value representations. The numpy `NaN` and `NaT` and Python `None` are all counted as missing.

# %%
dept.isna().sum()
# Out:
# 0

# %% [markdown]
# ## The `value_counts` method
#
# The `value_counts` method is one of the most valuable methods for string columns. It returns the count of each unique value in the Series and sorts it from most to least common.

# %%
dept.value_counts()
# Out:
# Police                     7573
# Fire                       4376
# Houston Public Works       4190
# Other                      3373
# Health & Human Services    1353
# Houston Airport System     1216
# Parks & Recreation         1152
# Library                     563
# Solid Waste Management      512
# Name: dept, dtype: int64

# %% [markdown]
# ### Notice what object is returned
#
# The `value_counts` method returns a Series with the unique values as the index and the count as the new values.
#
# ### Use `normalize=True` for relative frequency
#
# We can use `value_counts` to return the relative frequency (proportion) of each occurrence instead of the raw count by setting the parameter `normalize` to `True`. For instance, this tells us that 39% of the employees are members of the police department. To reduce the amount of noise and simplify the output, the frequencies are rounded to the nearest hundredth place.

# %%
dept.value_counts(normalize=True).round(2)
# Out:
# Police                     0.31
# Fire                       0.18
# Houston Public Works       0.17
# Other                      0.14
# Health & Human Services    0.06
# Houston Airport System     0.05
# Parks & Recreation         0.05
# Library                    0.02
# Solid Waste Management     0.02
# Name: dept, dtype: float64

# %% [markdown]
# ### `value_counts` works for columns of all data types
#
# The `value_counts` method works for columns of all data types, and not just strings. It's just usually more informative for string columns. Let's use it on the salary column to see if we have common salaries.

# %%
emp['salary'].value_counts().head()
# Out:
# 75942.10    1291
# 87545.38     651
# 68116.62     639
# 62540.14     521
# 48189.70     469
# Name: salary, dtype: int64

# %% [markdown]
# ## Special methods just for object columns
#
# pandas provides a collection of methods only available to object (and string) columns. These methods are not directly available using dot notation from the DataFrame variable name and you will not be able to find them as you normally do.
#
# To access these special string-only methods, first append the Series variable name with `.str` followed by another dot and then the specific string method. pandas refers to this as the `str` accessor. Think of the term 'accessor' as giving the Series *access* to specialized string methods. [Visit the official documentation][1] to take a look at the several dozen string-only methods available with the `str` accessor. Let's use the title column for these string-only methods.
#
# [1]: https://pandas.pydata.org/pandas-docs/stable/reference/series.html#string-handling

# %%
title = emp['title']
title.head()
# Out:
# 0               POLICE SERGEANT
# 1    ASSISTANT CITY ATTORNEY II
# 2       SENIOR SLUDGE PROCESSOR
# 3         SENIOR POLICE OFFICER
# 4         SENIOR POLICE OFFICER
# Name: title, dtype: object

# %% [markdown]
# ### Make each value lowercase
#
# Let's begin by calling a simple string method to make each value in the `title` Series lowercase. We will use the `lower` method of the `str` accessor.

# %%
title.str.lower().head()
# Out:
# 0               police sergeant
# 1    assistant city attorney ii
# 2       senior sludge processor
# 3         senior police officer
# 4         senior police officer
# Name: title, dtype: object

# %% [markdown]
# ### Lot's of methods, but mostly easy to use
#
# There is quite a lot of functionality to manipulate and probe strings in almost any way you can imagine. We will not cover every single method possible, but instead, walk through examples of some of the more common ones listed below:
#
# * `count` - Returns the number of non-overlapping occurrences of the passed string.
# * `contains` - Checks to see whether each string contains the given string. Returns a boolean Series
# * `len` - Returns the number of characters in each string
# * `split` - Splits the string into multiple strings by a given separator
# * `replace` - Replaces parts of a string with other characters
#
# ## The `count` string method
#
# The `count` method returns the number of non-overlapping occurrences of the passed string. Here, we count the number of uppercase 'O' characters appear in each string.

# %%
title.str.count('O').head()
# Out:
# 0    1
# 1    1
# 2    3
# 3    3
# 4    3
# Name: title, dtype: int64

# %%
title.head()
# Out:
# 0               POLICE SERGEANT
# 1    ASSISTANT CITY ATTORNEY II
# 2       SENIOR SLUDGE PROCESSOR
# 3         SENIOR POLICE OFFICER
# 4         SENIOR POLICE OFFICER
# Name: title, dtype: object

# %% [markdown]
# You are not limited to single characters. Here, we count the number of times 'ER' appears in each string.

# %%
title.str.count('ER').head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: title, dtype: int64

# %% [markdown]
# ## The `contains` str method
#
# The `contains` method returns a boolean whether or not the passed string is contained somewhere within the string. Let's determine if any titles contain the letter 'Z'?

# %%
title.str.contains('Z').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: title, dtype: bool

# %% [markdown]
# We can then sum this boolean Series to find the number of employees that have a title containing 'Z'.

# %%
title.str.contains('Z').sum()
# Out:
# 0

# %% [markdown]
# Let's find out which employees have the word 'POLICE' somewhere in their title.

# %%
title.str.contains('POLICE').head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: title, dtype: bool

# %% [markdown]
# Summing this Series reveals the number of employees that have the word 'POLICE' somewhere in their title.

# %%
title.str.contains('POLICE').sum()
# Out:
# 6690

# %% [markdown]
# ## The `len` str method
#
# The `len` string method returns the length of every string. Take note that this is completely different and unrelated to the `len` built-in function which returns the number of elements in a Series.

# %%
title.str.len().head()
# Out:
# 0    15
# 1    26
# 2    23
# 3    21
# 4    21
# Name: title, dtype: int64

# %% [markdown]
# ## The `split` str method
#
# The `split` method splits each string into multiple separate strings based on a given separator. The default separator is a single space. The following splits on each space and returns a Series of lists.

# %%
title.str.split().head(3)
# Out:
# 0                 [POLICE, SERGEANT]
# 1    [ASSISTANT, CITY, ATTORNEY, II]
# 2        [SENIOR, SLUDGE, PROCESSOR]
# Name: title, dtype: object

# %% [markdown]
# Set the `expand` parameter to `True` to return a DataFrame:

# %%
title.str.split(expand=True).head(3)
# Out:
#            0         1          2     3     4     5     6
# 0     POLICE  SERGEANT       None  None  None  None  None
# 1  ASSISTANT      CITY   ATTORNEY    II  None  None  None
# 2     SENIOR    SLUDGE  PROCESSOR  None  None  None  None

# %% [markdown]
# Here, we split on the string 'AN'. Note that the string used for splitting is removed and not contained in the result.

# %%
title.str.split('AN', expand=True).head(3)
# Out:
#                          0                   1     2     3
# 0             POLICE SERGE                   T  None  None
# 1                   ASSIST  T CITY ATTORNEY II  None  None
# 2  SENIOR SLUDGE PROCESSOR                None  None  None

# %% [markdown]
# ## The `replace` str method
#
# The `replace` string method allows you to replace one section of the string (a substring) with some other string. You must pass two string arguments to `replace` - the string you want to replace and its replacement value. Here, we replace 'SENIOR' with 'SR.'.

# %%
title.head()
# Out:
# 0               POLICE SERGEANT
# 1    ASSISTANT CITY ATTORNEY II
# 2       SENIOR SLUDGE PROCESSOR
# 3         SENIOR POLICE OFFICER
# 4         SENIOR POLICE OFFICER
# Name: title, dtype: object

# %%
title.str.replace('SENIOR', 'SR.').head()
# Out:
# 0               POLICE SERGEANT
# 1    ASSISTANT CITY ATTORNEY II
# 2          SR. SLUDGE PROCESSOR
# 3            SR. POLICE OFFICER
# 4            SR. POLICE OFFICER
# Name: title, dtype: object

# %% [markdown]
# ## Selecting substrings with the brackets
#
# Selecting one or more characters of a regular Python string is simple and accomplished by using either an integer or slice notation within the brackets. Let's review this concept now.

# %%
some_string = 'The Astros will win the world series without cheating'

# %% [markdown]
# Select the character at integer location 5.

# %%
some_string[5]
# Out:
# 's'

# %% [markdown]
# Select the 24th to 36th characters with slice notation.

# %%
some_string[24:36]
# Out:
# 'world series'

# %% [markdown]
# You can use the same square brackets appended directly to the `str` accessor to select one or more characters from every string in a Series. Let's begin by selecting the character at integer location 10.

# %%
title.str[10].head(3)
# Out:
# 0    G
# 1    C
# 2    D
# Name: title, dtype: object

# %% [markdown]
# In the following example, we use slice notation to select the last five characters of each string.

# %%
title.str[-5:].head(3)
# Out:
# 0    GEANT
# 1    EY II
# 2    ESSOR
# Name: title, dtype: object

# %% [markdown]
# Slice notation is used again to select from the 5th to 15th character.

# %%
title.str[5:15].head()
# Out:
# 0    E SERGEANT
# 1    TANT CITY
# 2    R SLUDGE P
# 3    R POLICE O
# 4    R POLICE O
# Name: title, dtype: object

# %% [markdown]
# ### Many more string-only methods
#
# There are many more string-only methods that were not covered in this chapter. I encourage you to explore them on your own. Many of them overlap with the built-in Python string methods.
#
# ## Regular expressions
#
# Regular expressions help match patterns within text. Many of the string methods presented above accept regular expressions as inputs for more advanced string maneuvering. They are an important part of doing data analysis and are covered thoroughly in their own part of this book.

# %% [markdown]
# ## Exercises
#
# Read in the movie dataset assigning the actor1 column to a variable name as a Series by executing the cell below. All missing values have been dropped from this Series. Use this Series for the exercises below.

# %%
movie = pd.read_csv('../data/movie.csv', index_col='title')
actor1 = movie['actor1'].dropna()
actor1.head(3)
# Out:
# title
# Avatar                                          CCH Pounder
# Pirates of the Caribbean: At World's End        Johnny Depp
# Spectre                                     Christoph Waltz
# Name: actor1, dtype: object

# %% [markdown]
# ### Exercise 1
#
# <span  style="color:green; font-size:16px">Which actor 1 has appeared in the most movies? Can you write an expression that returns this actors name as a string?</span>

# %%
actor1.value_counts().index[0]
# Out:
# 'Robert De Niro'

# %%
type(actor1.value_counts().index[0])
# Out:
# str

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">What percent of movies have the top 100 most frequent actor 1's appeared in?</span>

# %%
top_100 = actor1.value_counts()[0:100,]

top_100.head(3)
# Out:
# Robert De Niro    48
# Johnny Depp       36
# Nicolas Cage      32
# Name: actor1, dtype: int64

# %%
top_100.sum()/ len(movie)
# Out:
# 0.32465419039869814

# %%
len(movie)
# Out:
# 4916

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">How many actor 1's have appeared in exactly one movie?</span>

# %%
actor1_cnt = movie['actor1'].value_counts()
actor1_cnt.head(2)
# Out:
# Robert De Niro    48
# Johnny Depp       36
# Name: actor1, dtype: int64

# %%
(actor1_cnt == 1).sum()
# Out:
# 1379

# %% [markdown]
# ### Exercise 4
# <span  style="color:green; font-size:16px">How many actor 1's have more than 3 e's in their name? Output a unique array of just these actor names so we can manually verify them.</span>

# %%
actor1_e = movie['actor1'].str.count('e')
eee = actor1_e >3
x = movie[eee]

# %%
x.head()
# Out:
#                                          year  color content_rating  duration  \
# title
# X-Men: Days of Future Past             2014.0  Color          PG-13     149.0
# X-Men: Apocalypse                      2016.0  Color          PG-13     144.0
# 47 Ronin                               2013.0  Color          PG-13     128.0
# X-Men: First Class                     2011.0  Color          PG-13     132.0
# The Hunger Games: Mockingjay - Part 2  2015.0  Color          PG-13     137.0
#
#                                           director_name  director_fb  \
# title
# X-Men: Days of Future Past                 Bryan Singer          0.0
# X-Men: Apocalypse                          Bryan Singer          0.0
# 47 Ronin                                    Carl Rinsch         47.0
# X-Men: First Class                       Matthew Vaughn        905.0
# The Hunger Games: Mockingjay - Part 2  Francis Lawrence        508.0
#
#                                                   actor1  actor1_fb  \
# title
# X-Men: Days of Future Past             Jennifer Lawrence    34000.0
# X-Men: Apocalypse                      Jennifer Lawrence    34000.0
# 47 Ronin                                    Keanu Reeves    18000.0
# X-Men: First Class                     Jennifer Lawrence    34000.0
# The Hunger Games: Mockingjay - Part 2  Jennifer Lawrence    34000.0
#
#                                                        actor2  actor2_fb  ...  \
# title                                                                     ...
# X-Men: Days of Future Past                     Peter Dinklage    22000.0  ...
# X-Men: Apocalypse                          Michael Fassbender    13000.0  ...
# 47 Ronin                                 Cary-Hiroyuki Tagawa     1000.0  ...
# X-Men: First Class                         Michael Fassbender    13000.0  ...
# The Hunger Games: Mockingjay - Part 2  Philip Seymour Hoffman    22000.0  ...
#
#                                       actor3_fb        gross  \
# title
# X-Men: Days of Future Past              20000.0  233914986.0
# X-Men: Apocalypse                        1000.0  154985087.0
# 47 Ronin                                  982.0   38297305.0
# X-Men: First Class                       1000.0  146405371.0
# The Hunger Games: Mockingjay - Part 2   14000.0  281666058.0
#
#                                                                          genres  \
# title
# X-Men: Days of Future Past             Action|Adventure|Fantasy|Sci-Fi|Thriller
# X-Men: Apocalypse                                       Action|Adventure|Sci-Fi
# 47 Ronin                                         Action|Adventure|Drama|Fantasy
# X-Men: First Class                                      Action|Adventure|Sci-Fi
# The Hunger Games: Mockingjay - Part 2                          Adventure|Sci-Fi
#
#                                       num_reviews  num_voted_users  \
# title
# X-Men: Days of Future Past                  539.0           514125
# X-Men: Apocalypse                           396.0           148379
# 47 Ronin                                    218.0           116994
# X-Men: First Class                          500.0           518537
# The Hunger Games: Mockingjay - Part 2       389.0           166137
#
#                                                                            plot_keywords  \
# title
# X-Men: Days of Future Past             dystopia|super strength|supernatural power|tim...
# X-Men: Apocalypse                        mutant|superhero|superhero team|x men|year 1983
# 47 Ronin                                 box office flop|ronin|samurai|shogun|tournament
# X-Men: First Class                            cia|cia agent|mutant|nuclear war|professor
# The Hunger Games: Mockingjay - Part 2  death of sister|dystopia|execution|rebellion|r...
#
#                                       language country       budget  \
# title
# X-Men: Days of Future Past             English     USA  200000000.0
# X-Men: Apocalypse                      English     USA  178000000.0
# 47 Ronin                               English     USA  175000000.0
# X-Men: First Class                     English     USA  160000000.0
# The Hunger Games: Mockingjay - Part 2  English     USA  160000000.0
#
#                                        imdb_score
# title
# X-Men: Days of Future Past                    8.0
# X-Men: Apocalypse                             7.3
# 47 Ronin                                      6.3
# X-Men: First Class                            7.8
# The Hunger Games: Mockingjay - Part 2         6.6
#
# [5 rows x 21 columns]

# %%
x['actor1'].unique()
# Out:
# array(['Jennifer Lawrence', 'Keanu Reeves', 'Seychelle Gabriel',
#        'Jeremy Renner', 'Amber Stevens West', 'Peter Greene',
#        'Steven Anthony Lawrence', 'Cedric the Entertainer',
#        'Sean Pertwee', 'Xander Berkeley', 'Kathleen Freeman',
#        'Pierre Perrier', 'Catherine Deneuve', 'George Kennedy',
#        'Leighton Meester', 'Steve Guttenberg', 'Emmanuelle Seigner',
#        'Jurnee Smollett-Bell', 'Steve Oedekerk',
#        'Johannes Silberschneider', 'Bernadette Peters',
#        'Jacqueline McKenzie', 'Dee Bradley Baker', 'Jennifer Freeman',
#        'Gene Tierney', 'Roscoe Lee Browne', 'Phoebe Legere',
#        'Eric Sheffer Stevens', 'Michael Greyeyes', 'Steven Weber',
#        'George Newbern', 'Florence Henderson', 'Michelle Simone Miller',
#        'Chemeeka Walker', 'Fereshteh Sadre Orafaiy'], dtype=object)

# %%
# Out:
# 4916

# %% [markdown]
# ### Exercise 6
#
# <span  style="color:green; font-size:16px">How many unique actor 1 names end in 'x'?</span>

# %% [markdown]
# ### Exercise 7
#
# <span style="color:green; font-size:16px">The pandas string methods overlap with the built-in Python string methods. Find all the public method names that are in-common to both. Then find the public methods that are unique to each.</span>
