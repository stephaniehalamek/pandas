# %% [markdown]
# # DataFrame Missing Value Methods
#
# This chapter covers the methods available to a DataFrame to handle missing values. They are the exact same methods that were presented for the Series. These methods behave analogously as they do with Series, but are more complex as they deal with missing values in all of the columns in the DataFrame and have more options for their usage. We begin by reading in the movie dataset setting the title as the index.

# %%
import pandas as pd
pd.set_option('display.max_columns', 40)
movie = pd.read_csv('../data/movie.csv', index_col='title')
movie.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb            actor3  \
# title
# Avatar                                        936.0         Wes Studi
# Pirates of the Caribbean: At World's End     5000.0    Jack Davenport
# Spectre                                       393.0  Stephanie Sigman
#
#                                           actor3_fb        gross  \
# title
# Avatar                                        855.0  760505847.0
# Pirates of the Caribbean: At World's End     1000.0  309404152.0
# Spectre                                       161.0  200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                           num_reviews  num_voted_users  \
# title
# Avatar                                          723.0           886204
# Pirates of the Caribbean: At World's End        302.0           471220
# Spectre                                         602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8

# %% [markdown]
# ## Methods for handling missing values
#
# pandas provides the following DataFrame methods to handle missing values:
#
# * `isna` - Returns a DataFrame of booleans based on whether each value is missing or not
# * `notna` - Exact opposite of `isna`
# * `fillna` - Fills missing values in a variety of ways
# * `dropna` - Drops rows or columns with missing values
# * `interpolate` - Fills missing values using statistical interpolation
#
# ## The `isna` method
#
# The `isna` method returns a DataFrame of all boolean values. All missing values evaluate as `True` and everything else as `False`. Let's call this method on our `movie` DataFrame. There are several missing values in the fifth row.

# %%
movie.isna().head()
# Out:
#                                              year  color  content_rating  \
# title
# Avatar                                      False  False           False
# Pirates of the Caribbean: At World's End    False  False           False
# Spectre                                     False  False           False
# The Dark Knight Rises                       False  False           False
# Star Wars: Episode VII - The Force Awakens   True   True            True
#
#                                             duration  director_name  \
# title
# Avatar                                         False          False
# Pirates of the Caribbean: At World's End       False          False
# Spectre                                        False          False
# The Dark Knight Rises                          False          False
# Star Wars: Episode VII - The Force Awakens      True          False
#
#                                             director_fb  actor1  actor1_fb  \
# title
# Avatar                                            False   False      False
# Pirates of the Caribbean: At World's End          False   False      False
# Spectre                                           False   False      False
# The Dark Knight Rises                             False   False      False
# Star Wars: Episode VII - The Force Awakens        False   False      False
#
#                                             actor2  actor2_fb  actor3  \
# title
# Avatar                                       False      False   False
# Pirates of the Caribbean: At World's End     False      False   False
# Spectre                                      False      False   False
# The Dark Knight Rises                        False      False   False
# Star Wars: Episode VII - The Force Awakens   False      False    True
#
#                                             actor3_fb  gross  genres  \
# title
# Avatar                                          False  False   False
# Pirates of the Caribbean: At World's End        False  False   False
# Spectre                                         False  False   False
# The Dark Knight Rises                           False  False   False
# Star Wars: Episode VII - The Force Awakens       True   True   False
#
#                                             num_reviews  num_voted_users  \
# title
# Avatar                                            False            False
# Pirates of the Caribbean: At World's End          False            False
# Spectre                                           False            False
# The Dark Knight Rises                             False            False
# Star Wars: Episode VII - The Force Awakens         True            False
#
#                                             plot_keywords  language  country  \
# title
# Avatar                                              False     False    False
# Pirates of the Caribbean: At World's End            False     False    False
# Spectre                                             False     False    False
# The Dark Knight Rises                               False     False    False
# Star Wars: Episode VII - The Force Awakens           True      True     True
#
#                                             budget  imdb_score
# title
# Avatar                                       False       False
# Pirates of the Caribbean: At World's End     False       False
# Spectre                                      False       False
# The Dark Knight Rises                        False       False
# Star Wars: Episode VII - The Force Awakens    True       False

# %% [markdown]
# ### Finding the number of missing values in each column
#
# There is no single direct method for finding the number of missing values in each column of a DataFrame. However, the `count` method returns the number of non-missing values of each column.

# %%
movie.count().head()
# Out:
# year              4810
# color             4897
# content_rating    4616
# duration          4901
# director_name     4814
# dtype: int64

# %% [markdown]
# To find the number of missing values, we will need to first call the `isna` method to turn each value into a boolean, and then chain the `sum` method to count the number of missing values in each column.

# %%
movie.isna().sum().head()
# Out:
# year              106
# color              19
# content_rating    300
# duration           15
# director_name     102
# dtype: int64

# %% [markdown]
# ### Find the percentage of missing values by calling the mean method
#
# As we have seen before, taking the mean of a boolean Series returns the percentage of values that are `True`, and in this case, returns the percentage of missing values for each column.

# %%
movie.isna().mean().head()
# Out:
# year              0.021562
# color             0.003865
# content_rating    0.061025
# duration          0.003051
# director_name     0.020749
# dtype: float64

# %% [markdown]
# ### Nicer visuals with rounding
#
# Although the above result is accurate, it isn't that easy to read. The last few decimal places provide little information and are not necessary to report. The result isn't technically a percentage either, but a fraction. Let's round the values and multiply by 100 to get nicer output that is a percentage.

# %%
movie.isna().mean().round(3).head() * 100
# Out:
# year              2.2
# color             0.4
# content_rating    6.1
# duration          0.3
# director_name     2.1
# dtype: float64

# %% [markdown]
# ### The `notna` method
#
# The `notna` method is the exact opposite of `isna` and evaluates as `True` for all non-missing values. Instead of outputting the head, the output the first five rows and 8 columns using the `iloc` indexer.

# %%
movie.notna().iloc[:5, :8]
# Out:
#                                              year  color  content_rating  \
# title
# Avatar                                       True   True            True
# Pirates of the Caribbean: At World's End     True   True            True
# Spectre                                      True   True            True
# The Dark Knight Rises                        True   True            True
# Star Wars: Episode VII - The Force Awakens  False  False           False
#
#                                             duration  director_name  \
# title
# Avatar                                          True           True
# Pirates of the Caribbean: At World's End        True           True
# Spectre                                         True           True
# The Dark Knight Rises                           True           True
# Star Wars: Episode VII - The Force Awakens     False           True
#
#                                             director_fb  actor1  actor1_fb
# title
# Avatar                                             True    True       True
# Pirates of the Caribbean: At World's End           True    True       True
# Spectre                                            True    True       True
# The Dark Knight Rises                              True    True       True
# Star Wars: Episode VII - The Force Awakens         True    True       True

# %% [markdown]
# ## Dropping rows and columns with the `dropna` method
#
# The `dropna` method has more options than its Series counterpart and allows you to drop either rows or columns of your DataFrame. Called with the defaults, it drops all **rows** that have at least 1 missing value. Over 1,000 rows get dropped after calling the `dropna` method on our `movie` DataFrame.

# %%
movie.dropna().shape
# Out:
# (3707, 21)

# %%
movie.shape
# Out:
# (4916, 21)

# %% [markdown]
# ### Drop rows where only a particular column is missing
#
# By default, the `dropna` method drops any rows where one or more missing values exist for that entire row. pandas gives us the option of only dropping rows where a particular column or group of columns have missing values. Instead of looking at all of the columns for missing values, we can restrict the columns with the `subset` parameter. Set this parameter to a list of the column names to inspect for missing values. Below, we only drop rows that are missing either the `year` or `content_rating`.

# %%
movie.dropna(subset=['year', 'content_rating']).shape
# Out:
# (4552, 21)

# %% [markdown]
# Another option for `dropna` is setting the minimum threshold for non-missing values in each row. Our current DataFrame has 21 columns. Below, we use the `thresh` parameter to ensure that each row has at least 18 non-missing values.
# Useful for dropping incomplete rows according to a minimum amount of completeness.

# %%
movie.dropna(thresh=18).shape
# Out:
# (4767, 21)

# %% [markdown]
# ### Drop columns with missing values
#
# Just like we did with the statistical methods, we can change the direction of the operation for `dropna`, and drop columns instead of rows by setting the `axis` parameter to the string 'columns' or the integer 1. Let's drop all columns that have 1 or more missing values. Only three columns have no missing values.

# %%
movie.dropna(axis=1).head()
# Out:
#                                                                      genres  \
# title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                             num_voted_users  imdb_score
# title
# Avatar                                               886204         7.9
# Pirates of the Caribbean: At World's End             471220         7.1
# Spectre                                              275868         6.8
# The Dark Knight Rises                               1144337         8.5
# Star Wars: Episode VII - The Force Awakens                8         7.1

# %% [markdown]
# The `subset` parameter is available when dropping columns and can be given a list of index labels to limit the rows to look for missing values. The `thresh` parameter can be set as an integer to represent the minimum number of non-missing values in a particular column in order to be kept in the result. Here we drop all of the columns that don't have at least 4,800 non-missing values.

# %%
movie.dropna(axis=1, thresh=4800).shape
# Out:
# (4916, 17)

# %% [markdown]
# ## Filling missing values with the `fillna` method
#
# The `fillna` method fills missing values in your DataFrame in a similar fashion as it does with a Series.
#
# ### Filling the missing values with a given constant
#
# The most basic way to use the `fillna` method is to pass it a single value which replaces every missing value with this constant. The following replaces all missing values with the string 'FILLED'. Note, that this replaces all missing value representations - `NaN`, `NaT`, `NA`, and `None`. We only output the fifth row as it was the only one of the first five to contain missing values.

# %%
movie.fillna('FILLED').iloc[4:5, :]
# Out:
#                                               year   color content_rating  \
# title
# Star Wars: Episode VII - The Force Awakens  FILLED  FILLED         FILLED
#
#                                            duration director_name director_fb  \
# title
# Star Wars: Episode VII - The Force Awakens   FILLED   Doug Walker       131.0
#
#                                                  actor1 actor1_fb      actor2  \
# title
# Star Wars: Episode VII - The Force Awakens  Doug Walker     131.0  Rob Walker
#
#                                            actor2_fb  actor3 actor3_fb  \
# title
# Star Wars: Episode VII - The Force Awakens      12.0  FILLED    FILLED
#
#                                              gross       genres num_reviews  \
# title
# Star Wars: Episode VII - The Force Awakens  FILLED  Documentary      FILLED
#
#                                             num_voted_users plot_keywords  \
# title
# Star Wars: Episode VII - The Force Awakens                8        FILLED
#
#                                            language country  budget  \
# title
# Star Wars: Episode VII - The Force Awakens   FILLED  FILLED  FILLED
#
#                                             imdb_score
# title
# Star Wars: Episode VII - The Force Awakens         7.1

# %% [markdown]
# Filling a DataFrame's missing values with a single constant value may not be what you'd need in a real situation. The `movie` DataFrame has columns of different data types and by using the string 'FILLED', the data type of the numeric columns changed to object. For instance, the column `duration` was originally a float and is now an object.
#
# ### Use a dictionary to fill specific columns
#
# A more practical situation would be to fill each column with a different constant value. We can use `fillna` to do this by passing it a dictionary that maps the column name to the missing value replacement. The following fills the `content_rating` column with 'PG' and the `duration` column with 199. Missing values in other columns are not filled.

# %%
movie.fillna({'content_rating': 'PG', 'duration': 199}).iloc[4:5, :8]
# Out:
#                                             year color content_rating  \
# title
# Star Wars: Episode VII - The Force Awakens   NaN   NaN             PG
#
#                                             duration director_name  \
# title
# Star Wars: Episode VII - The Force Awakens     199.0   Doug Walker
#
#                                             director_fb       actor1  \
# title
# Star Wars: Episode VII - The Force Awakens        131.0  Doug Walker
#
#                                             actor1_fb
# title
# Star Wars: Episode VII - The Force Awakens      131.0

# %% [markdown]
# ### Fill all columns with the mean or median
#
# A somewhat common approach to filling missing values is to use the mean or median of the column as the replacement. Taking the `median` of a DataFrame returns a Series that has each column name labeling its median. A Series is also a valid object that can be passed to the `fillna` method. Let's begin by finding the median of each column.

# %%
mm = movie.median(numeric_only=True)
mm
# Out:
# year                   2005.0
# duration                103.0
# director_fb              48.0
# actor1_fb               982.0
# actor2_fb               593.0
# actor3_fb               366.0
# gross              25043962.0
# num_reviews             108.0
# num_voted_users       33132.5
# budget             19850000.0
# imdb_score                6.6
# dtype: float64

# %% [markdown]
# A pandas Series is similar to a built-in dictionary. The index labels are like keys that map to a single value. In fact, you can turn a Series into a dictionary with the `to_dict` method.

# %%
mm.to_dict()
# Out:
# {'year': 2005.0,
#  'duration': 103.0,
#  'director_fb': 48.0,
#  'actor1_fb': 982.0,
#  'actor2_fb': 593.0,
#  'actor3_fb': 366.0,
#  'gross': 25043962.0,
#  'num_reviews': 108.0,
#  'num_voted_users': 33132.5,
#  'budget': 19850000.0,
#  'imdb_score': 6.6}

# %% [markdown]
# Passing the Series to `fillna` uses each column's median as the replacement value. The string columns will not be filled as they do not have a median.

# %%
movie.fillna(mm).iloc[4:5]

# %% [markdown]
# ### Filling missing values with the preceding or following values
#
# Instead of filling missing values with a constant, you can fill in missing values with the immediately preceding or following known value. Let's use a simple csv to clearly see how this done.

# %%
df = pd.read_csv('../data/missing_example.csv')
df
# Out:
#        day  orders  sales
# 0   Monday     NaN  21.43
# 1      NaN     5.0    NaN
# 2      NaN    10.0    NaN
# 3  Tuesday     NaN    NaN
# 4      NaN     3.0    NaN

# %% [markdown]
# The `method` parameter controls whether you are going to fill in the missing values with the immediate preceding or following value. Set it equal to the string `'ffill'` to fill missing values going 'forward', i.e. using the immediate preceding value.

# %%
df.fillna(method='ffill')
# Out:
#        day  orders  sales
# 0   Monday     NaN  21.43
# 1   Monday     5.0  21.43
# 2   Monday    10.0  21.43
# 3  Tuesday    10.0  21.43
# 4  Tuesday     3.0  21.43

# %% [markdown]
# Notice that the first value for the `orders` column is still missing as there is no immediate preceding value to fill it with. Use the string 'bfill' to fill missing values going backwards.

# %%
df.fillna(method='bfill')
# Out:
#        day  orders  sales
# 0   Monday     5.0  21.43
# 1  Tuesday     5.0    NaN
# 2  Tuesday    10.0    NaN
# 3  Tuesday     3.0    NaN
# 4      NaN     3.0    NaN

# %% [markdown]
# You can limit the number of consecutive values filled with the `limit` parameter. Here we limit the number filled to only 1.

# %%
df.fillna(method='ffill', limit=1)
# Out:
#        day  orders  sales
# 0   Monday     NaN  21.43
# 1   Monday     5.0  21.43
# 2      NaN    10.0    NaN
# 3  Tuesday    10.0    NaN
# 4  Tuesday     3.0    NaN

# %% [markdown]
# When you use `fillna`, you must choose between filling with a constant, demonstrated by the first example, or by forward or backfilling with the `method` parameter, shown in the second example.
#
# ## The `interpolate` method
#
# The `interpolate` method was covered extensively in the Series part. It works the same with DataFrames and fills in missing values using a variety of statistical methods. By default, it uses linear interpolation on every column in the DataFrame. Let's read a small sample of stock price data for Microsoft, Apple, and Schlumberger with several missing values.

# %%
df_stocks = pd.read_csv('../data/stocks/sample_missing.csv')
df_stocks
# Out:
#          date    MSFT    AAPL    SLB
# 0  2019-10-08  135.67  224.40  30.71
# 1  2019-10-09     NaN     NaN    NaN
# 2  2019-10-10  139.10  230.09  31.07
# 3  2019-10-11     NaN     NaN    NaN
# 4  2019-10-14     NaN     NaN    NaN
# 5  2019-10-15  141.57  235.32  32.81
# 6  2019-10-16     NaN     NaN    NaN
# 7  2019-10-17     NaN     NaN    NaN
# 8  2019-10-18  137.41  236.41  32.31
# 9  2019-10-21     NaN     NaN    NaN

# %% [markdown]
# Let's use linear interpolation to fill in the missing values of each column.

# %%
df_stocks.interpolate('linear')
# Out:
#          date        MSFT        AAPL        SLB
# 0  2019-10-08  135.670000  224.400000  30.710000
# 1  2019-10-09  137.385000  227.245000  30.890000
# 2  2019-10-10  139.100000  230.090000  31.070000
# 3  2019-10-11  139.923333  231.833333  31.650000
# 4  2019-10-14  140.746667  233.576667  32.230000
# 5  2019-10-15  141.570000  235.320000  32.810000
# 6  2019-10-16  140.183333  235.683333  32.643333
# 7  2019-10-17  138.796667  236.046667  32.476667
# 8  2019-10-18  137.410000  236.410000  32.310000
# 9  2019-10-21  137.410000  236.410000  32.310000

# %% [markdown]
# Here, we use quadratic interpolation and place a limit on the number of consecutive missing values filled.

# %%
df_stocks.interpolate('quadratic', limit=1)
# Out:
#          date        MSFT        AAPL        SLB
# 0  2019-10-08  135.670000  224.400000  30.710000
# 1  2019-10-09  137.524023  227.463333  30.767701
# 2  2019-10-10  139.100000  230.090000  31.070000
# 3  2019-10-11  140.397931  232.280000  31.616897
# 4  2019-10-14         NaN         NaN        NaN
# 5  2019-10-15  141.570000  235.320000  32.810000
# 6  2019-10-16  140.985517  236.146667  32.962720
# 7  2019-10-17         NaN         NaN        NaN
# 8  2019-10-18  137.410000  236.410000  32.310000
# 9  2019-10-21         NaN         NaN        NaN

# %% [markdown]
# ## Exercises
#
# Execute the next cell to read in the college dataset with the institution name as the index and use it for the first few exercises.

# %%
college = pd.read_csv('../data/college.csv', index_col = 'instnm')
college.head(3)
# Out:
#                                            city stabbr  hbcu  menonly  \
# instnm
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
#
#                                      womenonly  relaffil  satvrmid  satmtmid  \
# instnm
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
#
#                                      distanceonly     ugds  ugds_white  \
# instnm
# Alabama A & M University                      0.0   4206.0      0.0333
# University of Alabama at Birmingham           0.0  11383.0      0.5922
# Amridge University                            1.0    291.0      0.2990
#
#                                      ugds_black  ugds_hisp  ugds_asian  \
# instnm
# Alabama A & M University                 0.9353     0.0055      0.0019
# University of Alabama at Birmingham      0.2600     0.0283      0.0518
# Amridge University                       0.4192     0.0069      0.0034
#
#                                      ugds_aian  ugds_nhpi  ugds_2mor  \
# instnm
# Alabama A & M University                0.0024     0.0019     0.0000
# University of Alabama at Birmingham     0.0022     0.0007     0.0368
# Amridge University                      0.0000     0.0000     0.0000
#
#                                      ugds_nra  ugds_unkn  pptug_ef  curroper  \
# instnm
# Alabama A & M University               0.0059     0.0138    0.0656         1
# University of Alabama at Birmingham    0.0179     0.0100    0.2607         1
# Amridge University                     0.0000     0.2715    0.4536         1
#
#                                      pctpell  pctfloan  ug25abv  \
# instnm
# Alabama A & M University              0.7356    0.8284   0.1049
# University of Alabama at Birmingham   0.3460    0.5214   0.2422
# Amridge University                    0.6801    0.7795   0.8540
#
#                                     md_earn_wne_p10 grad_debt_mdn_supp
# instnm
# Alabama A & M University                      30300              33888
# University of Alabama at Birmingham           39700            21941.5
# Amridge University                            40100              23370

# %% [markdown]
# The data dictionary is helpful to decipher the meaning of the columns. Uncomment the next line to read it in.

# %%
pd.read_csv('../data/dictionaries/college_data_dictionary.csv')
# Out:
#            column_name                                        description
# 0               instnm                                   Institution Name
# 1                 city                                      City Location
# 2               stabbr                                 State Abbreviation
# 3                 hbcu           Historically Black College or University
# 4              menonly                                       0/1 Men Only
# 5            womenonly                                     0/1 Women only
# 6             relaffil                          0/1 Religious Affiliation
# 7             satvrmid                                  SAT Verbal Median
# 8             satmtmid                                    SAT Math Median
# 9         distanceonly                            Distance Education Only
# 10                ugds                           Undergraduate Enrollment
# 11          ugds_white                            Percent Undergrad White
# 12          ugds_black                            Percent Undergrad Black
# 13           ugds_hisp                         Percent Undergrad Hispanic
# 14          ugds_asian                            Percent Undergrad Asian
# 15           ugds_aian   Percent Undergrad American Indian/Alaskan Native
# 16           ugds_nhpi  Percent Undergrad Native Hawaiian/Pacific Isla...
# 17           ugds_2mor                  Percent Undergrad 2 or more races
# 18            ugds_nra              Percent Undergrad non-resident aliens
# 19           ugds_unkn                     Percent Undergrad race unknown
# 20            pptug_ef                         Percent Students part-time
# 21            curroper                            0/1 Currently Operating
# 22             pctpell                   Percent Students with Pell grant
# 23            pctfloan                 Percent Students with federal loan
# 24             ug25abv                     Percent Students Older than 25
# 25     md_earn_wne_p10          Median Earnings 10 years after enrollment
# 26  grad_debt_mdn_supp                          Median debt of completers

# %% [markdown]
# ### Exercise 1
#
# <span  style="color:green; font-size:16px">Find the number of missing values for each row.</span>

# %%
college.isna().sum(axis = 1)
# Out:
# instnm
# Alabama A & M University                                   0
# University of Alabama at Birmingham                        0
# Amridge University                                         2
# University of Alabama in Huntsville                        0
# Alabama State University                                   0
#                                                           ..
# SAE Institute of Technology  San Francisco                21
# Rasmussen College - Overland Park                         21
# National Personal Training Institute of Cleveland         21
# Bay Area Medical Academy - San Jose Satellite Location    21
# Excel Learning Center-San Antonio South                   21
# Length: 7535, dtype: int64

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">What percentage of rows have more than 5 missing values?</span>

# %% [markdown]
# Number of rows w/ 5+ missing values (axis = 1 sum of isna)
# ___
# Number of total rows

# %%
len(college)
# Out:
# 7535

# %%
num_missing = college.isna().sum(axis = 1)
num_missing
# Out:
# instnm
# Alabama A & M University                                   0
# University of Alabama at Birmingham                        0
# Amridge University                                         2
# University of Alabama in Huntsville                        0
# Alabama State University                                   0
#                                                           ..
# SAE Institute of Technology  San Francisco                21
# Rasmussen College - Overland Park                         21
# National Personal Training Institute of Cleveland         21
# Bay Area Medical Academy - San Jose Satellite Location    21
# Excel Learning Center-San Antonio South                   21
# Length: 7535, dtype: int64

# %%
fives = num_missing[num_missing > 5]
len(fives)/ len(college)
# Out:
# 0.09011280690112806

# %% [markdown]
# ### Exercise 3
#
# <span  style="color:green; font-size:16px">How many total missing values are there in the entire DataFrame?</span>

# %%
college.isna().values.sum()
# Out:
# 24808

# %% [markdown]
# ### Exercise 5
#
# <span  style="color:green; font-size:16px">How many rows will be dropped when the `dropna` method is called with its defaults. Calculate this number without calling the `dropna` method.</span>

# %%
len(college) - len(college.dropna())
# Out:
# 6364

# %% [markdown]
# Mark each row with T/F for if it contains at least one missing value in it's columns
#
# OR, Sum # of NA cols per row
# Subset DF for rows >=1
# Len of subset DF

# %%
sum_nas = college.isna().sum(axis = 1)
len(sum_nas[sum_nas >=1])
# Out:
# 6364

# %% [markdown]
# ### Exercise 6
#
# <span  style="color:green; font-size:16px">Verify the result from exercise 5 by calling the `dropna` method.</span>

# %% [markdown]
# ### Exercise 7
#
# <span  style="color:green; font-size:16px">Drop all the rows that are missing the `ugds` column.</span>

# %%
college.dropna(subset = 'ugds')
# Out:
#                                                                city stabbr  \
# instnm
# Alabama A & M University                                     Normal     AL
# University of Alabama at Birmingham                      Birmingham     AL
# Amridge University                                       Montgomery     AL
# University of Alabama in Huntsville                      Huntsville     AL
# Alabama State University                                 Montgomery     AL
# ...                                                             ...    ...
# Hollywood Institute of Beauty Careers-West Palm...  West Palm Beach     FL
# Hollywood Institute of Beauty Careers-Casselberry       Casselberry     FL
# Coachella Valley Beauty College-Beaumont                   Beaumont     CA
# Dewey University-Mayaguez                                  Mayaguez     PR
# Coastal Pines Technical College                            Waycross     GA
#
#                                                     hbcu  menonly  womenonly  \
# instnm
# Alabama A & M University                             1.0      0.0        0.0
# University of Alabama at Birmingham                  0.0      0.0        0.0
# Amridge University                                   0.0      0.0        0.0
# University of Alabama in Huntsville                  0.0      0.0        0.0
# Alabama State University                             1.0      0.0        0.0
# ...                                                  ...      ...        ...
# Hollywood Institute of Beauty Careers-West Palm...   0.0      0.0        0.0
# Hollywood Institute of Beauty Careers-Casselberry    0.0      0.0        0.0
# Coachella Valley Beauty College-Beaumont             0.0      0.0        0.0
# Dewey University-Mayaguez                            0.0      0.0        0.0
# Coastal Pines Technical College                      0.0      0.0        0.0
#
#                                                     relaffil  satvrmid  \
# instnm
# Alabama A & M University                                   0     424.0
# University of Alabama at Birmingham                        0     570.0
# Amridge University                                         1       NaN
# University of Alabama in Huntsville                        0     595.0
# Alabama State University                                   0     425.0
# ...                                                      ...       ...
# Hollywood Institute of Beauty Careers-West Palm...         0       NaN
# Hollywood Institute of Beauty Careers-Casselberry          0       NaN
# Coachella Valley Beauty College-Beaumont                   0       NaN
# Dewey University-Mayaguez                                  0       NaN
# Coastal Pines Technical College                            0       NaN
#
#                                                     satmtmid  distanceonly  \
# instnm
# Alabama A & M University                               420.0           0.0
# University of Alabama at Birmingham                    565.0           0.0
# Amridge University                                       NaN           1.0
# University of Alabama in Huntsville                    590.0           0.0
# Alabama State University                               430.0           0.0
# ...                                                      ...           ...
# Hollywood Institute of Beauty Careers-West Palm...       NaN           0.0
# Hollywood Institute of Beauty Careers-Casselberry        NaN           0.0
# Coachella Valley Beauty College-Beaumont                 NaN           0.0
# Dewey University-Mayaguez                                NaN           0.0
# Coastal Pines Technical College                          NaN           0.0
#
#                                                        ugds  ugds_white  \
# instnm
# Alabama A & M University                             4206.0      0.0333
# University of Alabama at Birmingham                 11383.0      0.5922
# Amridge University                                    291.0      0.2990
# University of Alabama in Huntsville                  5451.0      0.6988
# Alabama State University                             4811.0      0.0158
# ...                                                     ...         ...
# Hollywood Institute of Beauty Careers-West Palm...     55.0      0.2182
# Hollywood Institute of Beauty Careers-Casselberry      75.0      0.1200
# Coachella Valley Beauty College-Beaumont               67.0      0.3284
# Dewey University-Mayaguez                              94.0      0.0000
# Coastal Pines Technical College                      1782.0      0.6762
#
#                                                     ugds_black  ugds_hisp  \
# instnm
# Alabama A & M University                                0.9353     0.0055
# University of Alabama at Birmingham                     0.2600     0.0283
# Amridge University                                      0.4192     0.0069
# University of Alabama in Huntsville                     0.1255     0.0382
# Alabama State University                                0.9208     0.0121
# ...                                                        ...        ...
# Hollywood Institute of Beauty Careers-West Palm...      0.4182     0.2364
# Hollywood Institute of Beauty Careers-Casselberry       0.3333     0.4400
# Coachella Valley Beauty College-Beaumont                0.1045     0.4925
# Dewey University-Mayaguez                               0.0000     1.0000
# Coastal Pines Technical College                         0.2508     0.0359
#
#                                                     ugds_asian  ugds_aian  \
# instnm
# Alabama A & M University                                0.0019     0.0024
# University of Alabama at Birmingham                     0.0518     0.0022
# Amridge University                                      0.0034     0.0000
# University of Alabama in Huntsville                     0.0376     0.0143
# Alabama State University                                0.0019     0.0010
# ...                                                        ...        ...
# Hollywood Institute of Beauty Careers-West Palm...      0.0182     0.0000
# Hollywood Institute of Beauty Careers-Casselberry       0.0000     0.0000
# Coachella Valley Beauty College-Beaumont                0.0149     0.0299
# Dewey University-Mayaguez                               0.0000     0.0000
# Coastal Pines Technical College                         0.0045     0.0034
#
#                                                     ugds_nhpi  ugds_2mor  \
# instnm
# Alabama A & M University                               0.0019     0.0000
# University of Alabama at Birmingham                    0.0007     0.0368
# Amridge University                                     0.0000     0.0000
# University of Alabama in Huntsville                    0.0002     0.0172
# Alabama State University                               0.0006     0.0098
# ...                                                       ...        ...
# Hollywood Institute of Beauty Careers-West Palm...     0.0000     0.0000
# Hollywood Institute of Beauty Careers-Casselberry      0.0000     0.0400
# Coachella Valley Beauty College-Beaumont               0.0149     0.0149
# Dewey University-Mayaguez                              0.0000     0.0000
# Coastal Pines Technical College                        0.0017     0.0191
#
#                                                     ugds_nra  ugds_unkn  \
# instnm
# Alabama A & M University                              0.0059     0.0138
# University of Alabama at Birmingham                   0.0179     0.0100
# Amridge University                                    0.0000     0.2715
# University of Alabama in Huntsville                   0.0332     0.0350
# Alabama State University                              0.0243     0.0137
# ...                                                      ...        ...
# Hollywood Institute of Beauty Careers-West Palm...    0.0182     0.0909
# Hollywood Institute of Beauty Careers-Casselberry     0.0000     0.0667
# Coachella Valley Beauty College-Beaumont              0.0000     0.0000
# Dewey University-Mayaguez                             0.0000     0.0000
# Coastal Pines Technical College                       0.0028     0.0056
#
#                                                     pptug_ef  curroper  \
# instnm
# Alabama A & M University                              0.0656         1
# University of Alabama at Birmingham                   0.2607         1
# Amridge University                                    0.4536         1
# University of Alabama in Huntsville                   0.2146         1
# Alabama State University                              0.0892         1
# ...                                                      ...       ...
# Hollywood Institute of Beauty Careers-West Palm...    0.0000         1
# Hollywood Institute of Beauty Careers-Casselberry     0.0000         1
# Coachella Valley Beauty College-Beaumont              0.0000         1
# Dewey University-Mayaguez                             0.2128         1
# Coastal Pines Technical College                       0.6908         1
#
#                                                     pctpell  pctfloan  \
# instnm
# Alabama A & M University                             0.7356    0.8284
# University of Alabama at Birmingham                  0.3460    0.5214
# Amridge University                                   0.6801    0.7795
# University of Alabama in Huntsville                  0.3072    0.4596
# Alabama State University                             0.7347    0.7554
# ...                                                     ...       ...
# Hollywood Institute of Beauty Careers-West Palm...   0.8248    0.8759
# Hollywood Institute of Beauty Careers-Casselberry    0.6802    0.6802
# Coachella Valley Beauty College-Beaumont             0.8148    0.5432
# Dewey University-Mayaguez                            0.9615    0.0000
# Coastal Pines Technical College                      0.6540    0.0000
#
#                                                     ug25abv md_earn_wne_p10  \
# instnm
# Alabama A & M University                             0.1049           30300
# University of Alabama at Birmingham                  0.2422           39700
# Amridge University                                   0.8540           40100
# University of Alabama in Huntsville                  0.2640           45500
# Alabama State University                             0.1270           26600
# ...                                                     ...             ...
# Hollywood Institute of Beauty Careers-West Palm...      NaN             NaN
# Hollywood Institute of Beauty Careers-Casselberry       NaN             NaN
# Coachella Valley Beauty College-Beaumont                NaN             NaN
# Dewey University-Mayaguez                               NaN             NaN
# Coastal Pines Technical College                         NaN             NaN
#
#                                                    grad_debt_mdn_supp
# instnm
# Alabama A & M University                                        33888
# University of Alabama at Birmingham                           21941.5
# Amridge University                                              23370
# University of Alabama in Huntsville                             24097
# Alabama State University                                      33118.5
# ...                                                               ...
# Hollywood Institute of Beauty Careers-West Palm...               7735
# Hollywood Institute of Beauty Careers-Casselberry                7735
# Coachella Valley Beauty College-Beaumont                         2170
# Dewey University-Mayaguez                           PrivacySuppressed
# Coastal Pines Technical College                     PrivacySuppressed
#
# [6874 rows x 26 columns]

# %% [markdown]
# ### Exercise 8
#
# <span style="color:green; font-size:16px">Drop all columns that have more than 5% of their values missing.</span>
#
# Calculate % missing (using isna and taking mean)
# Create bool filter
# Dropna using filter

# %%
missing = college.isna().mean(axis = 1)

# %%
filt = missing[missing > 0.05]
filt.head(3)
# Out:
# instnm
# Amridge University                   0.076923
# Central Alabama Community College    0.076923
# Athens State University              0.076923
# dtype: float64

# %%
missing.head(3)
# Out:
# instnm
# Alabama A & M University               0.000000
# University of Alabama at Birmingham    0.000000
# Amridge University                     0.076923
# dtype: float64

# %%
college.dropna(subset = filt.to_list())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 college.dropna(subset = filt.to_list())
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/frame.py:6561, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6559     check = indices == -1
#    6560     if check.any():
# -> 6561         raise KeyError(np.array(subset)[check].tolist())
#    6562     agg_obj = self.take(indices, axis=agg_axis)
#    6564 if thresh is not no_default:
#
# KeyError: [0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.11538461538461539, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.11538461538461539, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.11538461538461539, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.6153846153846154, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.11538461538461539, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.6538461538461539, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.6538461538461539, 0.6538461538461539, 0.07692307692307693, 0.07692307692307693, 0.23076923076923078, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.6538461538461539, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.6153846153846154, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.07692307692307693, 0.6153846153846154, 0.23076923076923078, 0.07692307692307693, 0.0769 ...

# %% [markdown]
# ### Exercise 9
#
# <span style="color:green; font-size:16px">Fill in the missing values with the maximum value of each numeric column.</span>

# %%
college.fillna(college.max(numeric))
