# %% [markdown]
# # Boolean Selection Single Conditions
#
# **Boolean Selection**, also referred to as **boolean indexing**, is the process of selecting subsets of rows from DataFrames (or Series) based on the actual **values** and NOT by labels or integer locations. All of the previous subset selections were done using either labels or integer location. Those selections had nothing to do with the actual values.
#
# ### Examples of boolean selection
#
# Let's see some examples of actual questions (in plain English) that boolean selection can help us answer from the bikes dataset. The term **query** is used to refer to these sorts of questions.
#
# * Find all rides by males
# * Find all rides with a duration longer than 2 hours
# * Find all rides that took place between March and June of 2015
# * Find all rides with a duration longer than 2 hours by females with temperature higher than 90 degrees
#
# ### All queries have a logical condition
#
# Each of the above queries have a strict logical condition that must be checked one row at a time.
#
# ### Keep or discard an entire row of data
#
# If you were to manually answer the above queries, you would need to scan each row and determine whether the row, as a whole, meets the condition. If so, then it is kept in the result, otherwise it is discarded.
#
# ### Each row will have a True or False value associated with it
#
# When you perform boolean selection, each row of the DataFrame (or value of a Series) has a `True` or `False` value associated with it corresponding to the outcome of the logical condition.
#
# ### Begin with a small DataFrame
#
# Let's perform our first boolean selection on our sample DataFrame. Let's read it in now.

# %%
import pandas as pd
df = pd.read_csv('../data/sample_data.csv', index_col=0)
df
# Out:
#           state  color    food  age  height  score
# name
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %% [markdown]
# ## Manually filtering the data
#
# Let's find all the people who are younger than 30 years of age. We will do this manually by inspecting the data.
#
# ### Create a list of booleans
#
# By inspecting the data, we see that `Niko`, `Aaron`, and `Penelope` are all under 30 years of age. To signify which people are under 30, we create a list of 7 boolean values corresponding to the 7 rows in the DataFrame. The values in the list that correspond with the positions of `Niko`, `Aaron`, and `Penelope` are `True`. All other values are `False`. `Niko`, `Aaron`, and `Penelope` are the 2nd, 3rd, and 4th rows, so these are the locations in the list that are `True`.

# %%
filt = [False, True, True, True, False, False, False]

# %% [markdown]
# ### Variable name `filt`
#
# The variable name `filt` will be used throughout the book to refer to the sequence of booleans. You are free to use any variable name you like for the sequence of booleans, but being consistent makes your code easier to understand. I chose `filt` because it is short for the word 'filter'. Boolean selection filters the data for a particular condition, which is why this variable name makes sense to me.
#
# ### Place this list in just the brackets
#
# The above list has `True` in the 2nd, 3rd, and 4th positions. These will be the rows that are kept in the resulting boolean selection. Place the list inside *just the brackets* to complete the selection.

# %%
df[filt]
# Out:
#          state  color   food  age  height  score
# name
# Niko        TX  green   Lamb    2      70    8.3
# Aaron       FL    red  Mango   12     120    9.0
# Penelope    AL  white  Apple    4      80    3.3

# %% [markdown]
# ### Wait a second… Isn’t `[ ]` just for column selection?
#
# The primary purpose of *just the brackets* for a DataFrame is to select one or more columns by using either a string or a list of strings. All of a sudden, this example shows entire rows being selected with boolean values. This is what makes pandas, unfortunately, a confusing library to learn and use.
#
# ## Operator overloading
#
# *Just the brackets* is **overloaded**. Depending on the inputs, pandas will do something completely different. Here are the rules for the different objects passed to *just the brackets*.
#
# * **string** — return a column as a Series
# * **list of strings** — return all those column names as a DataFrame
# * **sequence of booleans** — select all rows where `True`
#
# In summary, *just the brackets* primarily selects columns, but, if you pass it a sequence of booleans, it will select all rows that are `True`.

# %% [markdown]
# ## Practical boolean selection
#
# We almost never create boolean lists manually like we did above and instead use the actual data to create boolean Series.
#
# ### Creating boolean Series from column data
#
# By far the most common way to create a boolean Series is from the values of one particular column. We test a condition using one of the six comparison operators:
#
# * `<`
# * `<=`
# * `>`
# * `>=`
# * `==`
# * `!=`
#
# Let's begin completing practical boolean selection examples by reading in the bikes dataset.

# %%
bikes = pd.read_csv('../data/bikes.csv')
bikes.head(3)
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
#
#               from_station_name  start_capacity          to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 2          23.0         73.0        16.1  mostlycloudy

# %% [markdown]
# ### Create a boolean Series
#
# Let's create a boolean Series by determining which rows have a trip duration greater than 1,000 seconds. To make the comparison, we select the `tripduration` column as a Series and compare it against the integer 1,000.

# %%
filt = bikes['column'] < 1000 #df['colname']followed by boolean logic

# %%
filt = bikes['tripduration'] > 1000
filt.head(3)
# Out:
# 0    False
# 1    False
# 2     True
# Name: tripduration, dtype: bool

# %% [markdown]
# When we write `bikes['tripduration'] > 1000`, pandas compares each value in the `tripduration` column against 1,000. It returns a new Series the same length as `tripduartion` with boolean values corresponding to the outcome of the comparison. Let's verify that the `filt` Series is the same length as the DataFrame.

# %%
len(filt)
# Out:
# 50089

# %%
len(bikes)
# Out:
# 50089

# %% [markdown]
# ### Manually verify correctness
#
# Take a look at the `tripduration` column to manually verify that only the third row satisfied the condition. That ride lasted 1,040 seconds which is greater than 1,000 resulting in a value of `True`. The first two rides lasted less than 1,000 seconds and resulting with `False`.
#
# ### Complete the boolean selection
#
# We can now place the `filt` boolean Series into *just the brackets* to filter the entire DataFrame. This returns all the rows in the bikes dataset that have a trip duration greater than 1,000. Manually verify that the `tripduration` values on the screen are greater than 1,000.

# %%
bikes[filt].head(3)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 2    Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 8    Male  2013-07-03 15:21:00  2013-07-03 15:42:00          1300
# 10   Male  2013-07-04 17:17:00  2013-07-04 17:42:00          1523
#
#                from_station_name  start_capacity          to_station_name  \
# 2   Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 8   Clinton St & Washington Blvd            31.0    Wood St & Division St
# 10           Morgan St & 18th St            15.0   Damen Ave & Pierce Ave
#
#     end_capacity  temperature  wind_speed        events
# 2           23.0         73.0        16.1  mostlycloudy
# 8           15.0         71.1         0.0        cloudy
# 10          19.0         79.0         9.2  mostlycloudy

# %% [markdown]
# ### How many rows have a trip duration greater than 1000?
#
# To answer this question, let's assign the result of the boolean selection to a variable, and then compare the number of rows between it and the original DataFrame.

# %%
bikes_duration_1000 = bikes[filt]

# %% [markdown]
# Let's find the number of rows in each DataFrame.

# %%
len(bikes)
# Out:
# 50089

# %%
len(bikes_duration_1000)
# Out:
# 10178

# %% [markdown]
# We compute that 20% of the rides are longer than 1,000 seconds.

# %%
len(bikes_duration_1000) / len(bikes)
# Out:
# 0.20319830701351593

# %% [markdown]
# ## Boolean selection in one line
#
# Often, you will see boolean selection completed in a single line of code instead of the two lines we used above. The expression for the filter is placed directly within *just the brackets*. Although this method will save a line of code, I recommend assigning the filter as a separate variable to help with readability.

# %%
bikes[bikes['tripduration'] > 1000].head(3)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 2    Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 8    Male  2013-07-03 15:21:00  2013-07-03 15:42:00          1300
# 10   Male  2013-07-04 17:17:00  2013-07-04 17:42:00          1523
#
#                from_station_name  start_capacity          to_station_name  \
# 2   Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 8   Clinton St & Washington Blvd            31.0    Wood St & Division St
# 10           Morgan St & 18th St            15.0   Damen Ave & Pierce Ave
#
#     end_capacity  temperature  wind_speed        events
# 2           23.0         73.0        16.1  mostlycloudy
# 8           15.0         71.1         0.0        cloudy
# 10          19.0         79.0         9.2  mostlycloudy

# %% [markdown]
# ## Single condition expression
#
# Our first example tested a single condition (whether the trip duration was 1,000 or more). Let's test a different single condition and find all the rides that left from station State St & Van Buren St. We use the `==` operator to test for equality and again pass this variable to *just the brackets* which completes our selection.

# %%
filt = bikes['from_station_name'] == 'State St & Van Buren St'
bikes[filt].head(3)
# Out:
#     gender            starttime             stoptime  tripduration  \
# 7     Male  2013-07-03 09:07:00  2013-07-03 09:16:00           505
# 20  Female  2013-07-09 17:39:00  2013-07-09 17:55:00           943
# 55    Male  2013-07-16 15:31:00  2013-07-16 15:37:00           363
#
#           from_station_name  start_capacity             to_station_name  \
# 7   State St & Van Buren St            27.0  Franklin St & Jackson Blvd
# 20  State St & Van Buren St            27.0          State St & 16th St
# 55  State St & Van Buren St            27.0          Daley Center Plaza
#
#     end_capacity  temperature  wind_speed        events
# 7           27.0         64.0         5.8        cloudy
# 20          15.0         82.9         9.2  mostlycloudy
# 55          47.0         91.0         8.1  mostlycloudy

# %% [markdown]
# ## Summary of single condition boolean selection
#
# Boolean selection refers to the act of filtering data based on the values, and not on the labels or integer location. There are two main steps to do boolean selection:
#
# 1. Create a boolean Series - commonly done by comparing one column of data to another value
# 2. Place the boolean Series inside *just the brackets* to filter the data

# %% [markdown]
# ## Exercises
#
# Continue to use the bikes dataset for the first few exercises.

# %% [markdown]
# ### Exercise 1
#
# <span  style="color:green; font-size:16px">Find all the rides with temperature below 0.</span>

# %%
bikes.head()
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 3   Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
# 4   Male  2013-07-01 11:16:00  2013-07-01 11:18:00           130
#
#               from_station_name  start_capacity          to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 3       Carpenter St & Huron St            19.0   Clark St & Randolph St
# 4        Damen Ave & Pierce Ave            19.0   Damen Ave & Pierce Ave
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 2          23.0         73.0        16.1  mostlycloudy
# 3          31.0         72.0        16.1  mostlycloudy
# 4          19.0         73.0        17.3  partlycloudy

# %%
filt_temp = bikes['temperature'] < 0

bikes[filt_temp]
# Out:
#        gender            starttime             stoptime  tripduration  \
# 1871     Male  2013-12-12 05:13:00  2013-12-12 05:27:00           878
# 2049   Female  2014-01-23 06:15:00  2014-01-23 06:29:00           828
# 2054     Male  2014-01-23 21:15:00  2014-01-23 21:21:00           351
# 2062     Male  2014-01-27 17:07:00  2014-01-27 17:11:00           242
# 2063     Male  2014-01-27 17:19:00  2014-01-27 17:24:00           304
# 2064     Male  2014-01-28 08:03:00  2014-01-28 08:12:00           546
# 2117     Male  2014-02-12 01:21:00  2014-02-12 01:40:00          1149
# 2221     Male  2014-03-03 05:58:00  2014-03-03 06:04:00           332
# 10245    Male  2015-01-05 08:33:00  2015-01-05 08:58:00          1554
#
#                     to_station_name  end_capacity  temperature  wind_speed  \
# 1871        Carpenter St & Huron St          19.0         -2.0         6.9
# 2049      Ashland Ave & Division St          19.0         -2.0        16.1
# 2054       McClurg Ct & Illinois St          31.0         -0.9        12.7
# 2062   Clinton St & Washington Blvd          31.0         -5.1        15.0
# 2063         Damen Ave & Pierce Ave          19.0         -5.1        15.0
# 2064     Franklin St & Jackson Blvd          31.0         -8.0        12.7
# 2117             May St & Fulton St          15.0         -0.9         5.8
# 2221     Franklin St & Jackson Blvd          31.0         -0.9        11.5
# 10245       Hermitage Ave & Polk St          15.0         -2.0        11.5
# 10246          State St & Kinzie St          23.0         -2.0        11.5
# 10247            May St & Fulton St          15.0         -0.9        16.1
# 10254   Sheffield Ave & Webster Ave          19.0         -0.9        19.6
# 10259    Franklin St & Jackson Blvd          31.0         -0.9        16.1
# 10260   Dearborn Pkwy & Delaware Pl          19.0         -0.9        16.1
# 10261         Union Ave & Grand Ave          19.0         -2.9        15.0
# 10262     Columbus Dr & Randolph St          31.0         -6.0        12.7
# 10263       Franklin St & Arcade Pl          27.0         -2.9        17.3
# 10264        Clark St & Randolph St          31.0         -2.9        17.3
# 10265       Dearborn St & Monroe St          27.0         -2.0        15.0
# 10631     Larrabee St & Webster Ave          15.0         -5.1        17.3
# 21774     Columbus Dr & Randolph St          31.0         -4.0        15.0
# 27168       Avers Ave & Belmont Ave          19.0      -9999.0     -9999.0
# 35037        Damen Ave & Leland Ave          15.0         -2.0        11.5
# 35072    Francisco Ave & Foster Ave          15.0         -2.9        12.7
# 35073        Kingsbury St & Erie St          23.0         -8.0         6.9
# 35074  Marshfield Ave & Cortland St          23.0         -6.0         8.1
# 35075  Desplaines St & Jackson Blvd          23.0         -0.9        12.7
# 50067        Michigan Ave & 14th St          19.0         -2.9        11.5
# 50068   Dearborn Pkwy & Delaware Pl          19.0         -2.9         8.1
# 50069      Fairbanks Ct & Grand Ave          15.0         -0.9         8.1
#
#              events
# 1871   mostlycloudy
# 2049   partlycloudy
# 2054          clear
# 2062   partlycloudy
# 2063   partlycloudy
# 2064          clear
# 2117          clear
# 2221   partlycloudy
# 10245  partlycloudy
# 10246  partlycloudy
# 10247  partlycloudy
# 10254  partlycloudy
# 10259  partlycloudy
# 10260  partlycloudy
# 10261  partlycloudy
# 10262        cloudy
# 10263        cloudy
# 10264        cloudy
# 10265        cloudy
# 10631  partlycloudy
# 21774  partlycloudy
# 27168       unknown
# 35037  mostlycloudy
# 35072  partlycloudy
# 35073         clear
# 35074  partlycloudy
# 35075  partlycloudy
# 50067  partlycloudy
# 50068  partlycloudy
# 50069  partlycloudy

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">Find all the rides with wind speed greater than 30.</span>

# %%
filt_wind = bikes['wind_speed'] > 30
bikes[filt_wind].head()
# Out:
#       gender            starttime             stoptime  tripduration  \
# 2164    Male  2014-02-20 19:06:00  2014-02-20 19:07:00            66
# 2165    Male  2014-02-20 20:47:00  2014-02-20 21:14:00          1605
# 2479    Male  2014-04-01 08:28:00  2014-04-01 08:29:00            82
# 2680  Female  2014-04-12 15:46:00  2014-04-12 15:54:00           487
# 4265  Female  2014-06-15 13:17:00  2014-06-15 13:29:00           713
#
#                    from_station_name  start_capacity  \
# 2164   Pine Grove Ave & Waveland Ave            23.0
# 2165                 Millennium Park            35.0
# 2479       Desplaines St & Kinzie St            19.0
# 2680       Western Ave & Division St            15.0
# 4265  Sheffield Ave & Wellington Ave            23.0
#
#                     to_station_name  end_capacity  temperature  wind_speed  \
# 2164  Pine Grove Ave & Waveland Ave          23.0         46.9        31.1
# 2165      Clark St & Wrightwood Ave          15.0         39.0        35.7
# 2479      Desplaines St & Kinzie St          19.0         33.1        31.1
# 2680        Damen Ave & Chicago Ave          15.0         79.0        31.1
# 4265    Lake Shore Dr & Belmont Ave          19.0         82.0        31.1
#
#             events
# 2164  mostlycloudy
# 2165        cloudy
# 2479  mostlycloudy
# 2680  mostlycloudy
# 4265  mostlycloudy

# %% [markdown]
# ### Exercise 3
#
# <span  style="color:green; font-size:16px">Find all the rides that began from station 'Millennium Park'.</span>

# %%
filt_start = bikes['from_station_name'] == 'Millennium Park'
bikes[filt_start].head()
# Out:
#      gender            starttime             stoptime  tripduration  \
# 32     Male  2013-07-12 15:10:00  2013-07-12 15:24:00           888
# 42     Male  2013-07-15 08:17:00  2013-07-15 08:25:00           466
# 66     Male  2013-07-17 20:56:00  2013-07-17 21:14:00          1073
# 258  Female  2013-08-17 22:10:00  2013-08-17 22:53:00          2566
# 356    Male  2013-08-27 18:30:00  2013-08-27 18:36:00           373
#
#     from_station_name  start_capacity           to_station_name  end_capacity  \
# 32    Millennium Park            35.0  McClurg Ct & Illinois St          23.0
# 42    Millennium Park            35.0   Clinton St & Madison St          23.0
# 66    Millennium Park            35.0       Morgan St & 18th St          15.0
# 258   Millennium Park            35.0       Theater on the Lake          15.0
# 356   Millennium Park            35.0    Clark St & Randolph St          31.0
#
#      temperature  wind_speed        events
# 32          82.0        10.4  partlycloudy
# 42          82.0         0.0  partlycloudy
# 66          86.0         9.2  partlycloudy
# 258         69.1         5.8         clear
# 356         90.0        13.8  partlycloudy

# %% [markdown]
# ### Exercise 4
#
# <span  style="color:green; font-size:16px">Find all the rides with wind speed less than 0. How is this possible?</span>

# %%
filt2 = bikes['wind_speed'] < 0
bikes[filt2]
# Out:
#        gender            starttime             stoptime  tripduration  \
# 22990    Male  2016-03-19 10:08:00  2016-03-19 10:20:00           702
# 27168  Female  2016-06-30 11:47:00  2016-06-30 11:51:00           240
# 28368  Female  2016-07-21 21:02:29  2016-07-21 21:20:28          1079
# 29308    Male  2016-08-07 09:16:42  2016-08-07 09:22:59           377
# 29309    Male  2016-08-07 09:29:44  2016-08-07 09:41:16           693
# 29310    Male  2016-08-07 09:36:20  2016-08-07 09:48:21           722
# 38549    Male  2017-05-09 16:05:14  2017-05-09 16:26:27          1273
# 38550    Male  2017-05-09 16:12:43  2017-05-09 16:19:47           424
# 38551    Male  2017-05-09 16:46:51  2017-05-09 17:00:18           807
# 38552    Male  2017-05-09 16:57:29  2017-05-09 17:07:22           593
# 46181    Male  2017-09-14 15:07:48  2017-09-14 15:11:37           229
# 46182    Male  2017-09-14 15:18:59  2017-09-14 15:31:10           731
# 46183    Male  2017-09-14 15:28:30  2017-09-14 15:38:48           618
# 46184    Male  2017-09-14 15:31:14  2017-09-14 15:32:48            94
# 46185  Female  2017-09-14 15:38:15  2017-09-14 15:43:19           304
# 46186    Male  2017-09-14 15:46:27  2017-09-14 15:56:00           573
#
#                          from_station_name  start_capacity  \
# 22990                Wood St & Division St            15.0
# 27168            Kimball Ave & Belmont Ave            23.0
# 28368              Sedgwick St & North Ave            19.0
# 29308              Broadway & Cornelia Ave            15.0
# 29309  Mies van der Rohe Way & Chicago Ave            15.0
# 29310               Clark St & Lincoln Ave            23.0
# 38549                 Wabash Ave & 16th St            31.0
# 38550            Michigan Ave & Pearson St            23.0
# 38551               Michigan Ave & Lake St            31.0
# 38552               Michigan Ave & Lake St            31.0
# 46181               Clark St & Randolph St            39.0
# 46182                  Morgan St & Lake St            23.0
# 46183          Michigan Ave & Jackson Blvd            23.0
# 46184                  Canal St & Adams St            47.0
# 46185                   Daley Center Plaza            39.0
# 46186           Larrabee St & Kingsbury St            39.0
#
#                     to_station_name  end_capacity  temperature  wind_speed  \
# 22990  Campbell Ave & Fullerton Ave          15.0         42.8     -9999.0
# 27168       Avers Ave & Belmont Ave          19.0      -9999.0     -9999.0
# 28368     Ashland Ave & Division St          19.0         73.0     -9999.0
# 29308     Southport Ave & Roscoe St          19.0         77.0     -9999.0
# 29309    Lake Shore Dr & North Blvd          39.0         77.0     -9999.0
# 29310         Dearborn St & Erie St          23.0         77.0     -9999.0
# 38549         State St & Pearson St          27.0         60.1     -9999.0
# 38550      McClurg Ct & Illinois St          31.0         60.1     -9999.0
# 38551           Canal St & Adams St          47.0         60.1     -9999.0
# 38552           Canal St & Adams St          47.0         60.1     -9999.0
# 46181      Canal St & Monroe St (*)          28.0         80.1     -9999.0
# 46182          State St & Kinzie St          31.0         80.1     -9999.0
# 46183  Desplaines St & Jackson Blvd          27.0         80.1     -9999.0
# 46184      Jefferson St & Monroe St          19.0         80.1     -9999.0
# 46185         Dearborn St & Erie St          23.0         80.1     -9999.0
# 46186           Canal St & Adams St          47.0         80.1     -9999.0
#
#              events
# 22990  mostlycloudy
# 27168       unknown
# 28368       tstorms
# 29308  mostlycloudy
# 29309  mostlycloudy
# 29310  mostlycloudy
# 38549        cloudy
# 38550        cloudy
# 38551        cloudy
# 38552        cloudy
# 46181  partlycloudy
# 46182  partlycloudy
# 46183  partlycloudy
# 46184  partlycloudy
# 46185  partlycloudy
# 46186  partlycloudy

# %% [markdown]
# ### Exercise 5
#
# <span  style="color:green; font-size:16px">Find all the rides where the starting number of bikes at the station (start_capacity) was more than 50.</span>

# %%
filt_cap = bikes['start_capacity'] > 50
bikes[filt_cap]
# Out:
#        gender            starttime             stoptime  tripduration  \
#
# 49546    Shedd Aquarium            55.0    Field Blvd & South Water St
# 49556      Field Museum            55.0         State St & Randolph St
# 49758    Shedd Aquarium            55.0     Indiana Ave & Roosevelt Rd
#
#        end_capacity  temperature  wind_speed        events
# 36122          39.0         63.0        10.4  partlycloudy
# 37617          23.0         63.0         4.6        cloudy
# 37920          39.0         55.9        12.7  mostlycloudy
# 37940          23.0         57.9        12.7  partlycloudy
# 39102          27.0         51.1        12.7        cloudy
# 39446          15.0         75.9        24.2  partlycloudy
# 39709          15.0         84.9         8.1  partlycloudy
# 41494          19.0         78.1        15.0  partlycloudy
# 41664          19.0         80.1         5.8  mostlycloudy
# 41971          39.0         68.0         0.0  partlycloudy
# 42140          23.0         80.1         8.1  mostlycloudy
# 42256          31.0         71.1        11.5        cloudy
# 42338          39.0         79.0         8.1  mostlycloudy
# 42564          39.0         82.0         8.1  partlycloudy
# 43023          39.0         72.0         6.9        cloudy
# 43265          23.0         66.0         3.5         clear
# 43284          27.0         82.9         9.2  mostlycloudy
# 43585          15.0         73.0        10.4  mostlycloudy
# 43779          23.0         75.0        12.7  mostlycloudy
# 43826          47.0         62.1         3.5         clear
# 43977          31.0         71.1         5.8  mostlycloudy
# 44049          39.0         71.1         4.6  mostlycloudy
# 44815          23.0         77.0        15.0  partlycloudy
# 44862          47.0         70.0         6.9  partlycloudy
# 44974          15.0         72.0        10.4  partlycloudy
# 45000          23.0         72.0        10.4  partlycloudy
# 45210          23.0         71.1         9.2  mostlycloudy
# 45252          47.0         73.9         6.9  partlycloudy
# 45382          55.0         64.9        11.5  mostlycloudy
# 45474          39.0         72.0         5.8  mostlycloudy
# 45740          55.0         66.0        10.4        cloudy
# 45851          39.0         64.9        12.7  partlycloudy
# 45913          39.0         69.1         6.9         clear
# 46147          15.0         68.0         6.9        cloudy
# 46288          47.0         84.0         8.1  partlycloudy
# 46296          55.0         86.0        13.8  partlycloudy
# 46633          23.0         84.9         6.9  partlycloudy
# 47090          23.0         66.9        10.4  mostlycloudy
# 48353          27.0         51.1         0.0  partlycloudy
# 48949          31.0         37.9         6.9        cloudy
# 49492          31.0         51.8         6.9  partlycloudy
# 49546          19.0         39.0         0.0  partlycloudy
# 49556          27.0         57.9        11.5  mostlycloudy
# 49758          39.0         35.1         6.9          snow

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">Did any rides happen in temperature over 100 degrees?</span>

# %%
filt_hot = bikes['temperature'] > 100
bikes[filt_hot]
# Out:
# Empty DataFrame
# Columns: [gender, starttime, stoptime, tripduration, from_station_name, start_capacity, to_station_name, end_capacity, temperature, wind_speed, events]
# Index: []

# %% [markdown]
# #### Read in new data
#
# Read in the movie dataset by executing the cell below and use it for the following exercises.

# %%
import pandas as pd
movie = pd.read_csv('../data/movie.csv', index_col='title')
movie.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 7
#
# <span  style="color:green; font-size:16px">Select all movies that have 'Tom Hanks' as `actor1`. How many of these movies has he starred in?</span>

# %%
filt_tom = movie['actor1'] == 'Tom Hanks'
len(movie[filt_tom])
# Out:
# 24

# %% [markdown]
# ### Exercise 8
#
# <span  style="color:green; font-size:16px">Select movies with an IMDB score greater than 9.</span>

# %%
filt_score = movie['imdb_score'] > 9
movie[filt_score]
# Out:
#                             year  color content_rating  duration  \
# title
# The Shawshank Redemption  1994.0  Color              R     142.0
# Towering Inferno             NaN  Color            NaN      65.0
# Dekalog                      NaN  Color          TV-MA      55.0
# The Godfather             1972.0  Color              R     175.0
# Kickboxer: Vengeance      2016.0    NaN            NaN      90.0
#
#                                  director_name  director_fb          actor1  \
# title
# The Shawshank Redemption        Frank Darabont          0.0  Morgan Freeman
# Towering Inferno                John Blanchard          0.0    Martin Short
# Dekalog                                    NaN          NaN  Krystyna Janda
# The Godfather             Francis Ford Coppola          0.0       Al Pacino
# Kickboxer: Vengeance            John Stockwell        134.0    Matthew Ziff
#
#                           actor1_fb           actor2  actor2_fb  ...  \
# title                                                            ...
# The Shawshank Redemption    11000.0   Jeffrey DeMunn      745.0  ...
# Towering Inferno              770.0    Andrea Martin      179.0  ...
# Dekalog                        20.0  Olaf Lubaszenko        3.0  ...
# The Godfather               14000.0    Marlon Brando    10000.0  ...
# Kickboxer: Vengeance       260000.0       T.J. Storm      454.0  ...
#
#                          actor3_fb        gross       genres num_reviews  \
# title
# The Shawshank Redemption     461.0   28341469.0  Crime|Drama       199.0
# Towering Inferno             176.0          NaN       Comedy         NaN
# Dekalog                        2.0     447093.0        Drama        53.0
# The Godfather               3000.0  134821952.0  Crime|Drama       208.0
# Kickboxer: Vengeance         354.0          NaN       Action         2.0
#
#                           num_voted_users  \
# title
# The Shawshank Redemption          1689764
# Towering Inferno                       10
# Dekalog                             12590
# The Godfather                     1155770
# Kickboxer: Vengeance                  246
#
#                                                               plot_keywords  \
# title
# The Shawshank Redemption  escape from prison|first person narration|pris...
# Towering Inferno                                                        NaN
# Dekalog                   meaning of life|moral challenge|morality|searc...
# The Godfather             crime family|mafia|organized crime|patriarch|r...
# Kickboxer: Vengeance                                                    NaN
#
#                          language country      budget  imdb_score
# title
# The Shawshank Redemption  English     USA  25000000.0         9.3
# Towering Inferno          English  Canada         NaN         9.5
# Dekalog                    Polish  Poland         NaN         9.1
# The Godfather             English     USA   6000000.0         9.2
# Kickboxer: Vengeance          NaN     USA  17000000.0         9.1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 9
#
# <span  style="color:green; font-size:16px">Write a function that accepts a single parameter to find the number of movies for a given content rating. Use the function to find the number of movies for ratings 'R', 'PG-13', and 'PG'.</span>

# %%
def num_movies(rating):
    filt = movie['content_rating'] == rating
    count = len(movie[filt])
    return f'There are {count} movies rated {rating}.'

# %%
num_movies('R')
# Out:
# 'There are 2067 movies rated R.'

# %%
num_movies('PG-13')
# Out:
# 'There are 1411 movies rated PG-13.'

# %%
num_movies('PG')
# Out:
# 'There are 686 movies rated PG.'
