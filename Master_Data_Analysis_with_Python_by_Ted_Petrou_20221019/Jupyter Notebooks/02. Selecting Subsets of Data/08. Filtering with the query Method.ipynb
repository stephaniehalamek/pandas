# %% [markdown]
# # Filtering with the `query` Method
#
# The previous chapters on boolean selection showed us how to filter our DataFrames and Series based on their values. We created conditions, usually involving the comparison operators, resulting in boolean Series and passed them to the *just the brackets* or `loc` indexers to filter the data.
#
# In this chapter we cover the `query` method, which enables us to also make selections based on the values of the DataFrame or Series. The `query` method is easier and more intuitive to use than boolean selection, but doesn't provide as much functionality to filter the data. Still, it is a good method to know about to make your subset selections more readable.
#
# ## The `query` method
#
# The `query` method allows you to filter the data by writing the condition as a string. For instance, you would use the string `'tripduration > 1000'` to select all rows of the `bikes` dataset that have a `tripduration` greater than 1,000. Let's read in the bikes dataset and run this command now.

# %%
import pandas as pd
bikes = pd.read_csv('../data/bikes.csv', parse_dates=['starttime', 'stoptime'])
bikes.query('tripduration > 1000').head(3)
# Out:
#    gender           starttime            stoptime  tripduration  \
# 2    Male 2013-06-30 14:43:00 2013-06-30 15:01:00          1040
# 8    Male 2013-07-03 15:21:00 2013-07-03 15:42:00          1300
# 10   Male 2013-07-04 17:17:00 2013-07-04 17:42:00          1523
#
#                from_station_name  start_capacity          to_station_name  \
# 2   Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 8   Clinton St & Washington Blvd            31.0    Wood St & Division St
# 10           Morgan St & 18th St            15.0   Damen Ave & Pierce Ave
#
#     end_capacity  temperature  wind_speed        events
# 2           23.0         73.0        16.1  mostlycloudy
# 8           15.0         71.1         0.0        cloudy
# 10          19.0         79.0         9.2  mostlycloudy

# %% [markdown]
# ### Less syntax and more readable
#
# The `query` method generally uses less syntax than boolean selection and is usually more readable. Reproducing the last result with boolean selection would look like this:
#
# ```python
# bikes[bikes['tripduration'] > 1000]
# ```
#
# This looks a bit clumsy with the name `bikes` written twice right next to one another. The `query` method has its own set of rules for what constitutes a correctly written condition within the string you pass it. The rest of this chapter covers all of the available functionality of the `query` method. This syntax only works within the `query` method and is not allowed anywhere else in pandas.
#
# ## Use strings `and`, `or`, `not`
#
# Unlike boolean selection, you can use the strings `and`, `or`, and `not` instead of the operators `&`, `|`, and `~` which further aides readability with `query`. Let's select all rides with `tripduration` greater than 1,000 and `temperature` greater than 85.

# %%
bikes.query('tripduration > 1000 and temperature > 85').head(3)
# Out:
#     gender           starttime            stoptime  tripduration  \
# 40  Female 2013-07-14 14:08:00 2013-07-14 15:53:00          6274
# 53    Male 2013-07-16 13:04:00 2013-07-16 13:28:00          1435
# 60    Male 2013-07-17 10:23:00 2013-07-17 10:40:00          1024
#
#                from_station_name  start_capacity             to_station_name  \
# 40     Wabash Ave & Roosevelt Rd            19.0   Lake Shore Dr & Monroe St
# 53       Canal St & Jackson Blvd            35.0     Canal St & Jackson Blvd
# 60  Clinton St & Washington Blvd            31.0  Larrabee St & Menomonee St
#
#     end_capacity  temperature  wind_speed        events
# 40          11.0         87.1         8.1  partlycloudy
# 53          35.0         90.0         8.1  mostlycloudy
# 60          15.0         88.0         5.8  partlycloudy

# %% [markdown]
# ## Chained comparisons
#
# Let's say we want to find all rides where the temperature was between 50 and 60 degrees. You can do this with `query` by using the `and` operator.

# %%
bikes.query('temperature >= 50 and temperature <= 60').head(3)
# Out:
#      gender           starttime            stoptime  tripduration  \
# 590  Female 2013-09-13 07:55:00 2013-09-13 08:01:00           319
# 591    Male 2013-09-13 08:04:00 2013-09-13 08:16:00           738
# 592  Female 2013-09-13 08:04:00 2013-09-13 08:14:00           599
#
#                  from_station_name  start_capacity  \
# 590  Greenview Ave & Fullerton Ave            15.0
# 591     Lincoln Ave & Armitage Ave            19.0
# 592            Orleans St & Elm St            15.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 590  Sheffield Ave & Fullerton Ave          15.0         54.0        15.0
# 591     Larrabee St & Kingsbury St          27.0         57.9        13.8
# 592   Sheffield Ave & Kingsbury St          15.0         57.9        13.8
#
#            events
# 590  partlycloudy
# 591  partlycloudy
# 592  partlycloudy

# %% [markdown]
# While this syntax is valid, there is a more compact way. You can use a **chained comparison** to make the string even more readable and concise. A chained comparison places the column name between two comparison operators. The following implies that 50 is less than or equal to the temperature and the temperature is less than or equal to 60 which is equivalent to our previous selection.

# %%
bikes.query('50 <= temperature <= 60').head(3)
# Out:
#      gender           starttime            stoptime  tripduration  \
# 590  Female 2013-09-13 07:55:00 2013-09-13 08:01:00           319
# 591    Male 2013-09-13 08:04:00 2013-09-13 08:16:00           738
# 592  Female 2013-09-13 08:04:00 2013-09-13 08:14:00           599
#
#                  from_station_name  start_capacity  \
# 590  Greenview Ave & Fullerton Ave            15.0
# 591     Lincoln Ave & Armitage Ave            19.0
# 592            Orleans St & Elm St            15.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 590  Sheffield Ave & Fullerton Ave          15.0         54.0        15.0
# 591     Larrabee St & Kingsbury St          27.0         57.9        13.8
# 592   Sheffield Ave & Kingsbury St          15.0         57.9        13.8
#
#            events
# 590  partlycloudy
# 591  partlycloudy
# 592  partlycloudy

# %% [markdown]
# ## Reference strings with quotes
#
# If you would like to reference a literal string within `query`, you need to surround it with quotes, or else pandas will attempt to use it as a column name. Let's select all rides by a 'Female' with a trip duration greater than 2,000.

# %%
bikes.query('gender == "Female" and tripduration > 2000').head(3)
# Out:
#      gender           starttime            stoptime  tripduration  \
# 40   Female 2013-07-14 14:08:00 2013-07-14 15:53:00          6274
# 77   Female 2013-07-21 11:35:00 2013-07-21 13:54:00          8299
# 173  Female 2013-08-08 08:49:00 2013-08-08 09:31:00          2502
#
#               from_station_name  start_capacity               to_station_name  \
# 40    Wabash Ave & Roosevelt Rd            19.0     Lake Shore Dr & Monroe St
# 77           State St & 19th St            15.0  Sheffield Ave & Kingsbury St
# 173  Sheffield Ave & Addison St            27.0        Dearborn St & Adams St
#
#      end_capacity  temperature  wind_speed        events
# 40           11.0         87.1         8.1  partlycloudy
# 77           15.0         82.9         5.8  mostlycloudy
# 173          19.0         71.1        10.4  mostlycloudy

# %% [markdown]
# ### Forgetting quotes
#
# If you do not use quotes around your literal string, then pandas assumes that value is a column name. The following raises an error. It believes you are accessing a column name Female, which doesn't exist.

# %%
bikes.query('gender == Female and tripduration > 2000')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/scope.py:198, in Scope.resolve(self, key, is_local)
#     197 if self.has_resolvers:
# --> 198     return self.resolvers[key]
#     200 # if we're here that means that we have no locals and we also have
#     201 # no resolvers
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/collections/__init__.py:1004, in ChainMap.__getitem__(self, key)
#    1003         pass
# -> 1004 return self.__missing__(key)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/collections/__init__.py:996, in ChainMap.__missing__(self, key)
#     995 def __missing__(self, key):
# --> 996     raise KeyError(key)
#
# KeyError: 'Female'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/scope.py:209, in Scope.resolve(self, key, is_local)
#     205 try:
#     206     # last ditch effort we look in temporaries
#     207     # these are created when parsing indexing expressions
#     208     # e.g., df[df > 0]
# --> 209     return self.temps[key]
#     210 except KeyError as err:
#
# KeyError: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bikes.query('gender == Female and tripduration > 2000')
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4472 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473 kwargs["target"] = None
# -> 4474 res = self.eval(expr, **kwargs)
#    4476 try:
#    4477     result = self.loc[res]
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/frame.py:4612, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4609     kwargs["target"] = self
#    4610 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4612 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/eval.py:353, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     344 # get our (possibly passed-in) scope
#     345 env = ensure_scope(
#     346     level + 1,
#     347     global_dict=global_dict,
#    (...)
#     350     target=target,
#     351 )
# --> 353 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     355 # construct the engine and evaluate the parsed expression
#     356 eng = ENGINES[engine]
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:813, in Expr.__init__(self, expr, engine, parser, env, level)
#     811 self.parser = parser
#     812 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 813 self.terms = self.parse()
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:832, in Expr.parse(self)
#     828 def parse(self):
#     829     """
#     830     Parse an expression.
#     831     """
# --> 832     return self._visitor.visit(self.expr)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:750, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     747     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     749 operands = node.values
# --> 750 return reduce(visitor, operands)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:743, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     742 def visitor(x, y):
# --> 743     lhs = self._try_visit_binop(x)
#     744     rhs = self._try_visit_binop(y)
#     746     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:739, in BaseExprVisitor._try_visit_binop(self, bop)
#     737 if isinstance(bop, (Op, Term)):
#     738     return bop
# --> 739 return self.visit(bop)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:458, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     456     left = self.visit(node.left, side="left")
#     457 if right is None:
# --> 458     right = self.visit(node.right, side="right")
#     459 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     460 return op, op_class, left, right
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/expr.py:549, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     548 def visit_Name(self, node, **kwargs):
# --> 549     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/ops.py:85, in Term.__init__(self, name, env, side, encoding)
#      83 tname = str(name)
#      84 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 85 self._value = self._resolve_name()
#      86 self.encoding = encoding
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/ops.py:109, in Term._resolve_name(self)
#     104 if local_name in self.env.scope and isinstance(
#     105     self.env.scope[local_name], type
#     106 ):
#     107     is_local = False
# --> 109 res = self.env.resolve(local_name, is_local=is_local)
#     110 self.update(res)
#     112 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/miniconda3/envs/mini_ds/lib/python3.11/site-packages/pandas/core/computation/scope.py:211, in Scope.resolve(self, key, is_local)
#     209     return self.temps[key]
#     210 except KeyError as err:
# --> 211     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'Female' is not defined

# %% [markdown]
# ## Column to column comparisons
#
# It is possible to compare each value in one column with each value in another column. Here, we filter for all the rides where there were more bikes at the start than at the end.

# %%
bikes.query('start_capacity > end_capacity').head(3)
# Out:
#   gender           starttime            stoptime  tripduration  \
# 1   Male 2013-06-28 22:53:00 2013-06-28 23:03:00           623
# 6   Male 2013-07-02 17:47:00 2013-07-02 17:56:00           565
# 8   Male 2013-07-03 15:21:00 2013-07-03 15:42:00          1300
#
#               from_station_name  start_capacity  \
# 1  Clinton St & Washington Blvd            31.0
# 6        Clark St & Randolph St            31.0
# 8  Clinton St & Washington Blvd            31.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 1             Wells St & Walton St          19.0         69.1         6.9
# 6  Ravenswood Ave & Irving Park Rd          19.0         66.0        15.0
# 8            Wood St & Division St          15.0         71.1         0.0
#
#          events
# 1  partlycloudy
# 6        cloudy
# 8        cloudy

# %% [markdown]
# ## Use 'in' for multiple equalities
#
# You can check whether each value in a column is equal to one or more other values by using the word 'in' within your query. Use the syntax for creating a list within the query string to contain all the values you'd like to check. The following tests whether the weather event was snow or rain.

# %%
bikes.query('events in ["snow", "rain"]').head(3)
# Out:
#     gender           starttime            stoptime  tripduration  \
# 45    Male 2013-07-15 16:43:00 2013-07-15 16:55:00           727
# 112   Male 2013-07-26 19:10:00 2013-07-26 19:33:00          1395
# 124   Male 2013-07-30 18:53:00 2013-07-30 19:00:00           442
#
#               from_station_name  start_capacity             to_station_name  \
# 45      Greenwood Ave & 47th St            15.0      State St & Harrison St
# 112  Larrabee St & Kingsbury St            27.0      Damen Ave & Pierce Ave
# 124     Canal St & Jackson Blvd            35.0  Racine Ave & Congress Pkwy
#
#      end_capacity  temperature  wind_speed events
# 45           19.0         82.9         5.8   rain
# 112          19.0         66.9        12.7   rain
# 124          19.0         69.1         3.5   rain

# %% [markdown]
# There are multiple syntaxes for the above that all work the same, but I prefer using the above as it is most similar to the `isin` method used during boolean selection.
#
# * `bikes.query('["snow", "rain"] in events')`
# * `bikes.query('["snow", "rain"] == events')`
# * `bikes.query('events == ["snow", "rain"]')`

# %% [markdown]
# ### Use 'not in' to invert the condition
#
# You can invert the result of an 'in' clause by placing the word 'not' before it. Here, we find all the rides that did not have the weather events cloudy, partly cloudy or mostly cloudy.

# %%
bikes.query('events not in ["cloudy", "partlycloudy", "mostlycloudy"]').head(3)
# Out:
#     gender           starttime            stoptime  tripduration  \
# 25  Female 2013-07-11 08:17:00 2013-07-11 08:31:00           830
# 26    Male 2013-07-12 01:07:00 2013-07-12 01:24:00          1043
# 33    Male 2013-07-12 17:22:00 2013-07-12 17:34:00           730
#
#             from_station_name  start_capacity             to_station_name  \
# 25  Wabash Ave & Roosevelt Rd            19.0          Daley Center Plaza
# 26     State St & Harrison St            19.0        Racine Ave & 18th St
# 33   Clark St & Congress Pkwy            27.0  Racine Ave & Congress Pkwy
#
#     end_capacity  temperature  wind_speed events
# 25          47.0         73.9         8.1  clear
# 26          15.0         64.9         0.0  clear
# 33          19.0         79.0        10.4  clear

# %% [markdown]
# ## Arithmetic operations within `query`
#
# It is possible to write arithmetic operations within `query` just as you would outside of it. For instance, if we wanted to find all the rides such that there were 20 or more bikes at the start station than at the end, we do the following.

# %%
bikes.query('start_capacity - end_capacity >= 20').head(3)
# Out:
#     gender           starttime            stoptime  tripduration  \
# 54    Male 2013-07-16 15:13:00 2013-07-16 15:18:00           347
# 66    Male 2013-07-17 20:56:00 2013-07-17 21:14:00          1073
# 116   Male 2013-07-27 09:54:00 2013-07-27 09:56:00           121
#
#       from_station_name  start_capacity             to_station_name  \
# 54   Daley Center Plaza            47.0     State St & Van Buren St
# 66      Millennium Park            35.0         Morgan St & 18th St
# 116  Daley Center Plaza            47.0  LaSalle St & Washington St
#
#      end_capacity  temperature  wind_speed        events
# 54           27.0         91.0         8.1  mostlycloudy
# 66           15.0         86.0         9.2  partlycloudy
# 116          15.0         60.8        11.5        cloudy

# %% [markdown]
# ### Filtering for right triangles
#
# Let's read in the triangles dataset which contains the lengths of each side of a triangle as the columns `a`, `b`, and `c`.

# %%
triangles = pd.read_csv('../data/triangles.csv')
triangles.head()
# Out:
#    a  b  c
# 0  2  3  4
# 1  3  2  4
# 2  3  4  5
# 3  3  5  6
# 4  3  6  7

# %% [markdown]
# We can use the `query` method to find all the right triangles, those that satisfy the Pythagorean Theorem. We write the condition using the arithmetic and comparison operators.

# %%
triangles.query('a ** 2 + b ** 2 == c ** 2').head()
# Out:
#     a   b   c
# 2   3   4   5
# 5   4   3   5
# 14  5  12  13
# 21  6   8  10
# 33  7  24  25

# %% [markdown]
# The syntax is quite a bit nicer than the boolean selection alternative.

# %%
filt = triangles['a'] ** 2 + triangles['b'] ** 2 == triangles['c'] ** 2
triangles[filt].head()

# %% [markdown]
# ## Reference variable names with the `@` symbol
#
# By default, all words within the query string attempt to reference a column name. You can, however, reference a variable name by preceding it with the `@` symbol. Let's assign the variable name `min_length` to 5,000 and reference it in a query to find all the rides where trip duration was greater than it.

# %%
min_length = 5000
bikes.query('tripduration > @min_length').head(3)
# Out:
#     gender           starttime            stoptime  tripduration  \
# 18    Male 2013-07-09 13:12:00 2013-07-09 14:42:00          5396
# 40  Female 2013-07-14 14:08:00 2013-07-14 15:53:00          6274
# 77  Female 2013-07-21 11:35:00 2013-07-21 13:54:00          8299
#
#             from_station_name  start_capacity               to_station_name  \
# 18    Canal St & Jackson Blvd            35.0               Millennium Park
# 40  Wabash Ave & Roosevelt Rd            19.0     Lake Shore Dr & Monroe St
# 77         State St & 19th St            15.0  Sheffield Ave & Kingsbury St
#
#     end_capacity  temperature  wind_speed        events
# 18          35.0         79.0        13.8        cloudy
# 40          11.0         87.1         8.1  partlycloudy
# 77          15.0         82.9         5.8  mostlycloudy

# %%
max_temp = 70
bikes.query('temperature < @max_temp').head(3)
# Out:
#   gender           starttime            stoptime  tripduration  \
# 1   Male 2013-06-28 22:53:00 2013-06-28 23:03:00           623
# 6   Male 2013-07-02 17:47:00 2013-07-02 17:56:00           565
# 7   Male 2013-07-03 09:07:00 2013-07-03 09:16:00           505
#
#               from_station_name  start_capacity  \
# 1  Clinton St & Washington Blvd            31.0
# 6        Clark St & Randolph St            31.0
# 7       State St & Van Buren St            27.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 1             Wells St & Walton St          19.0         69.1         6.9
# 6  Ravenswood Ave & Irving Park Rd          19.0         66.0        15.0
# 7       Franklin St & Jackson Blvd          27.0         64.0         5.8
#
#          events
# 1  partlycloudy
# 6        cloudy
# 7        cloudy

# %% [markdown]
# ## Using the index with `query`
#
# You can even use the word `index` to make comparisons against the index as if it were a normal column. In the bikes DataFrame, the index is just the integers beginning at 0. Here, we select only the `events` that were 'cloudy' for an index value greater than 4,000.

# %%
bikes.query('index > 4000 and events == "cloudy" ').head(3)
# Out:
#      gender           starttime            stoptime  tripduration  \
# 4007   Male 2014-06-07 14:07:00 2014-06-07 14:31:00          1434
# 4008   Male 2014-06-07 14:58:00 2014-06-07 15:19:00          1258
# 4009   Male 2014-06-07 15:23:00 2014-06-07 15:28:00           297
#
#                from_station_name  start_capacity  \
# 4007  Lake Shore Dr & North Blvd            15.0
# 4008         Theater on the Lake            15.0
# 4009  Sheffield Ave & Addison St            27.0
#
#                     to_station_name  end_capacity  temperature  wind_speed  \
# 4007         Halsted St & Roscoe St          15.0         82.0        13.8
# 4008        Sheridan Rd & Buena Ave          15.0         82.0        13.8
# 4009  Pine Grove Ave & Waveland Ave          23.0         80.1        13.8
#
#       events
# 4007  cloudy
# 4008  cloudy
# 4009  cloudy

# %% [markdown]
# ### Referencing named index
#
# If your DataFrame has an index that is named, which happens when a column is set as the index, then you can use that name within `query` just as if it were a regular column name. Here, we create a new DataFrame that has the `from_station_name` as the index.

# %%
bikes_idx = bikes.set_index('from_station_name')

# %%
bikes_idx = bikes.set_index('from_station_name')
bikes_idx.head(3)
# Out:
#                              gender           starttime            stoptime  \
# from_station_name
# Lake Shore Dr & Monroe St      Male 2013-06-28 19:01:00 2013-06-28 19:17:00
# Clinton St & Washington Blvd   Male 2013-06-28 22:53:00 2013-06-28 23:03:00
# Sheffield Ave & Kingsbury St   Male 2013-06-30 14:43:00 2013-06-30 15:01:00
#
#                               tripduration  start_capacity  \
# from_station_name
# Lake Shore Dr & Monroe St              993            11.0
# Clinton St & Washington Blvd           623            31.0
# Sheffield Ave & Kingsbury St          1040            15.0
#
#                                       to_station_name  end_capacity  \
# from_station_name
# Lake Shore Dr & Monroe St       Michigan Ave & Oak St          15.0
# Clinton St & Washington Blvd     Wells St & Walton St          19.0
# Sheffield Ave & Kingsbury St  Dearborn St & Monroe St          23.0
#
#                               temperature  wind_speed        events
# from_station_name
# Lake Shore Dr & Monroe St            73.9        12.7  mostlycloudy
# Clinton St & Washington Blvd         69.1         6.9  partlycloudy
# Sheffield Ave & Kingsbury St         73.0        16.1  mostlycloudy

# %% [markdown]
# Notice the name 'from_station_name' directly above the index. This is the name for the index and what can be referenced when using `query`. Let's filter for trip ids greater than 200,000.

# %%
bikes_idx.query('from_station_name == "Theater on the Lake"').head(3)
# Out:
#                      gender           starttime            stoptime  \
# from_station_name
# Theater on the Lake    Male 2013-08-23 17:57:00 2013-08-23 18:16:00
# Theater on the Lake  Female 2013-08-24 15:31:00 2013-08-24 15:59:00
# Theater on the Lake    Male 2013-09-07 14:28:00 2013-09-07 14:37:00
#
#                      tripduration  start_capacity  \
# from_station_name
# Theater on the Lake          1166            15.0
# Theater on the Lake          1661            15.0
# Theater on the Lake           540            15.0
#
#                                    to_station_name  end_capacity  temperature  \
# from_station_name
# Theater on the Lake        Lincoln Ave & Roscoe St          19.0         79.0
# Theater on the Lake       Fairbanks Ct & Grand Ave          15.0         84.9
# Theater on the Lake  Sheffield Ave & Fullerton Ave          15.0         88.0
#
#                      wind_speed        events
# from_station_name
# Theater on the Lake         9.2  partlycloudy
# Theater on the Lake         6.9  partlycloudy
# Theater on the Lake        10.4  mostlycloudy

# %% [markdown]
# ## Use backticks to reference column names with spaces
#
# pandas allows DataFrames to have column names with spaces in them. In order to use a column name containing spaces within `query`, you'll need to surround it with backticks. If you don't use the backticks you'll get an error. Let's read in the San Francisco employee compensation dataset which contains multiple column names that have spaces.

# %%
sf_emp = pd.read_csv('../data/sf_employee_compensation.csv')
sf_emp.head(3)
# Out:
#    year                organization group                   job   salaries  \
# 0  2013                 Public Protection  Personnel Technician   71414.01
# 1  2013  General Administration & Finance             Planner 2   67941.06
# 2  2013                 Public Protection           Firefighter  116956.72
#
#    overtime  other salaries  retirement  health and dental  other benefits
# 0      0.00             0.0    14038.58           12918.24         5872.04
# 1      0.00             0.0    13030.23           10047.52         5608.37
# 2  59975.43         19037.3    24796.44           15788.97         3222.20

# %% [markdown]
# Let's find all the employees that are in the organization group of 'Public Protection'.

# %%
sf_emp.query('`organization group` == "Public Protection"').head(2)
# Out:
#    year organization group                   job   salaries  overtime  \
# 0  2013  Public Protection  Personnel Technician   71414.01      0.00
# 2  2013  Public Protection           Firefighter  116956.72  59975.43
#
#    other salaries  retirement  health and dental  other benefits
# 0             0.0    14038.58           12918.24         5872.04
# 2         19037.3    24796.44           15788.97         3222.20

# %%
sf_emp.query('`organization group` == "Public Protection"').head(3)

# %% [markdown]
# ### Selecting columns with `query`
#
# Unfortunately the `query` method does not give us the ability to select a subset of the columns when filtering the data. You would have to do normal column selection after calling the method. Here, we use *just the brackets* to select three columns after finding all the rides where the weather was snow or rain.

# %%
cols = ['starttime', 'temperature', 'events']
bikes.query('events in ["snow", "rain"]')[cols].head()

# %%
cols = ['job', 'salaries', 'retirement']
sf_emp.query('`organization group` == "Public Protection"')[cols].head(2)
# Out:
#                     job   salaries  retirement
# 0  Personnel Technician   71414.01    14038.58
# 2           Firefighter  116956.72    24796.44

# %% [markdown]
# ## Summary
#
# The `query` method provides an alternative to boolean selection to filter the data based on the values. Here are the rules for the string you provide.
#
# * The expression in the string must evaluate as True or False for every row
# * Column names may be accessed directly with their name
# * Often you will use one of the comparison operators to create a condition
# * Use chained comparison operators to shorten syntax
# * Use `and`, `or`, and `not` to create more complex conditions
# * To use a literal string, surround it with quotes
# * Use `in` to test multiple equalities. Provide the test values in a list
# * All arithmetic operators work just as they do outside of the string
# * Use the `@` character to reference a variable name
# * Reference the index with the string 'index' or the index's name
# * Use backticks to reference a column name with spaces in it

# %% [markdown]
# ## Exercises
#
# Use the bikes dataset for the first few exercises.

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">Use the `query` method to select trip durations between 5,000 and 10,000.</span>

# %%
bikes.head(1)
# Out:
#   gender           starttime            stoptime  tripduration  \
# 0   Male 2013-06-28 19:01:00 2013-06-28 19:17:00           993
#
#            from_station_name  start_capacity        to_station_name  \
# 0  Lake Shore Dr & Monroe St            11.0  Michigan Ave & Oak St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy

# %%
bikes.query('5000 < tripduration < 10000').head()
# Out:
#       gender           starttime            stoptime  tripduration  \
# 18      Male 2013-07-09 13:12:00 2013-07-09 14:42:00          5396
# 40    Female 2013-07-14 14:08:00 2013-07-14 15:53:00          6274
# 77    Female 2013-07-21 11:35:00 2013-07-21 13:54:00          8299
# 335     Male 2013-08-25 17:20:00 2013-08-25 19:26:00          7533
# 1954  Female 2013-12-28 11:37:00 2013-12-28 13:34:00          7050
#
#                from_station_name  start_capacity  \
# 18       Canal St & Jackson Blvd            35.0
# 40     Wabash Ave & Roosevelt Rd            19.0
# 77            State St & 19th St            15.0
# 335     McClurg Ct & Illinois St            23.0
# 1954  LaSalle St & Washington St            15.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 18                 Millennium Park          35.0         79.0        13.8
# 40       Lake Shore Dr & Monroe St          11.0         87.1         8.1
# 77    Sheffield Ave & Kingsbury St          15.0         82.9         5.8
# 335      Lake Shore Dr & Monroe St          11.0         87.1        12.7
# 1954           Theater on the Lake          15.0         44.1        12.7
#
#             events
# 18          cloudy
# 40    partlycloudy
# 77    mostlycloudy
# 335          clear
# 1954         clear

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">Use the `query` method to select trip durations between 5,000 and 10,000 when the weather was snow or rain. Retrieve the same data with boolean selection.</span>

# %%
bikes.query('5000 < tripduration < 10000 and events in ["snow", "rain"]').head(2)
# Out:
#       gender           starttime            stoptime  tripduration  \
# 8506    Male 2014-10-04 12:33:00 2014-10-04 14:06:00          5568
# 13355   Male 2015-06-15 11:41:00 2015-06-15 13:43:00          7295
#
#                 from_station_name  start_capacity  \
# 8506   Halsted St & Diversey Pkwy            15.0
# 13355    Racine Ave & Belmont Ave            15.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 8506   Halsted St & Wrightwood Ave          15.0         42.1        17.3
# 13355     Racine Ave & Belmont Ave          15.0         75.9         4.6
#
#       events
# 8506    rain
# 13355   rain

# %%
filt = (bikes['tripduration'] >= 5000) & (bikes['tripduration'] <= 10000) & (bikes['events'].isin(['snow', 'rain']))
bikes[filt].head(2)
# Out:
#       gender           starttime            stoptime  tripduration  \
# 8506    Male 2014-10-04 12:33:00 2014-10-04 14:06:00          5568
# 13355   Male 2015-06-15 11:41:00 2015-06-15 13:43:00          7295
#
#                 from_station_name  start_capacity  \
# 8506   Halsted St & Diversey Pkwy            15.0
# 13355    Racine Ave & Belmont Ave            15.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 8506   Halsted St & Wrightwood Ave          15.0         42.1        17.3
# 13355     Racine Ave & Belmont Ave          15.0         75.9         4.6
#
#       events
# 8506    rain
# 13355   rain

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">Use the `query` method to select trip durations between 5,000 and 10,000 when it was snow or rain. Create a list outside of the `query` method to hold the weather and reference that variable with `@` within `query`.</span>

# %%
bikes.query('5000 < tripduration < 10000 and events in ["snow", "rain"]').head()
# Out:
#       gender           starttime            stoptime  tripduration  \
# 8506    Male 2014-10-04 12:33:00 2014-10-04 14:06:00          5568
# 13355   Male 2015-06-15 11:41:00 2015-06-15 13:43:00          7295
# 22155   Male 2016-02-09 10:09:00 2016-02-09 12:28:00          8309
#
#                 from_station_name  start_capacity  \
# 8506   Halsted St & Diversey Pkwy            15.0
# 13355    Racine Ave & Belmont Ave            15.0
# 22155   Wabash Ave & Roosevelt Rd            23.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 8506   Halsted St & Wrightwood Ave          15.0         42.1        17.3
# 13355     Racine Ave & Belmont Ave          15.0         75.9         4.6
# 22155                Museum Campus          35.0         16.0        16.1
#
#       events
# 8506    rain
# 13355   rain
# 22155   snow

# %%
weather = ["snow", "rain"]
bikes.query('events in @weather').head()
# Out:
#      gender           starttime            stoptime  tripduration  \
# 45     Male 2013-07-15 16:43:00 2013-07-15 16:55:00           727
# 112    Male 2013-07-26 19:10:00 2013-07-26 19:33:00          1395
# 124    Male 2013-07-30 18:53:00 2013-07-30 19:00:00           442
# 161    Male 2013-08-05 17:09:00 2013-08-05 17:23:00           890
# 498  Female 2013-09-07 16:09:00 2013-09-07 16:26:00           978
#
#               from_station_name  start_capacity             to_station_name  \
# 45      Greenwood Ave & 47th St            15.0      State St & Harrison St
# 112  Larrabee St & Kingsbury St            27.0      Damen Ave & Pierce Ave
# 124     Canal St & Jackson Blvd            35.0  Racine Ave & Congress Pkwy
# 161      Clark St & Randolph St            31.0       Michigan Ave & Oak St
# 498     Damen Ave & Melrose Ave            11.0      Leavitt St & North Ave
#
#      end_capacity  temperature  wind_speed events
# 45           19.0         82.9         5.8   rain
# 112          19.0         66.9        12.7   rain
# 124          19.0         69.1         3.5   rain
# 161          15.0         68.0         8.1   rain
# 498          11.0         81.0         6.9   rain

# %% [markdown]
# Read in the movie dataset by executing the cell below and use it for the following exercises.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
movie = pd.read_csv('../data/movie.csv', index_col='title')
movie.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb            actor3  \
# title
# Avatar                                        936.0         Wes Studi
# Pirates of the Caribbean: At World's End     5000.0    Jack Davenport
# Spectre                                       393.0  Stephanie Sigman
#
#                                           actor3_fb        gross  \
# title
# Avatar                                        855.0  760505847.0
# Pirates of the Caribbean: At World's End     1000.0  309404152.0
# Spectre                                       161.0  200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                           num_reviews  num_voted_users  \
# title
# Avatar                                          723.0           886204
# Pirates of the Caribbean: At World's End        302.0           471220
# Spectre                                         602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Use the `query` method to find all movies where the total number of Facebook likes for all three actors is greater than 50,000.</span>

# %%
movie.query('actor1_fb + actor2_fb + actor3_fb) > 50000'.head()
# Out:
#                                                year  color content_rating  \
# title
# The Dark Knight Rises                        2012.0  Color          PG-13
# Avengers: Age of Ultron                      2015.0  Color          PG-13
# The Avengers                                 2012.0  Color          PG-13
# Pirates of the Caribbean: On Stranger Tides  2011.0  Color          PG-13
# Captain America: Civil War                   2016.0  Color          PG-13
#
#                                              duration      director_name  \
# title
# The Dark Knight Rises                           164.0  Christopher Nolan
# Avengers: Age of Ultron                         141.0        Joss Whedon
# The Avengers                                    173.0        Joss Whedon
# Pirates of the Caribbean: On Stranger Tides     136.0       Rob Marshall
# Captain America: Civil War                      147.0      Anthony Russo
#
#                                              director_fb             actor1  \
# title
# The Dark Knight Rises                            22000.0          Tom Hardy
# Avengers: Age of Ultron                              0.0    Chris Hemsworth
# The Avengers                                         0.0    Chris Hemsworth
# Pirates of the Caribbean: On Stranger Tides        252.0        Johnny Depp
# Captain America: Civil War                          94.0  Robert Downey Jr.
#
#                                              actor1_fb              actor2  \
# title
# The Dark Knight Rises                          27000.0      Christian Bale
# Avengers: Age of Ultron                        26000.0   Robert Downey Jr.
# The Avengers                                   26000.0   Robert Downey Jr.
# Pirates of the Caribbean: On Stranger Tides    40000.0         Sam Claflin
# Captain America: Civil War                     21000.0  Scarlett Johansson
#
#                                              actor2_fb                actor3  \
# title
# The Dark Knight Rises                          23000.0  Joseph Gordon-Levitt
# Avengers: Age of Ultron                        21000.0    Scarlett Johansson
# The Avengers                                   21000.0    Scarlett Johansson
# Pirates of the Caribbean: On Stranger Tides    11000.0        Stephen Graham
# Captain America: Civil War                     19000.0           Chris Evans
#
#                                              actor3_fb        gross  \
# title
# The Dark Knight Rises                          23000.0  448130642.0
# Avengers: Age of Ultron                        19000.0  458991599.0
# The Avengers                                   19000.0  623279547.0
# Pirates of the Caribbean: On Stranger Tides     1000.0  241063875.0
# Captain America: Civil War                     11000.0  407197282.0
#
#                                                                genres  \
# title
# The Dark Knight Rises                                 Action|Thriller
# Avengers: Age of Ultron                       Action|Adventure|Sci-Fi
# The Avengers                                  Action|Adventure|Sci-Fi
# Pirates of the Caribbean: On Stranger Tides  Action|Adventure|Fantasy
# Captain America: Civil War                    Action|Adventure|Sci-Fi
#
#                                              num_reviews  num_voted_users  \
# title
# The Dark Knight Rises                              813.0          1144337
# Avengers: Age of Ultron                            635.0           462669
# The Avengers                                       703.0           995415
# Pirates of the Caribbean: On Stranger Tides        448.0           370704
# Captain America: Civil War                         516.0           272670
#
#                                                                                  plot_keywords  \
# title
# The Dark Knight Rises                        deception|imprisonment|lawlessness|police offi...
# Avengers: Age of Ultron                      artificial intelligence|based on comic book|ca...
# The Avengers                                   alien invasion|assassin|battle|iron man|soldier
# Pirates of the Caribbean: On Stranger Tides          blackbeard|captain|pirate|revenge|soldier
# Captain America: Civil War                   based on comic book|knife|marvel cinematic uni...
#
#                                             language country       budget  \
# title
# The Dark Knight Rises                        English     USA  250000000.0
# Avengers: Age of Ultron                      English     USA  250000000.0
# The Avengers                                 English     USA  220000000.0
# Pirates of the Caribbean: On Stranger Tides  English     USA  250000000.0
# Captain America: Civil War                   English     USA  250000000.0
#
#                                              imdb_score
# title
# The Dark Knight Rises                               8.5
# Avengers: Age of Ultron                             7.5
# The Avengers                                        8.1
# Pirates of the Caribbean: On Stranger Tides         6.7
# Captain America: Civil War                          8.2

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">Select all the movies where the number of user voters is less than 10 times the number of reviews.</span>

# %%
movie.query('num_voted_users < num_reviews*10')
# Out:
#                                              year            color  \
# title
# Indignation                                2016.0            Color
# Pete's Dragon                              2016.0            Color
# Kicks                                      2016.0            Color
# Two Lovers and a Bear                      2016.0            Color
# Antibirth                                  2016.0            Color
# Mi America                                 2015.0            Color
# Sharkskin                                  2015.0            Color
# The Ghastly Love of Johnny X               2012.0  Black and White
# Wind Walkers                               2015.0            Color
# Down and Out with the Dolls                2001.0            Color
# Certifiably Jonathan                       2007.0            Color
# Departure                                  2015.0            Color
# The Last Big Thing                         1996.0            Color
# Bang Bang Baby                             2014.0            Color
# Elza                                       2011.0            Color
# The Young Unknowns                         2000.0            Color
# The Hadza: Last of the First               2014.0            Color
# They Will Have to Kill Us First            2015.0            Color
# Faith Connections                          2013.0            Color
# Sholem Aleichem: Laughing in the Darkness  2011.0            Color
# The Outrageous Sophie Tucker               2014.0            Color
# Born to Fly: Elizabeth Streb vs. Gravity   2014.0            Color
# Censored Voices                            2015.0            Color
# UnDivided                                  2013.0            Color
# Give Me Shelter                            2014.0            Color
# The Stewardesses                           1969.0            Color
# Short Cut to Nirvana: Kumbh Mela           2004.0            Color
# Call + Response                            2008.0            Color
# Theresa Is a Mother                        2012.0            Color
# Archaeology of a Woman                     2012.0            Color
# The Blood of My Brother                    2005.0            Color
# Over the Hill to the Poorhouse             1920.0  Black and White
# Queen Crab                                 2015.0            Color
# Counting                                   2015.0            Color
# Bending Steel                              2013.0            Color
# The Image Revolution                       2014.0            Color
# Tin Can Man                                2007.0  Black and White
# A Plague So Pleasant                       2013.0            Color
#
#                                           content_rating  duration  \
# title
# Indignation                                            R     110.0
# Pete's Dragon                                         PG     102.0
# Kicks                                                  R      80.0
# Two Lovers and a Bear                                NaN      96.0
# Antibirth                                            NaN      94.0
# Mi America                                             R     125.0
# Sharkskin                                            NaN     100.0
# The Ghastly Love of Johnny X                   Not Rated     106.0
# Wind Walkers                                           R      93.0
# Down and Out with the Dolls                            R      88.0
# Certifiably Jonathan                                 NaN      85.0
# Departure                                            NaN     109.0
# The Last Big Thing                                     R      98.0
# Bang Bang Baby                                       NaN      90.0
# Elza                                                 NaN      78.0
# The Young Unknowns                                     R      87.0
# The Hadza: Last of the First                         NaN      71.0
# They Will Have to Kill Us First                      NaN     105.0
# Faith Connections                                    NaN     115.0
# Sholem Aleichem: Laughing in the Darkness        Unrated      93.0
# The Outrageous Sophie Tucker                         NaN      96.0
# Born to Fly: Elizabeth Streb vs. Gravity             NaN      82.0
# Censored Voices                                      NaN      84.0
# UnDivided                                             PG      66.0
# Give Me Shelter                                      NaN      90.0
# The Stewardesses                                       X      93.0
# Short Cut to Nirvana: Kumbh Mela                 Unrated      85.0
# Call + Response                                    PG-13      86.0
# Theresa Is a Mother                                  NaN     105.0
# Archaeology of a Woman                               NaN      94.0
# The Blood of My Brother                              NaN      90.0
# Over the Hill to the Poorhouse                       NaN     110.0
# Queen Crab                                           NaN      80.0
# Counting                                             NaN     111.0
# Bending Steel                                        NaN      92.0
# The Image Revolution                                 NaN      81.0
# Tin Can Man                                          NaN      83.0
# A Plague So Pleasant                                 NaN      76.0
#
#                                                    director_name  director_fb  \
# title
# Indignation                                        James Schamus         44.0
# Pete's Dragon                                       David Lowery         38.0
# Kicks                                             Justin Tipping          2.0
# Two Lovers and a Bear                                 Kim Nguyen         16.0
# Antibirth                                            Danny Perez          0.0
# Mi America                                       Robert Fontaine          7.0
# Sharkskin                                              Dan Perri          0.0
# The Ghastly Love of Johnny X                        Paul Bunnell          5.0
# Wind Walkers                                 Russell Friedenberg          9.0
# Down and Out with the Dolls                            Kurt Voss          0.0
# Certifiably Jonathan                       James David Pasternak          0.0
# Departure                                        Andrew Steggall          0.0
# The Last Big Thing                                   Dan Zukovic          8.0
# Bang Bang Baby                                 Jeffrey St. Jules          0.0
# Elza                                          Mariette Monpierre          0.0
# The Young Unknowns                              Catherine Jelski          0.0
# The Hadza: Last of the First                       Bill Benenson          0.0
# They Will Have to Kill Us First                 Johanna Schwartz          0.0
# Faith Connections                                      Pan Nalin         95.0
# Sholem Aleichem: Laughing in the Darkness          Joseph Dorman          0.0
# The Outrageous Sophie Tucker                     William Gazecki          3.0
# Born to Fly: Elizabeth Streb vs. Gravity          Catherine Gund          0.0
# Censored Voices                                       Mor Loushy          0.0
# UnDivided                                             Sam Martin          0.0
# Give Me Shelter                                    Kristin Rizzo         30.0
# The Stewardesses                                 Al Silliman Jr.          0.0
# Short Cut to Nirvana: Kumbh Mela                Maurizio Benazzo          0.0
# Call + Response                                    Justin Dillon          0.0
# Theresa Is a Mother                              C. Fraser Press          0.0
# Archaeology of a Woman                            Sharon Greytak          0.0
# The Blood of My Brother                           Andrew Berends          0.0
# Over the Hill to the Poorhouse                 Harry F. Millarde          0.0
# Queen Crab                                           Brett Piper          7.0
# Counting                                               Jem Cohen          6.0
# Bending Steel                                       Dave Carroll          0.0
# The Image Revolution                              Patrick Meaney          3.0
# Tin Can Man                                        Ivan Kavanagh         18.0
# A Plague So Pleasant                            Benjamin Roberds          0.0
#
#                                                            actor1  actor1_fb  \
# title
# Indignation                                          Logan Lerman     8000.0
# Pete's Dragon                                 Bryce Dallas Howard     3000.0
# Kicks                                                 Tina Gilton      861.0
# Two Lovers and a Bear                              Gordon Pinsent      149.0
# Antibirth                                          Natasha Lyonne     1000.0
# Mi America                                          Michael Derek      128.0
# Sharkskin                                            Travis Myers      749.0
# The Ghastly Love of Johnny X                         Kate Maberly      416.0
# Wind Walkers                                      Rudy Youngblood      708.0
# Down and Out with the Dolls                                 Lemmy      268.0
# Certifiably Jonathan                               Robin Williams    49000.0
# Departure                                        Juliet Stevenson      202.0
# The Last Big Thing                                    Yul Vazquez       96.0
# Bang Bang Baby                                         Boyd Banks       57.0
# Elza                                              Stana Roumillac        0.0
# The Young Unknowns                                    Leslie Bibb     1000.0
# The Hadza: Last of the First                        Alfre Woodard     1000.0
# They Will Have to Kill Us First                       Aliou Touré        0.0
# Faith Connections                                      Bhole Baba        0.0
# Sholem Aleichem: Laughing in the Darkness           Rachel Dratch      399.0
# The Outrageous Sophie Tucker                       Carol Channing      387.0
# Born to Fly: Elizabeth Streb vs. Gravity          Elizabeth Streb        0.0
# Censored Voices                                           Amos Oz        3.0
# UnDivided                                               Sam Adams        0.0
# Give Me Shelter                                      Esai Morales      699.0
# The Stewardesses                                   Christina Hart       12.0
# Short Cut to Nirvana: Kumbh Mela                   The Dalai Lama       66.0
# Call + Response                                         Matisyahu      178.0
# Theresa Is a Mother                                 Elaine Bromka      178.0
# Archaeology of a Woman                             Sally Kirkland      433.0
# The Blood of My Brother                                       NaN        NaN
# Over the Hill to the Poorhouse                       Stephen Carr        2.0
# Queen Crab                                 Michelle Simone Miller      118.0
# Counting                                                      NaN        NaN
# Bending Steel                              Chris 'Wonder' Schoeck        0.0
# The Image Revolution                               Taliesin Jaffe       26.0
# Tin Can Man                                     Patrick O'Donnell       10.0
# A Plague So Pleasant                                  Eva Boehnke        0.0
#
#                                                              actor2  \
# title
# Indignation                                             Sarah Gadon
# Pete's Dragon                                         Oona Laurence
# Kicks                                      Natalie Stephany Aguilar
# Two Lovers and a Bear                           Justin Edward Seale
# Antibirth                                          Emmanuel Kabongo
# Mi America                                            Arturo Castro
# Sharkskin                                              David Proval
# The Ghastly Love of Johnny X                         Kevin McCarthy
# Wind Walkers                                            Glen Powell
# Down and Out with the Dolls                          Coyote Shivers
# Certifiably Jonathan                                Sarah Silverman
# Departure                                              Alex Lawther
# The Last Big Thing                                   Louis Mustillo
# Bang Bang Baby                                           Chloe Rose
# Elza                                              Christophe Cherki
# The Young Unknowns                                      Eion Bailey
# The Hadza: Last of the First                            Dave Fennoy
# They Will Have to Kill Us First                         Garba Touré
# Faith Connections                                   Pant Shirt Baba
# Sholem Aleichem: Laughing in the Darkness             Peter Riegert
# The Outrageous Sophie Tucker                          Bruce Vilanch
# Born to Fly: Elizabeth Streb vs. Gravity               Sarah Callan
# Censored Voices                                                 NaN
# UnDivided                                                Steve Duin
# Give Me Shelter                                         Robert Davi
# The Stewardesses                                         Nancy Ison
# Short Cut to Nirvana: Kumbh Mela                       Jasper Johal
# Call + Response                                 Natasha Bedingfield
# Theresa Is a Mother                                   Robert Turano
# Archaeology of a Woman                                 Alex Emanuel
# The Blood of My Brother                                         NaN
# Over the Hill to the Poorhouse                       Johnnie Walker
# Queen Crab                                          Steve Diasparra
# Counting                                                        NaN
# Bending Steel                                                   NaN
# The Image Revolution                                 Greg Aronowitz
# Tin Can Man                                           Michael Parle
# A Plague So Pleasant                                  Maxwell Moody
#
#                                            actor2_fb  \
# title
# Indignation                                    691.0
# Pete's Dragon                                  424.0
# Kicks                                          163.0
# Two Lovers and a Bear                          147.0
# Antibirth                                      677.0
# Mi America                                      22.0
# Sharkskin                                      354.0
# The Ghastly Love of Johnny X                   403.0
# Wind Walkers                                   571.0
# Down and Out with the Dolls                     44.0
# Certifiably Jonathan                           931.0
# Departure                                       47.0
# The Last Big Thing                              71.0
# Bang Bang Baby                                  40.0
# Elza                                             0.0
# The Young Unknowns                             749.0
# The Hadza: Last of the First                   338.0
# They Will Have to Kill Us First                  0.0
# Faith Connections                                0.0
# Sholem Aleichem: Laughing in the Darkness      169.0
# The Outrageous Sophie Tucker                   244.0
# Born to Fly: Elizabeth Streb vs. Gravity         0.0
# Censored Voices                                  NaN
# UnDivided                                        0.0
# Give Me Shelter                                683.0
# The Stewardesses                                12.0
# Short Cut to Nirvana: Kumbh Mela                 0.0
# Call + Response                                 58.0
# Theresa Is a Mother                             32.0
# Archaeology of a Woman                         375.0
# The Blood of My Brother                          NaN
# Over the Hill to the Poorhouse                   2.0
# Queen Crab                                      15.0
# Counting                                         NaN
# Bending Steel                                    NaN
# The Image Revolution                            20.0
# Tin Can Man                                      5.0
# A Plague So Pleasant                             0.0
#
#                                                                   actor3  \
# title
# Indignation                                                  Tracy Letts
# Pete's Dragon                                         Isiah Whitlock Jr.
# Kicks                                                        Justin Hall
# Two Lovers and a Bear                                       John Ralston
# Antibirth                                                    Mark Webber
# Mi America                                                 Brad Lee Wind
# Sharkskin                                              Carmen Argenziano
# The Ghastly Love of Johnny X                               Paul Williams
# Wind Walkers                                                Kiowa Gordon
# Down and Out with the Dolls                               Zoë Poledouris
# Certifiably Jonathan                                    Jonathan Winters
# Departure                                                   Niamh Cusack
# The Last Big Thing                                          James Lorinz
# Bang Bang Baby                                            Kristian Bruun
# Elza                                                        Teddy Doloir
# The Young Unknowns                                            Arly Jover
# The Hadza: Last of the First                                Jane Goodall
# They Will Have to Kill Us First                              Khaira Arby
# Faith Connections                          Shriman Umeshanad Brahmachari
# Sholem Aleichem: Laughing in the Darkness                  Jason Kravits
# The Outrageous Sophie Tucker                                Tony Bennett
# Born to Fly: Elizabeth Streb vs. Gravity                  Laura Flanders
# Censored Voices                                                      NaN
# UnDivided                                                     Jeff Jacob
# Give Me Shelter                                           Elaine Hendrix
# The Stewardesses                                          William Condos
# Short Cut to Nirvana: Kumbh Mela                        Swami Krishnanad
# Call + Response                                       Madeleine Albright
# Theresa Is a Mother                                       Matthew Gumley
# Archaeology of a Woman                                     Elaine Bromka
# The Blood of My Brother                                              NaN
# Over the Hill to the Poorhouse                                 Mary Carr
# Queen Crab                                                  A.J. DeLucia
# Counting                                                             NaN
# Bending Steel                                                        NaN
# The Image Revolution                                           Jeff Dowd
# Tin Can Man                                             Emma Eliza Regan
# A Plague So Pleasant                                      David Chandler
#
#                                            actor3_fb      gross  \
# title
# Indignation                                     85.0   560512.0
# Pete's Dragon                                  190.0        NaN
# Kicks                                          102.0        NaN
# Two Lovers and a Bear                           63.0        NaN
# Antibirth                                      442.0        NaN
# Mi America                                      17.0     3330.0
# Sharkskin                                      338.0        NaN
# The Ghastly Love of Johnny X                   356.0     2436.0
# Wind Walkers                                   485.0        NaN
# Down and Out with the Dolls                      3.0    58936.0
# Certifiably Jonathan                           924.0     7826.0
# Departure                                       30.0        NaN
# The Last Big Thing                              14.0    22434.0
# Bang Bang Baby                                  36.0        NaN
# Elza                                             0.0        NaN
# The Young Unknowns                             258.0    58163.0
# The Hadza: Last of the First                    21.0        NaN
# They Will Have to Kill Us First                  0.0        NaN
# Faith Connections                                0.0        NaN
# Sholem Aleichem: Laughing in the Darkness       59.0   906666.0
# The Outrageous Sophie Tucker                   205.0        NaN
# Born to Fly: Elizabeth Streb vs. Gravity         0.0    21199.0
# Censored Voices                                  NaN    34151.0
# UnDivided                                        0.0        NaN
# Give Me Shelter                                670.0        NaN
# The Stewardesses                                 0.0        NaN
# Short Cut to Nirvana: Kumbh Mela                 0.0   381225.0
# Call + Response                                 15.0   215185.0
# Theresa Is a Mother                             27.0        NaN
# Archaeology of a Woman                         178.0        NaN
# The Blood of My Brother                          NaN        NaN
# Over the Hill to the Poorhouse                   0.0  3000000.0
# Queen Crab                                       3.0        NaN
# Counting                                         NaN        NaN
# Bending Steel                                    NaN        NaN
# The Image Revolution                            18.0        NaN
# Tin Can Man                                      0.0        NaN
# A Plague So Pleasant                             0.0        NaN
#
#                                                                           genres  \
# title
# Indignation                                                                Drama
# Pete's Dragon                                           Adventure|Family|Fantasy
# Kicks                                                                  Adventure
# Two Lovers and a Bear                                              Drama|Romance
# Antibirth                                                                 Horror
# Mi America                                                           Crime|Drama
# Sharkskin                                  Comedy|Drama|Mystery|Romance|Thriller
# The Ghastly Love of Johnny X                       Comedy|Fantasy|Musical|Sci-Fi
# Wind Walkers                                              Action|Horror|Thriller
# Down and Out with the Dolls                                         Comedy|Music
# Certifiably Jonathan                                          Comedy|Documentary
# Departure                                                   Drama|Family|Romance
# The Last Big Thing                                                  Comedy|Drama
# Bang Bang Baby                                              Drama|Musical|Sci-Fi
# Elza                                                                       Drama
# The Young Unknowns                                                         Drama
# The Hadza: Last of the First                                         Documentary
# They Will Have to Kill Us First                                      Documentary
# Faith Connections                                    Biography|Documentary|Drama
# Sholem Aleichem: Laughing in the Darkness                            Documentary
# The Outrageous Sophie Tucker                                         Documentary
# Born to Fly: Elizabeth Streb vs. Gravity      Action|Biography|Documentary|Sport
# Censored Voices                                              Documentary|History
# UnDivided                                                            Documentary
# Give Me Shelter                                                      Documentary
# The Stewardesses                                                    Comedy|Drama
# Short Cut to Nirvana: Kumbh Mela                                     Documentary
# Call + Response                                        Documentary|History|Music
# Theresa Is a Mother                                           Comedy|Drama|Music
# Archaeology of a Woman                                                     Drama
# The Blood of My Brother                                          Documentary|War
# Over the Hill to the Poorhouse                                       Crime|Drama
# Queen Crab                                                Action|Sci-Fi|Thriller
# Counting                                                             Documentary
# Bending Steel                                                        Documentary
# The Image Revolution                                       Biography|Documentary
# Tin Can Man                                                               Horror
# A Plague So Pleasant                                       Drama|Horror|Thriller
#
#                                            num_reviews  num_voted_users  \
# title
# Indignation                                       63.0              550
# Pete's Dragon                                     78.0              408
# Kicks                                              6.0               59
# Two Lovers and a Bear                              6.0               33
# Antibirth                                         10.0               63
# Mi America                                         4.0               22
# Sharkskin                                          1.0                6
# The Ghastly Love of Johnny X                      94.0              344
# Wind Walkers                                      27.0              133
# Down and Out with the Dolls                       12.0               91
# Certifiably Jonathan                              17.0              132
# Departure                                         29.0              162
# The Last Big Thing                                95.0              334
# Bang Bang Baby                                    16.0              137
# Elza                                               2.0               19
# The Young Unknowns                                13.0              122
# The Hadza: Last of the First                       1.0                5
# They Will Have to Kill Us First                   22.0               74
# Faith Connections                                 19.0              113
# Sholem Aleichem: Laughing in the Darkness         29.0              154
# The Outrageous Sophie Tucker                       9.0               38
# Born to Fly: Elizabeth Streb vs. Gravity          10.0               40
# Censored Voices                                   23.0              186
# UnDivided                                          1.0                6
# Give Me Shelter                                    6.0               37
# The Stewardesses                                  21.0              161
# Short Cut to Nirvana: Kumbh Mela                  15.0              131
# Call + Response                                    7.0               48
# Theresa Is a Mother                               13.0               37
# Archaeology of a Woman                             3.0               15
# The Blood of My Brother                           12.0              102
# Over the Hill to the Poorhouse                     1.0                5
# Queen Crab                                        18.0               48
# Counting                                          12.0               61
# Bending Steel                                     10.0               53
# The Image Revolution                               7.0               66
# Tin Can Man                                       12.0               57
# A Plague So Pleasant                              13.0               38
#
#                                                                                plot_keywords  \
# title
# Indignation                                                                   based on novel
# Pete's Dragon                                                                            NaN
# Kicks                                                                                    NaN
# Two Lovers and a Bear                                                                    NaN
# Antibirth                                                                                NaN
# Mi America                                                                               NaN
# Sharkskin                                                                                NaN
# The Ghastly Love of Johnny X                             1950s|independent film|outlaw|trial
# Wind Walkers                                                           after dark horrorfest
# Down and Out with the Dolls                female bassist|female drummer|female guitarist...
# Certifiably Jonathan                       las vegas nevada|museum|reference to mr. roger...
# Departure                                  france|gay|language|male masturbation|masturba...
# The Last Big Thing                                     actor|magazine|model|rock band|suburb
# Bang Bang Baby                                                                           NaN
# Elza                                                                          foreign|french
# The Young Unknowns                                            based on play|independent film
# The Hadza: Last of the First               east africa|hunter gatherer|indigenous|rift va...
# They Will Have to Kill Us First                                                          NaN
# Faith Connections                                   faith|ganja|kumbh mela|little boy|orphan
# Sholem Aleichem: Laughing in the Darkness                                    jewish identity
# The Outrageous Sophie Tucker                                                             NaN
# Born to Fly: Elizabeth Streb vs. Gravity                                    three word title
# Censored Voices                                                                          NaN
# UnDivided                                                                                NaN
# Give Me Shelter                                                             independent film
# The Stewardesses                           female frontal nudity|female nudity|lesbian se...
# Short Cut to Nirvana: Kumbh Mela                                                         NaN
# Call + Response                            fair trade|human trafficking|non profit|rockum...
# Theresa Is a Mother                                                                      NaN
# Archaeology of a Woman                                                                   NaN
# The Blood of My Brother                                     american|blood|dream|patrol|tank
# Over the Hill to the Poorhouse               family relationships|gang|idler|poorhouse|thief
# Queen Crab                                                                               NaN
# Counting                                         city|city symphony|diary|essay|surveillance
# Bending Steel                                                                            NaN
# The Image Revolution                       comic book|comic book history|comics|spawn|wal...
# Tin Can Man                                                                              NaN
# A Plague So Pleasant                                                                     NaN
#
#                                           language  country      budget  \
# title
# Indignation                                 Hebrew      USA         NaN
# Pete's Dragon                              English      USA  65000000.0
# Kicks                                      English      USA         NaN
# Two Lovers and a Bear                      English   Canada   8700000.0
# Antibirth                                  English      USA   3500000.0
# Mi America                                 English      USA   2100000.0
# Sharkskin                                  English      USA   2100000.0
# The Ghastly Love of Johnny X               English      USA   2000000.0
# Wind Walkers                               English      USA   2000000.0
# Down and Out with the Dolls                English      USA   1200000.0
# Certifiably Jonathan                       English      USA   1200000.0
# Departure                                  English       UK   1100000.0
# The Last Big Thing                         English      USA         NaN
# Bang Bang Baby                             English   Canada   1000000.0
# Elza                                        French   France    900000.0
# The Young Unknowns                         English      USA         NaN
# The Hadza: Last of the First               English      USA    650000.0
# They Will Have to Kill Us First             French       UK    400000.0
# Faith Connections                            Hindi    India    550000.0
# Sholem Aleichem: Laughing in the Darkness  English      USA    500000.0
# The Outrageous Sophie Tucker               English      USA    500000.0
# Born to Fly: Elizabeth Streb vs. Gravity   English      USA    500000.0
# Censored Voices                             Hebrew   Israel    450000.0
# UnDivided                                  English      USA    250000.0
# Give Me Shelter                            English      USA    250000.0
# The Stewardesses                           English      USA    100000.0
# Short Cut to Nirvana: Kumbh Mela           English      USA    200000.0
# Call + Response                            English      USA    200000.0
# Theresa Is a Mother                        English      USA    200000.0
# Archaeology of a Woman                     English      USA    200000.0
# The Blood of My Brother                    English      USA    120000.0
# Over the Hill to the Poorhouse                 NaN      USA    100000.0
# Queen Crab                                 English      USA     75000.0
# Counting                                   English      USA     50000.0
# Bending Steel                              English      USA     50000.0
# The Image Revolution                       English      USA     50000.0
# Tin Can Man                                English  Ireland     10000.0
# A Plague So Pleasant                       English      USA      1400.0
#
#                                            imdb_score
# title
# Indignation                                       7.8
# Pete's Dragon                                     7.3
# Kicks                                             7.8
# Two Lovers and a Bear                             7.2
# Antibirth                                         6.3
# Mi America                                        7.2
# Sharkskin                                         6.7
# The Ghastly Love of Johnny X                      5.7
# Wind Walkers                                      3.6
# Down and Out with the Dolls                       6.1
# Certifiably Jonathan                              6.2
# Departure                                         7.0
# The Last Big Thing                                6.9
# Bang Bang Baby                                    5.4
# Elza                                              6.7
# The Young Unknowns                                4.2
# The Hadza: Last of the First                      7.4
# They Will Have to Kill Us First                   7.7
# Faith Connections                                 7.0
# Sholem Aleichem: Laughing in the Darkness         6.8
# The Outrageous Sophie Tucker                      7.2
# Born to Fly: Elizabeth Streb vs. Gravity          6.8
# Censored Voices                                   7.2
# UnDivided                                         7.8
# Give Me Shelter                                   8.0
# The Stewardesses                                  4.0
# Short Cut to Nirvana: Kumbh Mela                  7.2
# Call + Response                                   7.5
# Theresa Is a Mother                               6.7
# Archaeology of a Woman                            8.1
# The Blood of My Brother                           6.6
# Over the Hill to the Poorhouse                    4.8
# Queen Crab                                        4.5
# Counting                                          6.0
# Bending Steel                                     7.9
# The Image Revolution                              7.4
# Tin Can Man                                       6.7
# A Plague So Pleasant                              6.3

# %% [markdown]
# ### Exercise 6
#
# <span  style="color:green; font-size:16px">Select all the movies made in the 1990's that were rated R with an IMDB score greater than 8.</span>

# %%
movie.query('1990 >= year <= 1999 and content_rating == "R" and imdb_score > 8')
# Out:
#                                    year            color content_rating  \
# title
# The Thing                        1982.0            Color              R
# Apocalypse Now                   1979.0            Color              R
# Once Upon a Time in America      1984.0            Color              R
# Die Hard                         1988.0            Color              R
# Blade Runner                     1982.0            Color              R
# Goodfellas                       1990.0            Color              R
# Scarface                         1983.0            Color              R
# Psycho                           1960.0  Black and White              R
# The Shining                      1980.0            Color              R
# Amadeus                          1984.0            Color              R
# Raging Bull                      1980.0  Black and White              R
# Aliens                           1986.0            Color              R
# The Deer Hunter                  1978.0            Color              R
# The Godfather: Part II           1974.0            Color              R
# Das Boot                         1981.0            Color              R
# Alien                            1979.0            Color              R
# Stand by Me                      1986.0            Color              R
# Akira                            1988.0            Color              R
# The Godfather                    1972.0            Color              R
# The Terminator                   1984.0            Color              R
# Platoon                          1986.0            Color              R
# One Flew Over the Cuckoo's Nest  1975.0            Color              R
# Network                          1976.0            Color              R
# Taxi Driver                      1976.0            Color              R
# The Conformist                   1970.0            Color              R
# Woodstock                        1970.0            Color              R
# Cries & Whispers                 1972.0            Color              R
#
#                                  duration         director_name  director_fb  \
# title
# The Thing                           109.0        John Carpenter          0.0
# Apocalypse Now                      289.0  Francis Ford Coppola          0.0
# Once Upon a Time in America         251.0          Sergio Leone          0.0
# Die Hard                            131.0        John McTiernan        323.0
# Blade Runner                        117.0          Ridley Scott          0.0
# Goodfellas                          146.0       Martin Scorsese      17000.0
# Scarface                            142.0        Brian De Palma          0.0
# Psycho                              108.0      Alfred Hitchcock      13000.0
# The Shining                         146.0       Stanley Kubrick          0.0
# Amadeus                             180.0          Milos Forman        869.0
# Raging Bull                         121.0       Martin Scorsese      17000.0
# Aliens                              154.0         James Cameron          0.0
# The Deer Hunter                     183.0        Michael Cimino        517.0
# The Godfather: Part II              220.0  Francis Ford Coppola          0.0
# Das Boot                            293.0     Wolfgang Petersen        249.0
# Alien                               116.0          Ridley Scott          0.0
# Stand by Me                          89.0            Rob Reiner          0.0
# Akira                               124.0       Katsuhiro Ôtomo         78.0
# The Godfather                       175.0  Francis Ford Coppola          0.0
# The Terminator                      107.0         James Cameron          0.0
# Platoon                             120.0          Oliver Stone          0.0
# One Flew Over the Cuckoo's Nest     133.0          Milos Forman        869.0
# Network                             121.0          Sidney Lumet          0.0
# Taxi Driver                         110.0       Martin Scorsese      17000.0
# The Conformist                      106.0   Bernardo Bertolucci        973.0
# Woodstock                           215.0      Michael Wadleigh         14.0
# Cries & Whispers                     91.0        Ingmar Bergman          0.0
#
#                                                  actor1  actor1_fb  \
# title
# The Thing                               Wilford Brimley      957.0
# Apocalypse Now                            Harrison Ford    11000.0
# Once Upon a Time in America              Robert De Niro    22000.0
# Die Hard                                   Alan Rickman    25000.0
# Blade Runner                              Harrison Ford    11000.0
# Goodfellas                               Robert De Niro    22000.0
# Scarface                                      Al Pacino    14000.0
# Psycho                                      Janet Leigh      606.0
# The Shining                            Scatman Crothers      888.0
# Amadeus                                   Jeffrey Jones      692.0
# Raging Bull                              Robert De Niro    22000.0
# Aliens                                    Michael Biehn     2000.0
# The Deer Hunter                          Robert De Niro    22000.0
# The Godfather: Part II                   Robert De Niro    22000.0
# Das Boot                                Jürgen Prochnow      362.0
# Alien                                      Tom Skerritt     1000.0
# Stand by Me                               Marshall Bell      217.0
# Akira                                      Mitsuo Iwata        6.0
# The Godfather                                 Al Pacino    14000.0
# The Terminator                            Michael Biehn     2000.0
# Platoon                                     Johnny Depp    40000.0
# One Flew Over the Cuckoo's Nest        Scatman Crothers      888.0
# Network                                   Robert Duvall     3000.0
# Taxi Driver                              Robert De Niro    22000.0
# The Conformist                   Jean-Louis Trintignant      319.0
# Woodstock                                    Joe Cocker      262.0
# Cries & Whispers                            Liv Ullmann      440.0
#
#                                              actor2  actor2_fb  \
# title
# The Thing                             Richard Masur      163.0
# Apocalypse Now                        Marlon Brando    10000.0
# Once Upon a Time in America              Burt Young      683.0
# Die Hard                               Bruce Willis    13000.0
# Blade Runner                             Sean Young      759.0
# Goodfellas                               Mike Starr      854.0
# Scarface                          F. Murray Abraham      670.0
# Psycho                                   Vera Miles      332.0
# The Shining                          Shelley Duvall      629.0
# Amadeus                           F. Murray Abraham      670.0
# Raging Bull                          Cathy Moriarty      394.0
# Aliens                                  Carrie Henn      626.0
# The Deer Hunter                        Meryl Streep    11000.0
# The Godfather: Part II                    Al Pacino    14000.0
# Das Boot                         Martin Semmelrogge       21.0
# Alien                                  Yaphet Kotto      581.0
# Stand by Me                      Frances Lee McCain      107.0
# Akira                                 Takeshi Kusao        5.0
# The Godfather                         Marlon Brando    10000.0
# The Terminator                       Brian Thompson      663.0
# Platoon                                Tom Berenger      854.0
# One Flew Over the Cuckoo's Nest    Michael Berryman      721.0
# Network                                Faye Dunaway      977.0
# Taxi Driver                           Albert Brooks      745.0
# The Conformist                   Stefania Sandrelli       90.0
# Woodstock                              Jimi Hendrix      227.0
# Cries & Whispers                      Ingrid Thulin      132.0
#
#                                                       actor3  actor3_fb  \
# title
# The Thing                                      David Clennon      145.0
# Apocalypse Now                                 Robert Duvall     3000.0
# Once Upon a Time in America                   Treat Williams      642.0
# Die Hard                                 Reginald VelJohnson      541.0
# Blade Runner                                  M. Emmet Walsh      521.0
# Goodfellas                                      Paul Sorvino      635.0
# Scarface                         Mary Elizabeth Mastrantonio      638.0
# Psycho                                            John Gavin      285.0
# The Shining                                       Joe Turkel      413.0
# Amadeus                                            Tom Hulce      521.0
# Raging Bull                                    Frank Vincent      356.0
# Aliens                                     Jenette Goldstein      604.0
# The Deer Hunter                                  John Savage      652.0
# The Godfather: Part II                         Robert Duvall     3000.0
# Das Boot                                  Herbert Grönemeyer       18.0
# Alien                                          Bolaji Badejo      513.0
# Stand by Me                                  Casey Siemaszko      107.0
# Akira                                           Tesshô Genda        4.0
# The Godfather                                  Robert Duvall     3000.0
# The Terminator                                 Paul Winfield      255.0
# Platoon                                         Kevin Dillon      576.0
# One Flew Over the Cuckoo's Nest              Louise Fletcher      425.0
# Network                                       William Holden      682.0
# Taxi Driver                                      Peter Boyle      595.0
# The Conformist                               Dominique Sanda       48.0
# Woodstock                                          Joan Baez      136.0
# Cries & Whispers                            Erland Josephson       92.0
#
#                                        gross                         genres  \
# title
# The Thing                         13782838.0          Horror|Mystery|Sci-Fi
# Apocalypse Now                    78800000.0                      Drama|War
# Once Upon a Time in America        5300000.0                    Crime|Drama
# Die Hard                          81350242.0                Action|Thriller
# Blade Runner                      27000000.0                Sci-Fi|Thriller
# Goodfellas                        46836394.0          Biography|Crime|Drama
# Scarface                          44700000.0                    Crime|Drama
# Psycho                            32000000.0        Horror|Mystery|Thriller
# The Shining                              NaN                   Drama|Horror
# Amadeus                           51600000.0  Biography|Drama|History|Music
# Raging Bull                          45250.0          Biography|Drama|Sport
# Aliens                            85200000.0        Action|Adventure|Sci-Fi
# The Deer Hunter                          NaN                      Drama|War
# The Godfather: Part II            57300000.0                    Crime|Drama
# Das Boot                          11433134.0   Adventure|Drama|Thriller|War
# Alien                             78900000.0                  Horror|Sci-Fi
# Stand by Me                       52287414.0                Adventure|Drama
# Akira                               439162.0        Action|Animation|Sci-Fi
# The Godfather                    134821952.0                    Crime|Drama
# The Terminator                    38400000.0                  Action|Sci-Fi
# Platoon                          137963328.0                      Drama|War
# One Flew Over the Cuckoo's Nest  112000000.0                          Drama
# Network                                  NaN                  Drama|Romance
# Taxi Driver                              NaN                    Crime|Drama
# The Conformist                           NaN                          Drama
# Woodstock                         13300000.0      Documentary|History|Music
# Cries & Whispers                         NaN                          Drama
#
#                                  num_reviews  num_voted_users  \
# title
# The Thing                              297.0           258078
# Apocalypse Now                         261.0           450676
# Once Upon a Time in America            111.0           221000
# Die Hard                               233.0           592582
# Blade Runner                           302.0           461609
# Goodfellas                             192.0           728685
# Scarface                               147.0           537442
# Psycho                                 290.0           422432
# The Shining                            253.0           610333
# Amadeus                                134.0           270790
# Raging Bull                            151.0           235133
# Aliens                                 250.0           488537
# The Deer Hunter                        140.0           232577
# The Godfather: Part II                 149.0           790926
# Das Boot                                96.0           168203
# Alien                                  392.0           563827
# Stand by Me                             99.0           271794
# Akira                                  150.0           106160
# The Godfather                          208.0          1155770
# The Terminator                         204.0           600266
# Platoon                                120.0           291603
# One Flew Over the Cuckoo's Nest        149.0           680041
# Network                                161.0           103493
# Taxi Driver                            211.0           507063
# The Conformist                         120.0            17813
# Woodstock                               53.0            12631
# Cries & Whispers                        76.0            19964
#
#                                                                      plot_keywords  \
# title
# The Thing                        alien creature|alien life form|antarctica|isol...
# Apocalypse Now                            army|green beret|insanity|jungle|vietnam
# Once Upon a Time in America      1920s|ambiguity|childhood friend|new york|spea...
# Die Hard                         christmas|christmas eve|christmas party|held a...
# Blade Runner                     artificial intelligence|human android relation...
# Goodfellas                         betrayal|gangster|mafia|organized crime|robbery
# Scarface                         assassination attempt|capitalism|cocaine|cuban...
# Psycho                                               money|motel|rain|shower|theft
# The Shining                      breaking down a door|haunted hotel|identical t...
# Amadeus                          1800s|classical composer|composer|first person...
# Raging Bull                      boxing|domestic violence|hot temper|jealousy|rage
# Aliens                           alien|human versus alien|monster|rescue missio...
# The Deer Hunter                    escape|friend|party|pittsburgh steelers|vietnam
# The Godfather: Part II           1950s|corrupt politician|lake tahoe nevada|mel...
# Das Boot                             duty|submarine|submarine movie|tension|u boat
# Alien                                  alien|creature|future|outer space|spaceship
# Stand by Me                      friendship|summertime|treehouse|walking on tra...
# Akira                            based on manga|biker gang|gifted child|post th...
# The Godfather                    crime family|mafia|organized crime|patriarch|r...
# The Terminator                   cyborg|future war|robot|shootout in a police s...
# Platoon                                1960s|famous score|hero|vietnam|vietnam war
# One Flew Over the Cuckoo's Nest    1960s|escape|mental institution|nurse|sexuality
# Network                          media|monologue|television|television network|...
# Taxi Driver                       loner|neo noir|night shift|taxi driver|vigilante
# The Conformist                                  fascist|gun|italy|nudity|sexuality
# Woodstock                            drugs|hippie|music festival|the who|woodstock
# Cries & Whispers                 dying|love|mansion|selfishness|turn of the cen...
#
#                                  language       country        budget  \
# title
# The Thing                         English           USA  1.500000e+07
# Apocalypse Now                    English           USA  3.150000e+07
# Once Upon a Time in America       English         Italy  3.000000e+07
# Die Hard                          English           USA  2.800000e+07
# Blade Runner                      English           USA  2.800000e+07
# Goodfellas                        English           USA  2.500000e+07
# Scarface                          English           USA  2.500000e+07
# Psycho                            English           USA  8.069470e+05
# The Shining                       English           USA  1.900000e+07
# Amadeus                           English           USA  1.800000e+07
# Raging Bull                       English           USA  1.800000e+07
# Aliens                            English           USA  1.850000e+07
# The Deer Hunter                   English            UK  1.500000e+07
# The Godfather: Part II            English           USA  1.300000e+07
# Das Boot                           German  West Germany  1.400000e+07
# Alien                             English            UK  1.100000e+07
# Stand by Me                       English           USA  8.000000e+06
# Akira                            Japanese         Japan  1.100000e+09
# The Godfather                     English           USA  6.000000e+06
# The Terminator                    English            UK  6.500000e+06
# Platoon                           English            UK  6.000000e+06
# One Flew Over the Cuckoo's Nest   English           USA  4.400000e+06
# Network                           English           USA  3.800000e+06
# Taxi Driver                       English           USA  1.300000e+06
# The Conformist                    Italian         Italy  7.500000e+05
# Woodstock                         English           USA  6.000000e+05
# Cries & Whispers                  Swedish        Sweden  4.000000e+05
#
#                                  imdb_score
# title
# The Thing                               8.2
# Apocalypse Now                          8.5
# Once Upon a Time in America             8.4
# Die Hard                                8.2
# Blade Runner                            8.2
# Goodfellas                              8.7
# Scarface                                8.3
# Psycho                                  8.5
# The Shining                             8.4
# Amadeus                                 8.3
# Raging Bull                             8.3
# Aliens                                  8.4
# The Deer Hunter                         8.2
# The Godfather: Part II                  9.0
# Das Boot                                8.4
# Alien                                   8.5
# Stand by Me                             8.1
# Akira                                   8.1
# The Godfather                           9.2
# The Terminator                          8.1
# Platoon                                 8.1
# One Flew Over the Cuckoo's Nest         8.7
# Network                                 8.1
# Taxi Driver                             8.3
# The Conformist                          8.1
# Woodstock                               8.1
# Cries & Whispers                        8.2
