# %% [markdown]
# # Boolean Selection Multiple Conditions
#
# Thus far, our boolean selections involved just a single condition. It is possible to have as many conditions as you would like. To do so, you will need to combine your boolean expressions using the three logical operators, and, or, and not.
#
# ## Logical operators
#
# Core Python provides the logical operators `and`, `or`, and `not` to combine multiple conditions together. These operators always return a boolean value. Let's take a look at a few simple examples to review.
#
# We begin by testing whether five is greater than three and that 10 is greater than 20. There are two conditions here, with the first evaluating as `True` and the second as `False`. The `and` operator only returns `True` if both conditions are `True`, so in this case it returns `False`.

# %%
5 > 3 and 10 > 20
# Out:
# False

# %% [markdown]
# Let's keep the same conditions and change the logical operator to `or` which returns `True` if one or more of the conditions evaluate as `True`.

# %%
5 > 3 or 10 > 20
# Out:
# True

# %% [markdown]
# The `not` operator inverts a condition. Below, we invert the last expression. Because `not` has higher precedence than `or`, we use parentheses to ensure the `or` condition is evaluated first.

# %%
not (5 > 3 or 10 > 20)
# Out:
# False

# %% [markdown]
# ### Different logical operators for boolean Series
#
# These built-in logical operators do not work for creating multiple conditions with a boolean Series. Instead, you must use the following operators.
#
# * `&` for and (ampersand character)
# * `|` for or (pipe character)
# * `~` for not (tilde character)
#
# Let's use the bikes dataset to make our multiple condition queries.

# %%
import pandas as pd
bikes = pd.read_csv('../data/bikes.csv')
bikes.head(3)
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
#
#               from_station_name  start_capacity          to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 2          23.0         73.0        16.1  mostlycloudy

# %% [markdown]
# ### Our first multiple condition expression
#
# Let's find all the rides longer than 1,000 seconds by males. This query has two conditions - trip durations greater than 1,000 and a gender of 'Male'. The way we approach the problem is to assign each condition to a separate variable. Since we desire both of the conditions to be true, we must use the and (`&`) operator. Each single condition is placed on its own line before using the `&` operator to create the final filter that completes the boolean selection.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Male'
filt = filt1 & filt2
bikes[filt].head(3)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 2    Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 8    Male  2013-07-03 15:21:00  2013-07-03 15:42:00          1300
# 10   Male  2013-07-04 17:17:00  2013-07-04 17:42:00          1523
#
#                from_station_name  start_capacity          to_station_name  \
# 2   Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 8   Clinton St & Washington Blvd            31.0    Wood St & Division St
# 10           Morgan St & 18th St            15.0   Damen Ave & Pierce Ave
#
#     end_capacity  temperature  wind_speed        events
# 2           23.0         73.0        16.1  mostlycloudy
# 8           15.0         71.1         0.0        cloudy
# 10          19.0         79.0         9.2  mostlycloudy

# %% [markdown]
# ## Multiple conditions in one line
#
# It is possible to combine the entire expression into a single line. Many pandas users like doing this, so it is a good idea to know how it's done as you will definitely encounter it.
#
# ### Use parentheses to separate conditions
#
# You must encapsulate each condition within a set of parentheses in order to make this work. Each condition is separated like this:
#
# ```python
# (bikes['tripduration'] > 1000) & (bikes['events'] == 'cloudy')
# ```
#
# ### Same results
#
# The above expression is placed inside of *just the brackets* to get the same results. Again, I prefer assigning each condition to its own variable name for better readability.

# %%
bikes[(bikes['tripduration'] > 1000) & (bikes['gender'] == 'Male')].head(3)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 2    Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 8    Male  2013-07-03 15:21:00  2013-07-03 15:42:00          1300
# 10   Male  2013-07-04 17:17:00  2013-07-04 17:42:00          1523
#
#                from_station_name  start_capacity          to_station_name  \
# 2   Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
# 8   Clinton St & Washington Blvd            31.0    Wood St & Division St
# 10           Morgan St & 18th St            15.0   Damen Ave & Pierce Ave
#
#     end_capacity  temperature  wind_speed        events
# 2           23.0         73.0        16.1  mostlycloudy
# 8           15.0         71.1         0.0        cloudy
# 10          19.0         79.0         9.2  mostlycloudy

# %% [markdown]
# ## Using an `or` condition
#
# Let's find all the rides that were done by females **or** had trip durations longer than 1,000 seconds. In this example, we need at least one of the conditions to be true, which necessitates the use of the or (`|`) operator.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Female'
filt = filt1 | filt2
bikes[filt].head(3)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 2    Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 8    Male  2013-07-03 15:21:00  2013-07-03 15:42:00          1300
# 9  Female  2013-07-04 15:00:00  2013-07-04 15:16:00           922
#
#                from_station_name  start_capacity             to_station_name  \
# 2   Sheffield Ave & Kingsbury St            15.0     Dearborn St & Monroe St
# 8   Clinton St & Washington Blvd            31.0       Wood St & Division St
# 9  Lakeview Ave & Fullerton Pkwy            19.0  Racine Ave & Congress Pkwy
#
#    end_capacity  temperature  wind_speed        events
# 2          23.0         73.0        16.1  mostlycloudy
# 8          15.0         71.1         0.0        cloudy
# 9          19.0         81.0        12.7  mostlycloudy

# %% [markdown]
# ## Inverting a condition with the not operator
#
# The tilde character, `~`, represents the not operator and inverts a condition. For instance, if we wanted all the rides with trip duration less than or equal to 1,000, we could do it like this:

# %%
filt = bikes['tripduration'] > 1000
bikes[~filt].head(3)
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 3   Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
#
#               from_station_name  start_capacity         to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0   Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0    Wells St & Walton St
# 3       Carpenter St & Huron St            19.0  Clark St & Randolph St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 3          31.0         72.0        16.1  mostlycloudy

# %% [markdown]
# Of course, inverting a single conditions like this isn't too useful as we can use the less than or equal to operator instead.

# %%
filt = bikes['tripduration'] <= 1000
bikes[filt].head(3)

# %% [markdown]
# ### Invert a more complex condition
#
# Typically, we reserve the not operator for inverting more complex conditions. Let's invert the condition for selecting rides by females or those with duration over 1,000 seconds. Logically, this should return only male riders with duration 1,000 or less. The `~` operator has precedence over the `|` operator, so we use parentheses to ensure that the or operation is completed first. That result is then inverted.

# %%
filt1 = bikes['tripduration'] > 1000
filt2 = bikes['gender'] == 'Female'
filt = ~(filt1 | filt2)
bikes[filt].head(3)
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 3   Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
#
#               from_station_name  start_capacity         to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0   Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0    Wells St & Walton St
# 3       Carpenter St & Huron St            19.0  Clark St & Randolph St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 3          31.0         72.0        16.1  mostlycloudy

# %%
new = bikes[filt]
new.

# %%
new['gender'].value_counts()
# Out:
# Male    30759
# Name: gender, dtype: int64

# %%
bikes['gender'].value_counts()
# Out:
# Male      37654
# Female    12435
# Name: gender, dtype: int64

# %% [markdown]
# ### Even more complex conditions
#
# It is possible to build extremely complex conditions to select rows of your DataFrame that meet a very specific query. For instance, we can select males riders with trip duration between 5,000 and 10,000 seconds along with female riders with trip duration between 2,000 and 3,000 seconds. With multiple conditions, it's probably best to break out the logic into multiple steps:

# %%
filt1 = ((bikes['gender'] == 'Male') &
         (bikes['tripduration'] >= 5000) &
         (bikes['tripduration'] <= 10000))

filt2 = ((bikes['gender'] == 'Female') &
         (bikes['tripduration'] >= 2000) &
         (bikes['tripduration'] <= 3000))
filt = filt1 | filt2
bikes[filt].head(3)
# Out:
#      gender            starttime             stoptime  tripduration  \
# 18     Male  2013-07-09 13:12:00  2013-07-09 14:42:00          5396
# 173  Female  2013-08-08 08:49:00  2013-08-08 09:31:00          2502
# 258  Female  2013-08-17 22:10:00  2013-08-17 22:53:00          2566
#
#               from_station_name  start_capacity         to_station_name  \
# 18      Canal St & Jackson Blvd            35.0         Millennium Park
# 173  Sheffield Ave & Addison St            27.0  Dearborn St & Adams St
# 258             Millennium Park            35.0     Theater on the Lake
#
#      end_capacity  temperature  wind_speed        events
# 18           35.0         79.0        13.8        cloudy
# 173          19.0         71.1        10.4  mostlycloudy
# 258          15.0         69.1         5.8         clear

# %% [markdown]
# ## Many equality conditions in a single column
#
# Occasionally, we want to test equality in a single column with multiple values. This is most common in string columns. For instance, let's say we wanted to find all the rides where the events were either 'rain', 'snow', 'tstorms', or 'sleet'. One way to do this would be with four or conditions.

# %%
filt = ((bikes['events'] == 'rain') | 
        (bikes['events'] == 'snow') | 
        (bikes['events'] == 'tstorms') | 
        (bikes['events'] == 'sleet'))
bikes[filt].head(3)
# Out:
#    gender            starttime             stoptime  tripduration  \
# 45   Male  2013-07-15 16:43:00  2013-07-15 16:55:00           727
# 78   Male  2013-07-21 16:35:00  2013-07-21 17:06:00          1809
# 79   Male  2013-07-21 16:47:00  2013-07-21 17:03:00           999
#
#             from_station_name  start_capacity          to_station_name  \
# 45    Greenwood Ave & 47th St            15.0   State St & Harrison St
# 78  Michigan Ave & Pearson St            23.0          Millennium Park
# 79    Carpenter St & Huron St            19.0  Carpenter St & Huron St
#
#     end_capacity  temperature  wind_speed   events
# 45          19.0         82.9         5.8     rain
# 78          35.0         82.4        11.5  tstorms
# 79          19.0         82.4        11.5  tstorms

# %% [markdown]
# ### Use the `isin` method instead
#
# Instead of using an operator, we use the `isin` method. Pass it a list (or a set) of all the values you want to test equality with. The `isin` method returns a boolean Series and in this example, the same exact boolean Series as the previous one.

# %%
filt = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
bikes[filt].head(3)

# %% [markdown]
# ### Combining `isin` with other filters
#
# You can use the resulting boolean Series from the `isin` method in the same way as you would from the logical operators. For instance, If we wanted to find all the rides that had the same events as above and had a duration greater than 2,000 we would do the following:

# %%
filt1 = bikes['events'].isin(['rain', 'snow', 'tstorms', 'sleet'])
filt2 = bikes['tripduration'] > 2000
filt = filt1 & filt2
bikes[filt].head(3)

# %% [markdown]
# ## Exercises
#
# Continue to use the bikes dataset for the first few exercises.

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">Find all the rides where temperature was between 0 and 2.</span>

# %%
bikes.head(3)
# Out:
#   gender            starttime             stoptime  tripduration  \
# 0   Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1   Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2   Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
#
#               from_station_name  start_capacity          to_station_name  \
# 0     Lake Shore Dr & Monroe St            11.0    Michigan Ave & Oak St
# 1  Clinton St & Washington Blvd            31.0     Wells St & Walton St
# 2  Sheffield Ave & Kingsbury St            15.0  Dearborn St & Monroe St
#
#    end_capacity  temperature  wind_speed        events
# 0          15.0         73.9        12.7  mostlycloudy
# 1          19.0         69.1         6.9  partlycloudy
# 2          23.0         73.0        16.1  mostlycloudy

# %%
filt = (bikes['temperature'] >= 0) & (bikes['temperature'] <= 2)
bikes[filt].head()
# Out:
#       gender            starttime             stoptime  tripduration  \
# 1870  Female  2013-12-11 21:13:00  2013-12-11 21:19:00           347
# 1938    Male  2013-12-23 22:29:00  2013-12-23 22:37:00           455
# 2039    Male  2014-01-21 08:48:00  2014-01-21 09:13:00          1547
# 2040    Male  2014-01-21 08:50:00  2014-01-21 08:57:00           388
# 2043    Male  2014-01-21 19:28:00  2014-01-21 19:41:00           806
#
#               from_station_name  start_capacity             to_station_name  \
# 1870  Southport Ave & Roscoe St            19.0      Ashland Ave & Grace St
# 1938      State St & Pearson St            27.0      Clark St & Schiller St
# 2039     Damen Ave & Pierce Ave            19.0  Franklin St & Jackson Blvd
# 2040      Canal St & Madison St            23.0     Dearborn St & Monroe St
# 2043     Michigan Ave & 18th St            15.0       Indiana Ave & 31st St
#
#       end_capacity  temperature  wind_speed        events
# 1870          15.0          1.9        10.4         clear
# 1938          19.0         -0.0        15.0  partlycloudy
# 2039          31.0          1.9        19.6  partlycloudy
# 2040          27.0          1.9        19.6  partlycloudy
# 2043          11.0          1.9         8.1  mostlycloudy

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">Find all the rides with trip duration less than 100 done by females.</span>

# %%
filt1= bikes['tripduration'] < 100
filt2= bikes['gender'] == 'Female'
filt = filt1 & filt2
bikes[filt].head()
# Out:
#       gender            starttime             stoptime  tripduration  \
# 2485  Female  2014-04-01 15:43:00  2014-04-01 15:44:00            67
# 3366  Female  2014-05-17 14:55:00  2014-05-17 14:56:00            62
# 3629  Female  2014-05-27 07:55:00  2014-05-27 07:56:00            70
# 4665  Female  2014-06-25 17:01:00  2014-06-25 17:02:00            94
# 4930  Female  2014-07-01 21:36:00  2014-07-01 21:37:00            77
#
#             from_station_name  start_capacity          to_station_name  \
# 2485     Halsted St & Polk St            19.0     Halsted St & Polk St
# 3366  Damen Ave & Chicago Ave            15.0  Damen Ave & Chicago Ave
# 3629   Clark St & Schiller St            19.0   Clark St & Schiller St
# 4665   Broadway & Sheridan Rd            15.0   Broadway & Sheridan Rd
# 4930  Clinton St & Madison St            23.0  Clinton St & Madison St
#
#       end_capacity  temperature  wind_speed        events
# 2485          19.0         46.0        23.0  partlycloudy
# 3366          15.0         57.9        11.5  partlycloudy
# 3629          19.0         73.0         9.2        cloudy
# 4665          15.0         64.9        13.8        cloudy
# 4930          23.0         73.0         8.1  partlycloudy

# %%
bikes[(bikes['tripduration'] < 100) & (bikes['gender'] == 'Female')].head(2)
# Out:
#       gender            starttime             stoptime  tripduration  \
# 2485  Female  2014-04-01 15:43:00  2014-04-01 15:44:00            67
# 3366  Female  2014-05-17 14:55:00  2014-05-17 14:56:00            62
#
#             from_station_name  start_capacity          to_station_name  \
# 2485     Halsted St & Polk St            19.0     Halsted St & Polk St
# 3366  Damen Ave & Chicago Ave            15.0  Damen Ave & Chicago Ave
#
#       end_capacity  temperature  wind_speed        events
# 2485          19.0         46.0        23.0  partlycloudy
# 3366          15.0         57.9        11.5  partlycloudy

# %%
bikes[(filt1 & filt2)].head(2)
# Out:
#       gender            starttime             stoptime  tripduration  \
# 2485  Female  2014-04-01 15:43:00  2014-04-01 15:44:00            67
# 3366  Female  2014-05-17 14:55:00  2014-05-17 14:56:00            62
#
#             from_station_name  start_capacity          to_station_name  \
# 2485     Halsted St & Polk St            19.0     Halsted St & Polk St
# 3366  Damen Ave & Chicago Ave            15.0  Damen Ave & Chicago Ave
#
#       end_capacity  temperature  wind_speed        events
# 2485          19.0         46.0        23.0  partlycloudy
# 3366          15.0         57.9        11.5  partlycloudy

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">Find all the rides from 'Daley Center Plaza' to 'Michigan Ave &amp; Washington St'.</span>

# %%
filt = (bikes['from_station_name'] == 'Daley Center Plaza') & (bikes['to_station_name'] == 'Michigan Ave & Washington St')

bikes[filt]
# Out:
#        gender            starttime             stoptime  tripduration  \
# 6276   Female  2014-08-04 17:18:00  2014-08-04 17:22:00           214
# 31038  Female  2016-09-07 07:48:30  2016-09-07 07:53:27           297
# 46116    Male  2017-09-13 16:29:00  2017-09-13 16:32:42           222
#
#         from_station_name  start_capacity               to_station_name  \
# 6276   Daley Center Plaza            47.0  Michigan Ave & Washington St
# 31038  Daley Center Plaza            39.0  Michigan Ave & Washington St
# 46116  Daley Center Plaza            39.0  Michigan Ave & Washington St
#
#        end_capacity  temperature  wind_speed  events
# 6276           43.0         73.0         8.1  cloudy
# 31038          43.0         79.0        10.4  cloudy
# 46116          43.0         72.0         9.2  cloudy

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Find all the rides with temperature greater than 90 or trip duration greater than 2000 or wind speed greater than 20.</span>

# %%
filt = (bikes['temperature'] > 90) | (bikes['tripduration'] > 2000) | (bikes['wind_speed'] > 20)

bikes[filt]
# Out:
#        gender            starttime             stoptime  tripduration  \
# 12       Male  2013-07-05 10:02:00  2013-07-05 10:40:00          2263
# 18       Male  2013-07-09 13:12:00  2013-07-09 14:42:00          5396
# 40     Female  2013-07-14 14:08:00  2013-07-14 15:53:00          6274
# 54       Male  2013-07-16 15:13:00  2013-07-16 15:18:00           347
# 55       Male  2013-07-16 15:31:00  2013-07-16 15:37:00           363
# ...       ...                  ...                  ...           ...
# 49827    Male  2017-12-13 18:57:00  2017-12-13 19:00:00           232
# 49829    Male  2017-12-13 20:39:00  2017-12-13 20:47:00           439
# 49905    Male  2017-12-17 21:44:00  2017-12-17 22:34:00          3013
# 49926    Male  2017-12-18 18:00:00  2017-12-18 19:10:00          4214
# 50077    Male  2017-12-29 09:13:00  2017-12-29 09:53:00          2378
#
#                          from_station_name  start_capacity  \
# 12                Jefferson St & Monroe St            19.0
# 18                 Canal St & Jackson Blvd            35.0
# 40               Wabash Ave & Roosevelt Rd            19.0
# 54                      Daley Center Plaza            47.0
# 55                 State St & Van Buren St            27.0
# ...                                    ...             ...
# 49827            Wabash Ave & Roosevelt Rd            23.0
# 49829  Orleans St & Merchandise Mart Plaza            35.0
# 49905                  Ellis Ave & 53rd St            11.0
# 49926             Clark St & Congress Pkwy            27.0
# 50077                 Clinton St & 18th St            15.0
#
#                    to_station_name  end_capacity  temperature  wind_speed  \
# 12        Jefferson St & Monroe St          19.0         79.0         0.0
# 18                 Millennium Park          35.0         79.0        13.8
# 40       Lake Shore Dr & Monroe St          11.0         87.1         8.1
# 54         State St & Van Buren St          27.0         91.0         8.1
# 55              Daley Center Plaza          47.0         91.0         8.1
# ...                            ...           ...          ...         ...
# 49827         Federal St & Polk St          19.0         30.0        24.2
# 49829  Dearborn Pkwy & Delaware Pl          19.0         28.9        20.7
# 49905          Ellis Ave & 53rd St          11.0         41.0         5.8
# 49926        Green St & Madison St          19.0         39.9         8.1
# 50077         Canal St & Taylor St          15.0         12.9         4.6
#
#              events
# 12     partlycloudy
# 18           cloudy
# 40     partlycloudy
# 54     mostlycloudy
# 55     mostlycloudy
# ...             ...
# 49827        cloudy
# 49829          snow
# 49905        cloudy
# 49926  partlycloudy
# 50077        cloudy
#
# [2903 rows x 11 columns]

# %% [markdown]
# ### Exercise 5
#
# <span  style="color:green; font-size:16px">Invert the condition from exercise 4.</span>

# %%
bikes[~filt]
# Out:
#        gender            starttime             stoptime  tripduration  \
# 0        Male  2013-06-28 19:01:00  2013-06-28 19:17:00           993
# 1        Male  2013-06-28 22:53:00  2013-06-28 23:03:00           623
# 2        Male  2013-06-30 14:43:00  2013-06-30 15:01:00          1040
# 3        Male  2013-07-01 10:05:00  2013-07-01 10:16:00           667
# 4        Male  2013-07-01 11:16:00  2013-07-01 11:18:00           130
# ...       ...                  ...                  ...           ...
# 50084    Male  2017-12-30 13:07:00  2017-12-30 13:34:00          1625
# 50085    Male  2017-12-30 13:34:00  2017-12-30 13:44:00           585
# 50086    Male  2017-12-30 13:34:00  2017-12-30 13:48:00           824
# 50087  Female  2017-12-31 09:30:00  2017-12-31 09:33:00           178
# 50088    Male  2017-12-31 15:22:00  2017-12-31 15:26:00           214
#
#                   from_station_name  start_capacity  \
# 0         Lake Shore Dr & Monroe St            11.0
# 1      Clinton St & Washington Blvd            31.0
# 2      Sheffield Ave & Kingsbury St            15.0
# 3           Carpenter St & Huron St            19.0
# 4            Damen Ave & Pierce Ave            19.0
# ...                             ...             ...
# 50084         State St & Pearson St            27.0
# 50085      Halsted St & 35th St (*)            16.0
# 50086      Kingsbury St & Kinzie St            31.0
# 50087          Clinton St & Lake St            23.0
# 50088    Clarendon Ave & Leland Ave            15.0
#
#                      to_station_name  end_capacity  temperature  wind_speed  \
# 0              Michigan Ave & Oak St          15.0         73.9        12.7
# 1               Wells St & Walton St          19.0         69.1         6.9
# 2            Dearborn St & Monroe St          23.0         73.0        16.1
# 3             Clark St & Randolph St          31.0         72.0        16.1
# 4             Damen Ave & Pierce Ave          19.0         73.0        17.3
# ...                              ...           ...          ...         ...
# 50084              Clark St & Elm St          27.0          5.0        16.1
# 50085            Union Ave & Root St          11.0          5.0        16.1
# 50086  Halsted St & Blackhawk St (*)          20.0          5.0        16.1
# 50087       Kingsbury St & Kinzie St          31.0          7.0        11.5
# 50088     Clifton Ave & Lawrence Ave          15.0         10.9        15.0
#
#              events
# 0      mostlycloudy
# 1      partlycloudy
# 2      mostlycloudy
# 3      mostlycloudy
# 4      partlycloudy
# ...             ...
# 50084  partlycloudy
# 50085  partlycloudy
# 50086  partlycloudy
# 50087  partlycloudy
# 50088  partlycloudy
#
# [47186 rows x 11 columns]

# %% [markdown]
# ### Exercise 6
#
# <span  style="color:green; font-size:16px">Are there any rides where the weather event was snow and the temperature was greater than 40?</span>

# %%
filt = (bikes['events'] == 'snow') & (bikes['temperature'] > 40)
bikes[filt]
# Out:
# Empty DataFrame
# Columns: [gender, starttime, stoptime, tripduration, from_station_name, start_capacity, to_station_name, end_capacity, temperature, wind_speed, events]
# Index: []

# %% [markdown]
# Read in the movie dataset by executing the cell below and use it for the following exercises.

# %%
import pandas as pd
movie = pd.read_csv('../data/movie.csv', index_col='title')
movie.head(3)
# Out:
#                                             year  color content_rating  \
# title
# Avatar                                    2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
#
#                                           duration   director_name  \
# title
# Avatar                                       178.0   James Cameron
# Pirates of the Caribbean: At World's End     169.0  Gore Verbinski
# Spectre                                      148.0      Sam Mendes
#
#                                           director_fb           actor1  \
# title
# Avatar                                            0.0      CCH Pounder
# Pirates of the Caribbean: At World's End        563.0      Johnny Depp
# Spectre                                           0.0  Christoph Waltz
#
#                                           actor1_fb            actor2  \
# title
# Avatar                                       1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End    40000.0     Orlando Bloom
# Spectre                                     11000.0      Rory Kinnear
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Avatar                                        936.0  ...     855.0
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
#
#                                                 gross  \
# title
# Avatar                                    760505847.0
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
#
#                                                                    genres  \
# title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
#
#                                          num_reviews  num_voted_users  \
# title
# Avatar                                         723.0           886204
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
#
#                                                                               plot_keywords  \
# title
# Avatar                                               avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
#
#                                          language country       budget  \
# title
# Avatar                                    English     USA  237000000.0
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
#
#                                           imdb_score
# title
# Avatar                                           7.9
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Exercise 7
#
# <span style="color:green; font-size:16px">Select all movies with an IMDB score between 8 and 9.</span>

# %%
filt = (movie['imdb_score'] > 8) & (movie['imdb_score'] < 9) 

movie[filt]
# Out:
#                                          year  color content_rating  duration  \
# title
# The Dark Knight Rises                  2012.0  Color          PG-13     164.0
# The Avengers                           2012.0  Color          PG-13     173.0
# Captain America: Civil War             2016.0  Color          PG-13     147.0
# Toy Story 3                            2010.0  Color              G     103.0
# WALL·E                                 2008.0  Color              G      98.0
# ...                                       ...    ...            ...       ...
# Butterfly Girl                         2014.0  Color            NaN      78.0
# A Charlie Brown Christmas              1965.0  Color           TV-G      25.0
# The Brain That Sings                   2013.0  Color            NaN      62.0
# Peace, Propaganda & the Promised Land  2004.0  Color            NaN      80.0
# The Last Waltz                         1978.0  Color             PG     117.0
#
#                                            director_name  director_fb  \
# title
# The Dark Knight Rises                  Christopher Nolan      22000.0
# The Avengers                                 Joss Whedon          0.0
# Captain America: Civil War                 Anthony Russo         94.0
# Toy Story 3                                  Lee Unkrich        125.0
# WALL·E                                    Andrew Stanton        475.0
# ...                                                  ...          ...
# Butterfly Girl                                 Cary Bell          0.0
# A Charlie Brown Christmas                  Bill Melendez         36.0
# The Brain That Sings                     Amal Al-Agroobi         58.0
# Peace, Propaganda & the Promised Land         Sut Jhally          3.0
# The Last Waltz                           Martin Scorsese      17000.0
#
#                                                   actor1  actor1_fb  \
# title
# The Dark Knight Rises                          Tom Hardy    27000.0
# The Avengers                             Chris Hemsworth    26000.0
# Captain America: Civil War             Robert Downey Jr.    21000.0
# Toy Story 3                                    Tom Hanks    15000.0
# WALL·E                                 John Ratzenberger     1000.0
# ...                                                  ...        ...
# Butterfly Girl                             Abigail Evans        0.0
# A Charlie Brown Christmas                  Peter Robbins       39.0
# The Brain That Sings                                 NaN        NaN
# Peace, Propaganda & the Promised Land       Noam Chomsky      103.0
# The Last Waltz                               Ringo Starr      725.0
#
#                                                    actor2  actor2_fb  ...  \
# title                                                                 ...
# The Dark Knight Rises                      Christian Bale    23000.0  ...
# The Avengers                            Robert Downey Jr.    21000.0  ...
# Captain America: Civil War             Scarlett Johansson    19000.0  ...
# Toy Story 3                             John Ratzenberger     1000.0  ...
# WALL·E                                       Fred Willard      729.0  ...
# ...                                                   ...        ...  ...
# Butterfly Girl                               Stacie Evans        0.0  ...
# A Charlie Brown Christmas                   Bill Melendez       36.0  ...
# The Brain That Sings                                  NaN        NaN  ...
# Peace, Propaganda & the Promised Land       Seth Ackerman        0.0  ...
# The Last Waltz                                 Levon Helm      572.0  ...
#
#                                       actor3_fb        gross  \
# title
# The Dark Knight Rises                   23000.0  448130642.0
# The Avengers                            19000.0  623279547.0
# Captain America: Civil War              11000.0  407197282.0
# Toy Story 3                               721.0  414984497.0
# WALL·E                                    522.0  223806889.0
# ...                                         ...          ...
# Butterfly Girl                              0.0          NaN
# A Charlie Brown Christmas                  27.0          NaN
# The Brain That Sings                        NaN          NaN
# Peace, Propaganda & the Promised Land       0.0          NaN
# The Last Waltz                            476.0     321952.0
#
#                                                                           genres  \
# title
# The Dark Knight Rises                                            Action|Thriller
# The Avengers                                             Action|Adventure|Sci-Fi
# Captain America: Civil War                               Action|Adventure|Sci-Fi
# Toy Story 3                            Adventure|Animation|Comedy|Family|Fantasy
# WALL·E                                         Adventure|Animation|Family|Sci-Fi
# ...                                                                          ...
# Butterfly Girl                                                       Documentary
# A Charlie Brown Christmas                                Animation|Comedy|Family
# The Brain That Sings                                          Documentary|Family
# Peace, Propaganda & the Promised Land                                Documentary
# The Last Waltz                                                 Documentary|Music
#
#                                       num_reviews  num_voted_users  \
# title
# The Dark Knight Rises                       813.0          1144337
# The Avengers                                703.0           995415
# Captain America: Civil War                  516.0           272670
# Toy Story 3                                 453.0           544884
# WALL·E                                      421.0           718837
# ...                                           ...              ...
# Butterfly Girl                                NaN               27
# A Charlie Brown Christmas                    43.0            21826
# The Brain That Sings                          NaN               18
# Peace, Propaganda & the Promised Land        16.0              496
# The Last Waltz                               71.0            12611
#
#                                                                            plot_keywords  \
# title
# The Dark Knight Rises                  deception|imprisonment|lawlessness|police offi...
# The Avengers                             alien invasion|assassin|battle|iron man|soldier
# Captain America: Civil War             based on comic book|knife|marvel cinematic uni...
# Toy Story 3                                       college|day care|escape|teddy bear|toy
# WALL·E                                                    earth|obesity|plant|robot|soil
# ...                                                                                  ...
# Butterfly Girl                                                                       NaN
# A Charlie Brown Christmas              christmas|christmas tree|commercialism|meaning...
# The Brain That Sings                   autism|middle east|music therapy|united arab e...
# Peace, Propaganda & the Promised Land  arab israeli conflict|israel|media|middle east...
# The Last Waltz                          band|final concert|guitar|interview|thanksgiving
#
#                                       language               country  \
# title
# The Dark Knight Rises                  English                   USA
# The Avengers                           English                   USA
# Captain America: Civil War             English                   USA
# Toy Story 3                            English                   USA
# WALL·E                                 English                   USA
# ...                                        ...                   ...
# Butterfly Girl                         English                   USA
# A Charlie Brown Christmas              English                   USA
# The Brain That Sings                    Arabic  United Arab Emirates
# Peace, Propaganda & the Promised Land  English                   USA
# The Last Waltz                         English                   USA
#
#                                             budget  imdb_score
# title
# The Dark Knight Rises                  250000000.0         8.5
# The Avengers                           220000000.0         8.1
# Captain America: Civil War             250000000.0         8.2
# Toy Story 3                            200000000.0         8.3
# WALL·E                                 180000000.0         8.4
# ...                                            ...         ...
# Butterfly Girl                            180000.0         8.7
# A Charlie Brown Christmas                 150000.0         8.4
# The Brain That Sings                      125000.0         8.2
# Peace, Propaganda & the Promised Land      70000.0         8.3
# The Last Waltz                                 NaN         8.2
#
# [241 rows x 21 columns]

# %% [markdown]
# ### Exercise 8
#
# <span  style="color:green; font-size:16px">Select all movies rated 'PG-13' that had IMDB scores between 8 and 9.</span>

# %%
filt = (movie['imdb_score'] > 8) & (movie['imdb_score'] < 9) & (movie['content_rating'] == 'PG-13') 

movie[filt]
# Out:
#                                                       year            color  \
# title
# The Dark Knight Rises                               2012.0            Color
# The Avengers                                        2012.0            Color
# Captain America: Civil War                          2016.0            Color
# Guardians of the Galaxy                             2014.0            Color
# Interstellar                                        2014.0            Color
# Inception                                           2010.0            Color
# Batman Begins                                       2005.0            Color
# The Bourne Ultimatum                                2007.0            Color
# Pirates of the Caribbean: The Curse of the Blac...  2003.0            Color
# The Lord of the Rings: The Fellowship of the Ring   2001.0            Color
# The Martian                                         2015.0            Color
# The Lord of the Rings: The Return of the King       2003.0            Color
# The Lord of the Rings: The Two Towers               2002.0            Color
# A Beautiful Mind                                    2001.0            Color
# Jurassic Park                                       1993.0            Color
# Forrest Gump                                        1994.0  Black and White
# Indiana Jones and the Last Crusade                  1989.0            Color
# The Sixth Sense                                     1999.0            Color
# The Prestige                                        2006.0            Color
# Million Dollar Baby                                 2004.0            Color
# The Help                                            2011.0            Color
# Warrior                                             2011.0            Color
# Princess Mononoke                                   1997.0            Color
# Hotel Rwanda                                        2004.0            Color
# The Imitation Game                                  2014.0            Color
# The Sea Inside                                      2004.0            Color
# Once Upon a Time in the West                        1968.0            Color
# Samsara                                             2011.0            Color
# Batman: The Dark Knight Returns, Part 2             2013.0            Color
# Lage Raho Munna Bhai                                2006.0            Color
# Inside Job                                          2010.0            Color
# Growing Up Smith                                    2015.0            Color
# Queen of the Mountains                              2014.0            Color
# A Separation                                        2011.0            Color
# Hoop Dreams                                         1994.0            Color
#
#                                                    content_rating  duration  \
# title
# The Dark Knight Rises                                       PG-13     164.0
# The Avengers                                                PG-13     173.0
# Captain America: Civil War                                  PG-13     147.0
# Guardians of the Galaxy                                     PG-13     121.0
# Interstellar                                                PG-13     169.0
# Inception                                                   PG-13     148.0
# Batman Begins                                               PG-13     128.0
# The Bourne Ultimatum                                        PG-13     115.0
# Pirates of the Caribbean: The Curse of the Blac...          PG-13     143.0
# The Lord of the Rings: The Fellowship of the Ring           PG-13     171.0
# The Martian                                                 PG-13     151.0
# The Lord of the Rings: The Return of the King               PG-13     192.0
# The Lord of the Rings: The Two Towers                       PG-13     172.0
# A Beautiful Mind                                            PG-13     135.0
# Jurassic Park                                               PG-13     127.0
# Forrest Gump                                                PG-13     142.0
# Indiana Jones and the Last Crusade                          PG-13     127.0
# The Sixth Sense                                             PG-13     107.0
# The Prestige                                                PG-13     130.0
# Million Dollar Baby                                         PG-13     132.0
# The Help                                                    PG-13     146.0
# Warrior                                                     PG-13     140.0
# Princess Mononoke                                           PG-13     134.0
# Hotel Rwanda                                                PG-13     121.0
# The Imitation Game                                          PG-13     114.0
# The Sea Inside                                              PG-13     125.0
# Once Upon a Time in the West                                PG-13     145.0
# Samsara                                                     PG-13     102.0
# Batman: The Dark Knight Returns, Part 2                     PG-13     148.0
# Lage Raho Munna Bhai                                        PG-13     144.0
# Inside Job                                                  PG-13     105.0
# Growing Up Smith                                            PG-13     102.0
# Queen of the Mountains                                      PG-13     135.0
# A Separation                                                PG-13     123.0
# Hoop Dreams                                                 PG-13     170.0
#
#                                                          director_name  \
# title
# The Dark Knight Rises                                Christopher Nolan
# The Avengers                                               Joss Whedon
# Captain America: Civil War                               Anthony Russo
# Guardians of the Galaxy                                     James Gunn
# Interstellar                                         Christopher Nolan
# Inception                                            Christopher Nolan
# Batman Begins                                        Christopher Nolan
# The Bourne Ultimatum                                   Paul Greengrass
# Pirates of the Caribbean: The Curse of the Blac...      Gore Verbinski
# The Lord of the Rings: The Fellowship of the Ring        Peter Jackson
# The Martian                                               Ridley Scott
# The Lord of the Rings: The Return of the King            Peter Jackson
# The Lord of the Rings: The Two Towers                    Peter Jackson
# A Beautiful Mind                                            Ron Howard
# Jurassic Park                                         Steven Spielberg
# Forrest Gump                                           Robert Zemeckis
# Indiana Jones and the Last Crusade                    Steven Spielberg
# The Sixth Sense                                     M. Night Shyamalan
# The Prestige                                         Christopher Nolan
# Million Dollar Baby                                     Clint Eastwood
# The Help                                                   Tate Taylor
# Warrior                                                 Gavin O'Connor
# Princess Mononoke                                       Hayao Miyazaki
# Hotel Rwanda                                              Terry George
# The Imitation Game                                       Morten Tyldum
# The Sea Inside                                      Alejandro Amenábar
# Once Upon a Time in the West                              Sergio Leone
# Samsara                                                     Ron Fricke
# Batman: The Dark Knight Returns, Part 2                      Jay Oliva
# Lage Raho Munna Bhai                                   Rajkumar Hirani
# Inside Job                                            Charles Ferguson
# Growing Up Smith                                          Frank Lotito
# Queen of the Mountains                                Sadyk Sher-Niyaz
# A Separation                                            Asghar Farhadi
# Hoop Dreams                                                Steve James
#
#                                                     director_fb  \
# title
# The Dark Knight Rises                                   22000.0
# The Avengers                                                0.0
# Captain America: Civil War                                 94.0
# Guardians of the Galaxy                                   571.0
# Interstellar                                            22000.0
# Inception                                               22000.0
# Batman Begins                                           22000.0
# The Bourne Ultimatum                                      521.0
# Pirates of the Caribbean: The Curse of the Blac...        563.0
# The Lord of the Rings: The Fellowship of the Ring           0.0
# The Martian                                                 0.0
# The Lord of the Rings: The Return of the King               0.0
# The Lord of the Rings: The Two Towers                       0.0
# A Beautiful Mind                                         2000.0
# Jurassic Park                                           14000.0
# Forrest Gump                                                0.0
# Indiana Jones and the Last Crusade                      14000.0
# The Sixth Sense                                             0.0
# The Prestige                                            22000.0
# Million Dollar Baby                                     16000.0
# The Help                                                  150.0
# Warrior                                                   149.0
# Princess Mononoke                                        6000.0
# Hotel Rwanda                                               83.0
# The Imitation Game                                         77.0
# The Sea Inside                                            448.0
# Once Upon a Time in the West                                0.0
# Samsara                                                   330.0
# Batman: The Dark Knight Returns, Part 2                    41.0
# Lage Raho Munna Bhai                                      124.0
# Inside Job                                                117.0
# Growing Up Smith                                            5.0
# Queen of the Mountains                                    135.0
# A Separation                                                0.0
# Hoop Dreams                                                23.0
#
#                                                                     actor1  \
# title
# The Dark Knight Rises                                            Tom Hardy
# The Avengers                                               Chris Hemsworth
# Captain America: Civil War                               Robert Downey Jr.
# Guardians of the Galaxy                                     Bradley Cooper
# Interstellar                                           Matthew McConaughey
# Inception                                                Leonardo DiCaprio
# Batman Begins                                               Christian Bale
# The Bourne Ultimatum                                            Matt Damon
# Pirates of the Caribbean: The Curse of the Blac...             Johnny Depp
# The Lord of the Rings: The Fellowship of the Ring          Christopher Lee
# The Martian                                                     Matt Damon
# The Lord of the Rings: The Return of the King                Orlando Bloom
# The Lord of the Rings: The Two Towers                      Christopher Lee
# A Beautiful Mind                                             Adam Goldberg
# Jurassic Park                                                 Wayne Knight
# Forrest Gump                                                     Tom Hanks
# Indiana Jones and the Last Crusade                           Harrison Ford
# The Sixth Sense                                               Bruce Willis
# The Prestige                                                Christian Bale
# Million Dollar Baby                                         Clint Eastwood
# The Help                                                        Emma Stone
# Warrior                                                          Tom Hardy
# Princess Mononoke                                            Minnie Driver
# Hotel Rwanda                                                   Don Cheadle
# The Imitation Game                                    Benedict Cumberbatch
# The Sea Inside                                                 Belén Rueda
# Once Upon a Time in the West                             Claudia Cardinale
# Samsara                                             Collin Alfredo St. Dic
# Batman: The Dark Knight Returns, Part 2                    Michael Emerson
# Lage Raho Munna Bhai                                           Vidya Balan
# Inside Job                                                      Matt Damon
# Growing Up Smith                                         Brighton Sharbino
# Queen of the Mountains                                     Elina Abai Kyzy
# A Separation                                               Shahab Hosseini
# Hoop Dreams                                                  William Gates
#
#                                                     actor1_fb  \
# title
# The Dark Knight Rises                                 27000.0
# The Avengers                                          26000.0
# Captain America: Civil War                            21000.0
# Guardians of the Galaxy                               14000.0
# Interstellar                                          11000.0
# Inception                                             29000.0
# Batman Begins                                         23000.0
# The Bourne Ultimatum                                  13000.0
# Pirates of the Caribbean: The Curse of the Blac...    40000.0
# The Lord of the Rings: The Fellowship of the Ring     16000.0
# The Martian                                           13000.0
# The Lord of the Rings: The Return of the King          5000.0
# The Lord of the Rings: The Two Towers                 16000.0
# A Beautiful Mind                                       1000.0
# Jurassic Park                                           967.0
# Forrest Gump                                          15000.0
# Indiana Jones and the Last Crusade                    11000.0
# The Sixth Sense                                       13000.0
# The Prestige                                          23000.0
# Million Dollar Baby                                   16000.0
# The Help                                              15000.0
# Warrior                                               27000.0
# Princess Mononoke                                       893.0
# Hotel Rwanda                                           3000.0
# The Imitation Game                                    19000.0
# The Sea Inside                                          273.0
# Once Upon a Time in the West                            973.0
# Samsara                                                  48.0
# Batman: The Dark Knight Returns, Part 2                2000.0
# Lage Raho Munna Bhai                                    464.0
# Inside Job                                            13000.0
# Growing Up Smith                                       3000.0
# Queen of the Mountains                                    0.0
# A Separation                                            786.0
# Hoop Dreams                                               7.0
#
#                                                                           actor2  \
# title
# The Dark Knight Rises                                             Christian Bale
# The Avengers                                                   Robert Downey Jr.
# Captain America: Civil War                                    Scarlett Johansson
# Guardians of the Galaxy                                               Vin Diesel
# Interstellar                                                       Anne Hathaway
# Inception                                                              Tom Hardy
# Batman Begins                                                        Liam Neeson
# The Bourne Ultimatum                                               Edgar Ramírez
# Pirates of the Caribbean: The Curse of the Blac...                 Orlando Bloom
# The Lord of the Rings: The Fellowship of the Ring                  Orlando Bloom
# The Martian                                                        Donald Glover
# The Lord of the Rings: The Return of the King                         Billy Boyd
# The Lord of the Rings: The Two Towers                              Orlando Bloom
# A Beautiful Mind                                                Austin Pendleton
# Jurassic Park                                                    Ariana Richards
# Forrest Gump                                                Siobhan Fallon Hogan
# Indiana Jones and the Last Crusade                                 Julian Glover
# The Sixth Sense                                                Haley Joel Osment
# The Prestige                                                        Hugh Jackman
# Million Dollar Baby                                               Morgan Freeman
# The Help                                                     Bryce Dallas Howard
# Warrior                                                             Frank Grillo
# Princess Mononoke                                             Jada Pinkett Smith
# Hotel Rwanda                                                      Sophie Okonedo
# The Imitation Game                                                  Rory Kinnear
# The Sea Inside                                                       Lola Dueñas
# Once Upon a Time in the West                                        Woody Strode
# Samsara                                             Balinese Tari Legong Dancers
# Batman: The Dark Knight Returns, Part 2                              Mark Valley
# Lage Raho Munna Bhai                                                 Sanjay Dutt
# Inside Job                                                        George W. Bush
# Growing Up Smith                                                      Jake Busey
# Queen of the Mountains                                         Aziz Muradillayev
# A Separation                                                        Leila Hatami
# Hoop Dreams                                                          Arthur Agee
#
#                                                     actor2_fb  ... actor3_fb  \
# title                                                          ...
# The Dark Knight Rises                                 23000.0  ...   23000.0
# The Avengers                                          21000.0  ...   19000.0
# Captain America: Civil War                            19000.0  ...   11000.0
# Guardians of the Galaxy                               14000.0  ...    3000.0
# Interstellar                                          11000.0  ...    6000.0
# Inception                                             27000.0  ...   23000.0
# Batman Begins                                         14000.0  ...   11000.0
# The Bourne Ultimatum                                    897.0  ...     883.0
# Pirates of the Caribbean: The Curse of the Blac...     5000.0  ...    1000.0
# The Lord of the Rings: The Fellowship of the Ring      5000.0  ...     857.0
# The Martian                                             801.0  ...     372.0
# The Lord of the Rings: The Return of the King           857.0  ...     416.0
# The Lord of the Rings: The Two Towers                  5000.0  ...     857.0
# A Beautiful Mind                                        592.0  ...     535.0
# Jurassic Park                                           610.0  ...     191.0
# Forrest Gump                                            294.0  ...     194.0
# Indiana Jones and the Last Crusade                      844.0  ...     440.0
# The Sixth Sense                                        3000.0  ...     766.0
# The Prestige                                          20000.0  ...   19000.0
# Million Dollar Baby                                   11000.0  ...     567.0
# The Help                                               3000.0  ...    2000.0
# Warrior                                                 798.0  ...     581.0
# Princess Mononoke                                       851.0  ...     745.0
# Hotel Rwanda                                            460.0  ...     242.0
# The Imitation Game                                      393.0  ...     305.0
# The Sea Inside                                          114.0  ...      93.0
# Once Upon a Time in the West                            423.0  ...     392.0
# Samsara                                                   0.0  ...       0.0
# Batman: The Dark Knight Returns, Part 2                 774.0  ...     739.0
# Lage Raho Munna Bhai                                    426.0  ...     327.0
# Inside Job                                              125.0  ...      18.0
# Growing Up Smith                                        660.0  ...     259.0
# Queen of the Mountains                                    0.0  ...       0.0
# A Separation                                            712.0  ...     620.0
# Hoop Dreams                                               6.0  ...       2.0
#
#                                                           gross  \
# title
# The Dark Knight Rises                               448130642.0
# The Avengers                                        623279547.0
# Captain America: Civil War                          407197282.0
# Guardians of the Galaxy                             333130696.0
# Interstellar                                        187991439.0
# Inception                                           292568851.0
# Batman Begins                                       205343774.0
# The Bourne Ultimatum                                227137090.0
# Pirates of the Caribbean: The Curse of the Blac...  305388685.0
# The Lord of the Rings: The Fellowship of the Ring   313837577.0
# The Martian                                         228430993.0
# The Lord of the Rings: The Return of the King       377019252.0
# The Lord of the Rings: The Two Towers               340478898.0
# A Beautiful Mind                                    170708996.0
# Jurassic Park                                       356784000.0
# Forrest Gump                                        329691196.0
# Indiana Jones and the Last Crusade                  197171806.0
# The Sixth Sense                                     293501675.0
# The Prestige                                         53082743.0
# Million Dollar Baby                                 100422786.0
# The Help                                            169705587.0
# Warrior                                              13651662.0
# Princess Mononoke                                     2298191.0
# Hotel Rwanda                                         23472900.0
# The Imitation Game                                   91121452.0
# The Sea Inside                                        2086345.0
# Once Upon a Time in the West                                NaN
# Samsara                                               2601847.0
# Batman: The Dark Knight Returns, Part 2                     NaN
# Lage Raho Munna Bhai                                        NaN
# Inside Job                                            4311834.0
# Growing Up Smith                                            NaN
# Queen of the Mountains                                      NaN
# A Separation                                          7098492.0
# Hoop Dreams                                           7830611.0
#
#                                                                                     genres  \
# title
# The Dark Knight Rises                                                      Action|Thriller
# The Avengers                                                       Action|Adventure|Sci-Fi
# Captain America: Civil War                                         Action|Adventure|Sci-Fi
# Guardians of the Galaxy                                            Action|Adventure|Sci-Fi
# Interstellar                                                        Adventure|Drama|Sci-Fi
# Inception                                                 Action|Adventure|Sci-Fi|Thriller
# Batman Begins                                                             Action|Adventure
# The Bourne Ultimatum                                               Action|Mystery|Thriller
# Pirates of the Caribbean: The Curse of the Blac...                Action|Adventure|Fantasy
# The Lord of the Rings: The Fellowship of the Ring           Action|Adventure|Drama|Fantasy
# The Martian                                                         Adventure|Drama|Sci-Fi
# The Lord of the Rings: The Return of the King               Action|Adventure|Drama|Fantasy
# The Lord of the Rings: The Two Towers                       Action|Adventure|Drama|Fantasy
# A Beautiful Mind                                                           Biography|Drama
# Jurassic Park                                                    Adventure|Sci-Fi|Thriller
# Forrest Gump                                                                  Comedy|Drama
# Indiana Jones and the Last Crusade                                Action|Adventure|Fantasy
# The Sixth Sense                                                     Drama|Mystery|Thriller
# The Prestige                                                 Drama|Mystery|Sci-Fi|Thriller
# Million Dollar Baby                                                            Drama|Sport
# The Help                                                                             Drama
# Warrior                                                                        Drama|Sport
# Princess Mononoke                                              Adventure|Animation|Fantasy
# Hotel Rwanda                                                             Drama|History|War
# The Imitation Game                                            Biography|Drama|Thriller|War
# The Sea Inside                                                     Biography|Drama|Romance
# Once Upon a Time in the West                                                       Western
# Samsara                                                                  Documentary|Music
# Batman: The Dark Knight Returns, Part 2             Action|Animation|Crime|Sci-Fi|Thriller
# Lage Raho Munna Bhai                                                  Comedy|Drama|Romance
# Inside Job                                                               Crime|Documentary
# Growing Up Smith                                                       Comedy|Drama|Family
# Queen of the Mountains                                      Action|Biography|Drama|History
# A Separation                                                                 Drama|Mystery
# Hoop Dreams                                                        Documentary|Drama|Sport
#
#                                                    num_reviews  \
# title
# The Dark Knight Rises                                    813.0
# The Avengers                                             703.0
# Captain America: Civil War                               516.0
# Guardians of the Galaxy                                  653.0
# Interstellar                                             712.0
# Inception                                                642.0
# Batman Begins                                            478.0
# The Bourne Ultimatum                                     329.0
# Pirates of the Caribbean: The Curse of the Blac...       271.0
# The Lord of the Rings: The Fellowship of the Ring        297.0
# The Martian                                              568.0
# The Lord of the Rings: The Return of the King            328.0
# The Lord of the Rings: The Two Towers                    294.0
# A Beautiful Mind                                         205.0
# Jurassic Park                                            308.0
# Forrest Gump                                             149.0
# Indiana Jones and the Last Crusade                       149.0
# The Sixth Sense                                          234.0
# The Prestige                                             341.0
# Million Dollar Baby                                      268.0
# The Help                                                 373.0
# Warrior                                                  317.0
# Princess Mononoke                                        174.0
# Hotel Rwanda                                             187.0
# The Imitation Game                                       454.0
# The Sea Inside                                           157.0
# Once Upon a Time in the West                             164.0
# Samsara                                                  115.0
# Batman: The Dark Knight Returns, Part 2                   44.0
# Lage Raho Munna Bhai                                      15.0
# Inside Job                                               171.0
# Growing Up Smith                                           NaN
# Queen of the Mountains                                    16.0
# A Separation                                             354.0
# Hoop Dreams                                               53.0
#
#                                                     num_voted_users  \
# title
# The Dark Knight Rises                                       1144337
# The Avengers                                                 995415
# Captain America: Civil War                                   272670
# Guardians of the Galaxy                                      682155
# Interstellar                                                 928227
# Inception                                                   1468200
# Batman Begins                                                980946
# The Bourne Ultimatum                                         491077
# Pirates of the Caribbean: The Curse of the Blac...           809474
# The Lord of the Rings: The Fellowship of the Ring           1238746
# The Martian                                                  472488
# The Lord of the Rings: The Return of the King               1215718
# The Lord of the Rings: The Two Towers                       1100446
# A Beautiful Mind                                             610568
# Jurassic Park                                                613473
# Forrest Gump                                                1251222
# Indiana Jones and the Last Crusade                           515306
# The Sixth Sense                                              704766
# The Prestige                                                 844052
# Million Dollar Baby                                          482064
# The Help                                                     318955
# Warrior                                                      332276
# Princess Mononoke                                            221552
# Hotel Rwanda                                                 264533
# The Imitation Game                                           467613
# The Sea Inside                                                64556
# Once Upon a Time in the West                                 216005
# Samsara                                                       22457
# Batman: The Dark Knight Returns, Part 2                       30434
# Lage Raho Munna Bhai                                          27569
# Inside Job                                                    55382
# Growing Up Smith                                                108
# Queen of the Mountains                                         3144
# A Separation                                                 151812
# Hoop Dreams                                                   18980
#
#                                                                                         plot_keywords  \
# title
# The Dark Knight Rises                               deception|imprisonment|lawlessness|police offi...
# The Avengers                                          alien invasion|assassin|battle|iron man|soldier
# Captain America: Civil War                          based on comic book|knife|marvel cinematic uni...
# Guardians of the Galaxy                             bounty hunter|outer space|raccoon|talking anim...
# Interstellar                                        black hole|father daughter relationship|saving...
# Inception                                           ambiguous ending|corporate espionage|dream|sub...
# Batman Begins                                       armored car|gangster|gotham|mixed martial arts...
# The Bourne Ultimatum                                       action hero|cia|dark past|flashback|memory
# Pirates of the Caribbean: The Curse of the Blac...             caribbean|curse|governor|pirate|undead
# The Lord of the Rings: The Fellowship of the Ring                  elf|hobbit|middle earth|quest|ring
# The Martian                                         astronaut|international cooperation|left for d...
# The Lord of the Rings: The Return of the King                               battle|epic|king|orc|ring
# The Lord of the Rings: The Two Towers                       epic|evil wizard|middle earth|ring|wizard
# A Beautiful Mind                                    conspiracy|cryptography|mathematician|mental i...
# Jurassic Park                                       dinosaur|jurassic park|survival|theme park|tyr...
# Forrest Gump                                                amputee|love|vietnam|vietnam war|war hero
# Indiana Jones and the Last Crusade                                   castle|diary|holy grail|map|nazi
# The Sixth Sense                                     able to see the dead|ghost|plot twist|psychic|...
# The Prestige                                               illusion|magician|obsession|rivalry|secret
# Million Dollar Baby                                 boxing|boxing trainer|death|suicide attempt|wo...
# The Help                                            black servant|chocolate pie|jackson mississipp...
# Warrior                                             alcoholic|mixed martial arts|return home|tourn...
# Princess Mononoke                                       anime|cult film|forest|princess|studio ghibli
# Hotel Rwanda                                        atrocity|central africa|ethnic warfare|united ...
# The Imitation Game                                  crossword puzzle|cryptography|enigma code|gay ...
# The Sea Inside                                               dignity|euthanasia|freedom|lawyer|sailor
# Once Upon a Time in the West                              gang|gun|harmonica|killing|woman in bathtub
# Samsara                                             hall of mirrors|mont saint michel france|palac...
# Batman: The Dark Knight Returns, Part 2                batman|joker|mutant|tattoo on breast|the joker
# Lage Raho Munna Bhai                                love|professor of history|radio|satyagraha|uns...
# Inside Job                                          florida|iceland|interview|new york city new yo...
# Growing Up Smith                                    adolescence|girl next door|growing vegetables|...
# Queen of the Mountains                              19th century|central asia|mother son relations...
# A Separation                                        alzheimer's disease|caregiver|divorce|iran|ira...
# Hoop Dreams                                         athlete|basketball|high school|high school stu...
#
#                                                     language      country  \
# title
# The Dark Knight Rises                                English          USA
# The Avengers                                         English          USA
# Captain America: Civil War                           English          USA
# Guardians of the Galaxy                              English          USA
# Interstellar                                         English          USA
# Inception                                            English          USA
# Batman Begins                                        English          USA
# The Bourne Ultimatum                                 English          USA
# Pirates of the Caribbean: The Curse of the Blac...   English          USA
# The Lord of the Rings: The Fellowship of the Ring    English  New Zealand
# The Martian                                          English          USA
# The Lord of the Rings: The Return of the King        English          USA
# The Lord of the Rings: The Two Towers                English          USA
# A Beautiful Mind                                     English          USA
# Jurassic Park                                        English          USA
# Forrest Gump                                         English          USA
# Indiana Jones and the Last Crusade                   English          USA
# The Sixth Sense                                      English          USA
# The Prestige                                         English          USA
# Million Dollar Baby                                  English          USA
# The Help                                             English          USA
# Warrior                                              English          USA
# Princess Mononoke                                   Japanese        Japan
# Hotel Rwanda                                         English           UK
# The Imitation Game                                   English           UK
# The Sea Inside                                       Spanish        Spain
# Once Upon a Time in the West                         English        Italy
# Samsara                                                 None          USA
# Batman: The Dark Knight Returns, Part 2              English          USA
# Lage Raho Munna Bhai                                   Hindi        India
# Inside Job                                           English          USA
# Growing Up Smith                                     English          USA
# Queen of the Mountains                               English   Kyrgyzstan
# A Separation                                         Persian         Iran
# Hoop Dreams                                          English          USA
#
#                                                           budget  imdb_score
# title
# The Dark Knight Rises                               2.500000e+08         8.5
# The Avengers                                        2.200000e+08         8.1
# Captain America: Civil War                          2.500000e+08         8.2
# Guardians of the Galaxy                             1.700000e+08         8.1
# Interstellar                                        1.650000e+08         8.6
# Inception                                           1.600000e+08         8.8
# Batman Begins                                       1.500000e+08         8.3
# The Bourne Ultimatum                                1.100000e+08         8.1
# Pirates of the Caribbean: The Curse of the Blac...  1.400000e+08         8.1
# The Lord of the Rings: The Fellowship of the Ring   9.300000e+07         8.8
# The Martian                                         1.080000e+08         8.1
# The Lord of the Rings: The Return of the King       9.400000e+07         8.9
# The Lord of the Rings: The Two Towers               9.400000e+07         8.7
# A Beautiful Mind                                    5.800000e+07         8.2
# Jurassic Park                                       6.300000e+07         8.1
# Forrest Gump                                        5.500000e+07         8.8
# Indiana Jones and the Last Crusade                  4.800000e+07         8.3
# The Sixth Sense                                     4.000000e+07         8.1
# The Prestige                                        4.000000e+07         8.5
# Million Dollar Baby                                 3.000000e+07         8.1
# The Help                                            2.500000e+07         8.1
# Warrior                                             2.500000e+07         8.2
# Princess Mononoke                                   2.400000e+09         8.4
# Hotel Rwanda                                        1.750000e+07         8.1
# The Imitation Game                                  1.400000e+07         8.1
# The Sea Inside                                      1.000000e+07         8.1
# Once Upon a Time in the West                        5.000000e+06         8.6
# Samsara                                             4.000000e+06         8.5
# Batman: The Dark Knight Returns, Part 2             3.500000e+06         8.4
# Lage Raho Munna Bhai                                1.200000e+08         8.2
# Inside Job                                                   NaN         8.3
# Growing Up Smith                                    2.000000e+06         8.2
# Queen of the Mountains                              1.400000e+06         8.7
# A Separation                                        5.000000e+05         8.4
# Hoop Dreams                                         7.000000e+05         8.3
#
# [35 rows x 21 columns]

# %% [markdown]
# ### Exercise 9
#
# <span  style="color:green; font-size:16px">Select movies that were rated either R, PG-13, or PG.</span>

# %%
movie['content_rating'].isin(['R', 'PG-13', 'PG'])
# Out:
# title
# Avatar                                         True
# Pirates of the Caribbean: At World's End       True
# Spectre                                        True
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                               True
# My Date with Drew                              True
# Name: content_rating, Length: 4916, dtype: bool

# %% [markdown]
# ### Exercise 10
#
# <span  style="color:green; font-size:16px">Select movies that are either rated PG-13 or had an IMDB score greater than 7.</span>

# %%
filt = (movie['imdb_score'] > 7) & (movie['content_rating'] == 'PG-13') 

movie[filt]
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Avengers: Age of Ultron                     2015.0  Color          PG-13
# Pirates of the Caribbean: Dead Man's Chest  2006.0  Color          PG-13
# ...                                            ...    ...            ...
# Call + Response                             2008.0  Color          PG-13
# The Trials of Darryl Hunt                   2006.0  Color          PG-13
# Heroes of Dirt                              2015.0  Color          PG-13
# The Mighty                                  1998.0  Color          PG-13
# The Mongol King                             2005.0  Color          PG-13
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# The Dark Knight Rises                          164.0  Christopher Nolan
# Avengers: Age of Ultron                        141.0        Joss Whedon
# Pirates of the Caribbean: Dead Man's Chest     151.0     Gore Verbinski
# ...                                              ...                ...
# Call + Response                                 86.0      Justin Dillon
# The Trials of Darryl Hunt                      106.0        Ricki Stern
# Heroes of Dirt                                  98.0        Eric Bugbee
# The Mighty                                     100.0      Peter Chelsom
# The Mongol King                                 84.0    Anthony Vallone
#
#                                             director_fb           actor1  \
# title
# Avatar                                              0.0      CCH Pounder
# Pirates of the Caribbean: At World's End          563.0      Johnny Depp
# The Dark Knight Rises                           22000.0        Tom Hardy
# Avengers: Age of Ultron                             0.0  Chris Hemsworth
# Pirates of the Caribbean: Dead Man's Chest        563.0      Johnny Depp
# ...                                                 ...              ...
# Call + Response                                     0.0        Matisyahu
# The Trials of Darryl Hunt                          15.0      Darryl Hunt
# Heroes of Dirt                                      0.0       Joel Moody
# The Mighty                                         23.0    Kieran Culkin
# The Mongol King                                     2.0   Richard Jewell
#
#                                             actor1_fb               actor2  \
# title
# Avatar                                         1000.0     Joel David Moore
# Pirates of the Caribbean: At World's End      40000.0        Orlando Bloom
# The Dark Knight Rises                         27000.0       Christian Bale
# Avengers: Age of Ultron                       26000.0    Robert Downey Jr.
# Pirates of the Caribbean: Dead Man's Chest    40000.0        Orlando Bloom
# ...                                               ...                  ...
# Call + Response                                 178.0  Natasha Bedingfield
# The Trials of Darryl Hunt                         2.0     Evelyn Jefferson
# Heroes of Dirt                                   52.0           Bill Allen
# The Mighty                                     1000.0         Elden Henson
# The Mongol King                                  45.0       John Considine
#
#                                             actor2_fb  ... actor3_fb  \
# title                                                  ...
# Avatar                                          936.0  ...     855.0
# Pirates of the Caribbean: At World's End       5000.0  ...    1000.0
# The Dark Knight Rises                         23000.0  ...   23000.0
# Avengers: Age of Ultron                       21000.0  ...   19000.0
# Pirates of the Caribbean: Dead Man's Chest     5000.0  ...    1000.0
# ...                                               ...  ...       ...
# Call + Response                                  58.0  ...      15.0
# The Trials of Darryl Hunt                         0.0  ...       0.0
# Heroes of Dirt                                   36.0  ...      21.0
# The Mighty                                      577.0  ...     545.0
# The Mongol King                                  44.0  ...       2.0
#
#                                                   gross  \
# title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# The Dark Knight Rises                       448130642.0
# Avengers: Age of Ultron                     458991599.0
# Pirates of the Caribbean: Dead Man's Chest  423032628.0
# ...                                                 ...
# Call + Response                                215185.0
# The Trials of Darryl Hunt                        1111.0
# Heroes of Dirt                                      NaN
# The Mighty                                    2643689.0
# The Mongol King                                     NaN
#
#                                                                      genres  \
# title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# The Dark Knight Rises                                       Action|Thriller
# Avengers: Age of Ultron                             Action|Adventure|Sci-Fi
# Pirates of the Caribbean: Dead Man's Chest         Action|Adventure|Fantasy
# ...                                                                     ...
# Call + Response                                   Documentary|History|Music
# The Trials of Darryl Hunt                                 Crime|Documentary
# Heroes of Dirt                                           Action|Drama|Sport
# The Mighty                                                     Comedy|Drama
# The Mongol King                                                 Crime|Drama
#
#                                            num_reviews  num_voted_users  \
# title
# Avatar                                           723.0           886204
# Pirates of the Caribbean: At World's End         302.0           471220
# The Dark Knight Rises                            813.0          1144337
# Avengers: Age of Ultron                          635.0           462669
# Pirates of the Caribbean: Dead Man's Chest       313.0           522040
# ...                                                ...              ...
# Call + Response                                    7.0               48
# The Trials of Darryl Hunt                         11.0              771
# Heroes of Dirt                                     2.0               53
# The Mighty                                        57.0            10499
# The Mongol King                                    NaN               36
#
#                                                                                 plot_keywords  \
# title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Avengers: Age of Ultron                     artificial intelligence|based on comic book|ca...
# Pirates of the Caribbean: Dead Man's Chest  box office hit|giant squid|heart|liar's dice|m...
# ...                                                                                       ...
# Call + Response                             fair trade|human trafficking|non profit|rockum...
# The Trials of Darryl Hunt                   false accusation|murder|north carolina|trial|w...
# Heroes of Dirt                                             bike|bmx|drugs|troubled teen|youth
# The Mighty                                   book|friendship|knight|learning disability|tutor
# The Mongol King                                   jewell|mongol|nostradamus|stepnicka|vallone
#
#                                            language country       budget  \
# title
# Avatar                                      English     USA  237000000.0
# Pirates of the Caribbean: At World's End    English     USA  300000000.0
# The Dark Knight Rises                       English     USA  250000000.0
# Avengers: Age of Ultron                     English     USA  250000000.0
# Pirates of the Caribbean: Dead Man's Chest  English     USA  225000000.0
# ...                                             ...     ...          ...
# Call + Response                             English     USA     200000.0
# The Trials of Darryl Hunt                   English     USA     200000.0
# Heroes of Dirt                              English     USA          NaN
# The Mighty                                  English     USA          NaN
# The Mongol King                             English     USA       3250.0
#
#                                             imdb_score
# title
# Avatar                                             7.9
# Pirates of the Caribbean: At World's End           7.1
# The Dark Knight Rises                              8.5
# Avengers: Age of Ultron                            7.5
# Pirates of the Caribbean: Dead Man's Chest         7.3
# ...                                                ...
# Call + Response                                    7.5
# The Trials of Darryl Hunt                          7.7
# Heroes of Dirt                                     7.1
# The Mighty                                         7.3
# The Mongol King                                    7.8
#
# [326 rows x 21 columns]

# %% [markdown]
# ### Exercise 11
#
# <span  style="color:green; font-size:16px">Find all the movies that have at least one of the three actors with more than 10,000 Facebook likes.</span>

# %%
filt = (movie['actor1_fb'] > 10000) | (movie['actor2_fb'] > 10000) | (movie['actor3_fb'] > 10000)

movie[filt]
# Out:
#                                             year  color content_rating  \
# title
# Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# Spectre                                   2015.0  Color          PG-13
# The Dark Knight Rises                     2012.0  Color          PG-13
# Spider-Man 3                              2007.0  Color          PG-13
# Avengers: Age of Ultron                   2015.0  Color          PG-13
# ...                                          ...    ...            ...
# Like Crazy                                2011.0  Color          PG-13
# Bronson                                   2008.0  Color              R
# A Fistful of Dollars                      1964.0  Color              R
# The Grace Card                            2010.0  Color          PG-13
# Smiling Fish & Goat on Fire               1999.0  Color              R
#
#                                           duration         director_name  \
# title
# Pirates of the Caribbean: At World's End     169.0        Gore Verbinski
# Spectre                                      148.0            Sam Mendes
# The Dark Knight Rises                        164.0     Christopher Nolan
# Spider-Man 3                                 156.0             Sam Raimi
# Avengers: Age of Ultron                      141.0           Joss Whedon
# ...                                            ...                   ...
# Like Crazy                                    90.0         Drake Doremus
# Bronson                                       92.0  Nicolas Winding Refn
# A Fistful of Dollars                          99.0          Sergio Leone
# The Grace Card                               101.0        David G. Evans
# Smiling Fish & Goat on Fire                   90.0          Kevin Jordan
#
#                                           director_fb             actor1  \
# title
# Pirates of the Caribbean: At World's End        563.0        Johnny Depp
# Spectre                                           0.0    Christoph Waltz
# The Dark Knight Rises                         22000.0          Tom Hardy
# Spider-Man 3                                      0.0       J.K. Simmons
# Avengers: Age of Ultron                           0.0    Chris Hemsworth
# ...                                               ...                ...
# Like Crazy                                       52.0  Jennifer Lawrence
# Bronson                                           0.0          Tom Hardy
# A Fistful of Dollars                              0.0     Clint Eastwood
# The Grace Card                                    0.0     Michael Joiner
# Smiling Fish & Goat on Fire                       4.0     Derick Martini
#
#                                           actor1_fb              actor2  \
# title
# Pirates of the Caribbean: At World's End    40000.0       Orlando Bloom
# Spectre                                     11000.0        Rory Kinnear
# The Dark Knight Rises                       27000.0      Christian Bale
# Spider-Man 3                                24000.0        James Franco
# Avengers: Age of Ultron                     26000.0   Robert Downey Jr.
# ...                                             ...                 ...
# Like Crazy                                  34000.0      Charlie Bewley
# Bronson                                     27000.0         James Lance
# A Fistful of Dollars                        16000.0  Gian Maria Volontè
# The Grace Card                              77000.0        Chris Thomas
# Smiling Fish & Goat on Fire                 20000.0      Christa Miller
#
#                                           actor2_fb  ... actor3_fb  \
# title                                                ...
# Pirates of the Caribbean: At World's End     5000.0  ...    1000.0
# Spectre                                       393.0  ...     161.0
# The Dark Knight Rises                       23000.0  ...   23000.0
# Spider-Man 3                                11000.0  ...    4000.0
# Avengers: Age of Ultron                     21000.0  ...   19000.0
# ...                                             ...  ...       ...
# Like Crazy                                    487.0  ...     224.0
# Bronson                                       161.0  ...     146.0
# A Fistful of Dollars                          360.0  ...      93.0
# The Grace Card                                 21.0  ...      16.0
# Smiling Fish & Goat on Fire                   467.0  ...     113.0
#
#                                                 gross  \
# title
# Pirates of the Caribbean: At World's End  309404152.0
# Spectre                                   200074175.0
# The Dark Knight Rises                     448130642.0
# Spider-Man 3                              336530303.0
# Avengers: Age of Ultron                   458991599.0
# ...                                               ...
# Like Crazy                                  3388210.0
# Bronson                                      104792.0
# A Fistful of Dollars                        3500000.0
# The Grace Card                              2428241.0
# Smiling Fish & Goat on Fire                  277233.0
#
#                                                                 genres  \
# title
# Pirates of the Caribbean: At World's End      Action|Adventure|Fantasy
# Spectre                                      Action|Adventure|Thriller
# The Dark Knight Rises                                  Action|Thriller
# Spider-Man 3                                  Action|Adventure|Romance
# Avengers: Age of Ultron                        Action|Adventure|Sci-Fi
# ...                                                                ...
# Like Crazy                                               Drama|Romance
# Bronson                                   Action|Biography|Crime|Drama
# A Fistful of Dollars                              Action|Drama|Western
# The Grace Card                                                   Drama
# Smiling Fish & Goat on Fire                             Comedy|Romance
#
#                                          num_reviews  num_voted_users  \
# title
# Pirates of the Caribbean: At World's End       302.0           471220
# Spectre                                        602.0           275868
# The Dark Knight Rises                          813.0          1144337
# Spider-Man 3                                   392.0           383056
# Avengers: Age of Ultron                        635.0           462669
# ...                                              ...              ...
# Like Crazy                                     206.0            46813
# Bronson                                        225.0            84817
# A Fistful of Dollars                           122.0           147566
# The Grace Card                                  25.0             2099
# Smiling Fish & Goat on Fire                     21.0             2631
#
#                                                                               plot_keywords  \
# title
# Pirates of the Caribbean: At World's End  goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                 bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                     deception|imprisonment|lawlessness|police offi...
# Spider-Man 3                                      sandman|spider man|symbiote|venom|villain
# Avengers: Age of Ultron                   artificial intelligence|based on comic book|ca...
# ...                                                                                     ...
# Like Crazy                                girlfriend|immigration|long distance relations...
# Bronson                                   male full frontal nudity|prison|prisoner|solit...
# A Fistful of Dollars                                  balladeer|bar|drifter|mexican|revenge
# The Grace Card                            christian film|forgiveness|hospital|pastor|police
# Smiling Fish & Goat on Fire               accountant|actor|animal in title|mail carrier|...
#
#                                          language country       budget  \
# title
# Pirates of the Caribbean: At World's End  English     USA  300000000.0
# Spectre                                   English      UK  245000000.0
# The Dark Knight Rises                     English     USA  250000000.0
# Spider-Man 3                              English     USA  258000000.0
# Avengers: Age of Ultron                   English     USA  250000000.0
# ...                                           ...     ...          ...
# Like Crazy                                English     USA     250000.0
# Bronson                                   English      UK          NaN
# A Fistful of Dollars                      Italian   Italy     200000.0
# The Grace Card                            English     USA     200000.0
# Smiling Fish & Goat on Fire               English     USA      40000.0
#
#                                           imdb_score
# title
# Pirates of the Caribbean: At World's End         7.1
# Spectre                                          6.8
# The Dark Knight Rises                            8.5
# Spider-Man 3                                     6.2
# Avengers: Age of Ultron                          7.5
# ...                                              ...
# Like Crazy                                       6.7
# Bronson                                          7.1
# A Fistful of Dollars                             8.0
# The Grace Card                                   6.4
# Smiling Fish & Goat on Fire                      7.6
#
# [1337 rows x 21 columns]

# %% [markdown]
# ### Exercise 12
#
# <span  style="color:green; font-size:16px">Invert the condition from exercise 10. In words, what have you selected?</span>

# %%
movie[~filt]
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# John Carter                                 2012.0  Color          PG-13
# Tangled                                     2010.0  Color             PG
# Quantum of Solace                           2008.0  Color          PG-13
# ...                                            ...    ...            ...
# Signed Sealed Delivered                     2013.0  Color            NaN
# The Following                                  NaN  Color          TV-14
# A Plague So Pleasant                        2013.0  Color            NaN
# Shanghai Calling                            2012.0  Color          PG-13
# My Date with Drew                           2004.0  Color             PG
#
#                                             duration     director_name  \
# title
# Avatar                                         178.0     James Cameron
# Star Wars: Episode VII - The Force Awakens       NaN       Doug Walker
# John Carter                                    132.0    Andrew Stanton
# Tangled                                        100.0      Nathan Greno
# Quantum of Solace                              106.0      Marc Forster
# ...                                              ...               ...
# Signed Sealed Delivered                         87.0       Scott Smith
# The Following                                   43.0               NaN
# A Plague So Pleasant                            76.0  Benjamin Roberds
# Shanghai Calling                               100.0       Daniel Hsia
# My Date with Drew                               90.0          Jon Gunn
#
#                                             director_fb              actor1  \
# title
# Avatar                                              0.0         CCH Pounder
# Star Wars: Episode VII - The Force Awakens        131.0         Doug Walker
# John Carter                                       475.0        Daryl Sabara
# Tangled                                            15.0        Brad Garrett
# Quantum of Solace                                 395.0  Giancarlo Giannini
# ...                                                 ...                 ...
# Signed Sealed Delivered                             2.0         Eric Mabius
# The Following                                       NaN         Natalie Zea
# A Plague So Pleasant                                0.0         Eva Boehnke
# Shanghai Calling                                    0.0           Alan Ruck
# My Date with Drew                                  16.0         John August
#
#                                             actor1_fb            actor2  \
# title
# Avatar                                         1000.0  Joel David Moore
# Star Wars: Episode VII - The Force Awakens      131.0        Rob Walker
# John Carter                                     640.0   Samantha Morton
# Tangled                                         799.0      Donna Murphy
# Quantum of Solace                               451.0   Mathieu Amalric
# ...                                               ...               ...
# Signed Sealed Delivered                         637.0     Daphne Zuniga
# The Following                                   841.0     Valorie Curry
# A Plague So Pleasant                              0.0     Maxwell Moody
# Shanghai Calling                                946.0     Daniel Henney
# My Date with Drew                                86.0  Brian Herzlinger
#
#                                             actor2_fb  ... actor3_fb  \
# title                                                  ...
# Avatar                                          936.0  ...     855.0
# Star Wars: Episode VII - The Force Awakens       12.0  ...       NaN
# John Carter                                     632.0  ...     530.0
# Tangled                                         553.0  ...     284.0
# Quantum of Solace                               412.0  ...     393.0
# ...                                               ...  ...       ...
# Signed Sealed Delivered                         470.0  ...     318.0
# The Following                                   593.0  ...     319.0
# A Plague So Pleasant                              0.0  ...       0.0
# Shanghai Calling                                719.0  ...     489.0
# My Date with Drew                                23.0  ...      16.0
#
#                                                   gross  \
# title
# Avatar                                      760505847.0
# Star Wars: Episode VII - The Force Awakens          NaN
# John Carter                                  73058679.0
# Tangled                                     200807262.0
# Quantum of Solace                           168368427.0
# ...                                                 ...
# Signed Sealed Delivered                             NaN
# The Following                                       NaN
# A Plague So Pleasant                                NaN
# Shanghai Calling                                10443.0
# My Date with Drew                               85222.0
#
#                                                                                        genres  \
# title
# Avatar                                                        Action|Adventure|Fantasy|Sci-Fi
# Star Wars: Episode VII - The Force Awakens                                        Documentary
# John Carter                                                           Action|Adventure|Sci-Fi
# Tangled                                     Adventure|Animation|Comedy|Family|Fantasy|Musi...
# Quantum of Solace                                                            Action|Adventure
# ...                                                                                       ...
# Signed Sealed Delivered                                                          Comedy|Drama
# The Following                                                    Crime|Drama|Mystery|Thriller
# A Plague So Pleasant                                                    Drama|Horror|Thriller
# Shanghai Calling                                                         Comedy|Drama|Romance
# My Date with Drew                                                                 Documentary
#
#                                            num_reviews  num_voted_users  \
# title
# Avatar                                           723.0           886204
# Star Wars: Episode VII - The Force Awakens         NaN                8
# John Carter                                      462.0           212204
# Tangled                                          324.0           294810
# Quantum of Solace                                403.0           330784
# ...                                                ...              ...
# Signed Sealed Delivered                            1.0              629
# The Following                                     43.0            73839
# A Plague So Pleasant                              13.0               38
# Shanghai Calling                                  14.0             1255
# My Date with Drew                                 43.0             4285
#
#                                                                                 plot_keywords  \
# title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Star Wars: Episode VII - The Force Awakens                                                NaN
# John Carter                                 alien|american civil war|male nipple|mars|prin...
# Tangled                                     17th century|based on fairy tale|disney|flower...
# Quantum of Solace                           action hero|attempted rape|bond girl|official ...
# ...                                                                                       ...
# Signed Sealed Delivered                                fraud|postal worker|prison|theft|trial
# The Following                                    cult|fbi|hideout|prison escape|serial killer
# A Plague So Pleasant                                                                      NaN
# Shanghai Calling                                                                          NaN
# My Date with Drew                           actress name in title|crush|date|four word tit...
#
#                                            language country       budget  \
# title
# Avatar                                      English     USA  237000000.0
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
# John Carter                                 English     USA  263700000.0
# Tangled                                     English     USA  260000000.0
# Quantum of Solace                           English      UK  200000000.0
# ...                                             ...     ...          ...
# Signed Sealed Delivered                     English  Canada          NaN
# The Following                               English     USA          NaN
# A Plague So Pleasant                        English     USA       1400.0
# Shanghai Calling                            English     USA          NaN
# My Date with Drew                           English     USA       1100.0
#
#                                             imdb_score
# title
# Avatar                                             7.9
# Star Wars: Episode VII - The Force Awakens         7.1
# John Carter                                        6.6
# Tangled                                            7.8
# Quantum of Solace                                  6.7
# ...                                                ...
# Signed Sealed Delivered                            7.7
# The Following                                      7.5
# A Plague So Pleasant                               6.3
# Shanghai Calling                                   6.3
# My Date with Drew                                  6.6
#
# [3579 rows x 21 columns]

# %% [markdown]
# ### Exercise 13
#
# <span  style="color:green; font-size:16px">Select all movies from the 1970's.</span>

# %%
filt = (movie['year'] >= 1970) & (movie['year'] < 1980)
movie[filt]
# Out:
#                                  year            color content_rating  \
# title
# All That Jazz                  1979.0            Color              R
# Superman                       1978.0            Color             PG
# Solaris                        1972.0  Black and White             PG
# Mean Streets                   1973.0            Color              R
# Star Trek: The Motion Picture  1979.0            Color             PG
# ...                               ...              ...            ...
# Penitentiary                   1979.0            Color              R
# The Night Visitor              1971.0            Color             GP
# The Last Waltz                 1978.0            Color             PG
# Pink Narcissus                 1971.0            Color      Not Rated
# Pink Flamingos                 1972.0            Color          NC-17
#
#                                duration     director_name  director_fb  \
# title
# All That Jazz                     123.0         Bob Fosse        189.0
# Superman                          188.0    Richard Donner        503.0
# Solaris                           115.0  Andrei Tarkovsky          0.0
# Mean Streets                      112.0   Martin Scorsese      17000.0
# Star Trek: The Motion Picture     143.0       Robert Wise        338.0
# ...                                 ...               ...          ...
# Penitentiary                       99.0      Jamaa Fanaka          9.0
# The Night Visitor                 106.0     Laslo Benedek          6.0
# The Last Waltz                    117.0   Martin Scorsese      17000.0
# Pink Narcissus                     65.0     James Bidgood          0.0
# Pink Flamingos                    108.0       John Waters          0.0
#
#                                            actor1  actor1_fb  \
# title
# All That Jazz                        Roy Scheider      813.0
# Superman                            Marlon Brando    10000.0
# Solaris                          Donatas Banionis       29.0
# Mean Streets                       Robert De Niro    22000.0
# Star Trek: The Motion Picture       Leonard Nimoy    12000.0
# ...                                           ...        ...
# Penitentiary                   Leon Isaac Kennedy      116.0
# The Night Visitor                     Liv Ullmann      440.0
# The Last Waltz                        Ringo Starr      725.0
# Pink Narcissus                         Don Brooks        0.0
# Pink Flamingos                             Divine      462.0
#
#                                             actor2  actor2_fb  ... actor3_fb  \
# title                                                          ...
# All That Jazz                           Ben Vereen      388.0  ...      87.0
# Superman                             Margot Kidder      593.0  ...     467.0
# Solaris                        Anatoliy Solonitsyn       29.0  ...      12.0
# Mean Streets                       David Carradine      926.0  ...     354.0
# Star Trek: The Motion Picture     Nichelle Nichols      664.0  ...     643.0
# ...                                            ...        ...  ...       ...
# Penitentiary                        Chuck Mitchell       24.0  ...      10.0
# The Night Visitor                    Trevor Howard       98.0  ...      13.0
# The Last Waltz                          Levon Helm      572.0  ...     476.0
# Pink Narcissus                       Bobby Kendall        0.0  ...       NaN
# Pink Flamingos                          Mink Stole      143.0  ...     105.0
#
#                                      gross  \
# title
# All That Jazz                          NaN
# Superman                       134218018.0
# Solaris                                NaN
# Mean Streets                       32645.0
# Star Trek: The Motion Picture   82300000.0
# ...                                    ...
# Penitentiary                           NaN
# The Night Visitor                      NaN
# The Last Waltz                    321952.0
# Pink Narcissus                      8231.0
# Pink Flamingos                    180483.0
#
#                                                               genres  \
# title
# All That Jazz                             Comedy|Drama|Music|Musical
# Superman                       Action|Adventure|Drama|Romance|Sci-Fi
# Solaris                                         Drama|Mystery|Sci-Fi
# Mean Streets                            Crime|Drama|Romance|Thriller
# Star Trek: The Motion Picture               Adventure|Mystery|Sci-Fi
# ...                                                              ...
# Penitentiary                                       Crime|Drama|Sport
# The Night Visitor                              Crime|Horror|Thriller
# The Last Waltz                                     Documentary|Music
# Pink Narcissus                                         Drama|Fantasy
# Pink Flamingos                                   Comedy|Crime|Horror
#
#                               num_reviews  num_voted_users  \
# title
# All That Jazz                        84.0            19228
# Superman                            169.0           126357
# Solaris                             144.0            54057
# Mean Streets                        112.0            67797
# Star Trek: The Motion Picture       134.0            63330
# ...                                   ...              ...
# Penitentiary                         23.0              509
# The Night Visitor                    14.0              544
# The Last Waltz                       71.0            12611
# Pink Narcissus                        8.0              803
# Pink Flamingos                       73.0            16792
#
#                                                                    plot_keywords  \
# title
# All That Jazz                  dancer|editing|stand up comedian|surgery|vomiting
# Superman                             1970s|clark kent|planet|superhero|year 1978
# Solaris                        hallucination|ocean|psychologist|scientist|spa...
# Mean Streets                   bar|catholic guilt|epilepsy|italian american|m...
# Star Trek: The Motion Picture    alien|space|space station|spacecraft|warp speed
# ...                                                                          ...
# Penitentiary                   blaxploitation|boxing|convict|drifter|false ac...
# The Night Visitor              escape|independent film|mental illness|prison|...
# The Last Waltz                  band|final concert|guitar|interview|thanksgiving
# Pink Narcissus                 male frontal nudity|male pubic hair|male rear ...
# Pink Flamingos                      absurd humor|egg|gross out humor|lesbian|sex
#
#                               language       country      budget  imdb_score
# title
# All That Jazz                  English           USA         NaN         7.8
# Superman                       English           USA  55000000.0         7.3
# Solaris                        Russian  Soviet Union   1000000.0         8.1
# Mean Streets                   English           USA    500000.0         7.4
# Star Trek: The Motion Picture  English           USA  35000000.0         6.4
# ...                                ...           ...         ...         ...
# Penitentiary                   English           USA    100000.0         5.8
# The Night Visitor              English           USA         NaN         6.8
# The Last Waltz                 English           USA         NaN         8.2
# Pink Narcissus                 English           USA     27000.0         6.7
# Pink Flamingos                 English           USA     10000.0         6.1
#
# [109 rows x 21 columns]
